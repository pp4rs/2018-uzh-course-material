# %% [markdown]
# # Introduction
#
#
# There is no silver bullet to getting info from the internet.
#
# The coding requirements in these notes start easy and will gradually become more demanding. We will cover the following web scraping techniques
#
# 1. copy pasting clean tables
# 2. APIs
# 3. Scraping static webpages with BeautifulSoup
# 4. Scraping dynamic wepages with Selenium

# %% [markdown]
# # 1. Copy Pasting
#
# No, this isn’t a joke. If the data is in a clean table, and small enough that you can hightlight it all, copying and pasting often produces a text document that can be read in easily. For example, Wikipedia tables are easy to approach this way. Consider the list of nominal GDP by countries according to [Wikipedia](https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)). If you highlight one of the tables, paste it in a plaintext editor such as Atom, you could load with

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)

# %%
import pandas as pd

# %%
data = pd.read_csv("gdp_list_imf.txt", sep = "\t", names = ['no', 'country', 'gdp'])

# %%
data[1:15]
# Out:
#          no                          country  gdp
# 1   (US$MM)                              NaN  NaN
# 2       190                           Tuvalu   40
# 3       189                         Kiribati  186
# 4       188                 Marshall Islands  199
# 5       187                            Palau  321
# 6       186   Federated States of Micronesia  329
# 7       185            São Tomé and Príncipe  372
# 8       184                            Tonga  437
# 9       183                         Dominica  608
# 10      182                          Comoros  659
# 11      181   St. Vincent and the Grenadines  815
# 12      180                          Vanuatu  837
# 13      179                            Samoa  844
# 14      178              St. Kitts and Nevis  939

# %%
data[191:193]
# Out:
#     no                   country         gdp
# 191  1             United States  19,390,600
# 192  —   European Union[n 1][19]  17,308,862

# %% [markdown]
# # 2. API
#
# Application Programming Interface (API): set of methods to access data which is not publically available as a complete data set.
#
# A lot of APIs are private - either they’re only available to people who are authorized to use them, or they’re used internally by development teams. However, a good number are public, but may require purchasing access or at least registering to get an API key. There’s a useful list of [public APIs](https://github.com/toddmotto/public-apis) maintained by Todd Motto.
#
# ## Rate Limits
# Note that a lot of API’s have rate limits - the number of requests you can send in a particular window of time (e.g. 100 requests per hour). Before spending a lot of time scraping, make sure you know the rate limit and structure your requests appropriately. You may need to space your scraping out over a couple of days.
#
# ## JSON
# A lot of formal APIs return data in a format known as JSON (JavaScript Object Notation). It is similar to dictionaries in Python. An example modified from [Wikipedia](https://en.wikipedia.org/wiki/JSON):

# %% [markdown]
# ```
# {
#   "firstName": "John",
#   "lastName": "Smith",
#   "isAlive": true,
#   "age": 25,
#   "address": {
#     "streetAddress": "21 2nd Street",
#     "city": "New York",
#     "state": "NY",
#     "postalCode": "10021-3100"
#   },
#   "children": [],
#   "spouse": null
# }```

# %%
# Import json library to be able to read the data we want to import
import json

# %%
with open('wiki_example.json', 'r') as json_file:
  json_data = json.load(json_file)
json_data
# Out:
# {'firstName': 'John',
#  'lastName': 'Smith',
#  'isAlive': True,
#  'age': 25,
#  'address': {'streetAddress': '21 2nd Street',
#   'city': 'New York',
#   'state': 'NY',
#   'postalCode': '10021-3100'},
#  'children': [],
#  'spouse': None}

# %%
# The type of json is stored in dictionary format. Access data with familiar syntax. 
type(json_data)
# Out:
# dict

# %%
# let's access the dictionary
json_data['firstName']
# Out:
# 'John'

# %% [markdown]
# ## Example: Currency Rates
# The site [exchangeratesapi.io](https://exchangeratesapi.io/) provides an API to obtain daily currency conversion rates. The URL differs depending on the date desired; current results are [exchangeratesapi.io/api/latest](https://api.exchangeratesapi.io/latest). Query parameters include `base=` to get the comparison (default is “EUR”). We will obtain the JSON data from an API query and use the json library to parse the data.

# %%
import json
import requests
# These snippets you ll use very often for any scraping:

# Define the website we want to open as url
url = "https://api.exchangeratesapi.io/latest"
# Define the result we get as "response". Request.get(webpage argument) loads the page. 
response = requests.get(url)

# %%
# let's try to get the data. Here is one way. But strings are not so practical, you ll need to split it to access info. 
#data = response.text
data = response
data
#type(data)
# Out:
# <Response [200]>

# %%
#Let s get the actual output like this
data = response.text
data
# Out:
# '{"base":"EUR","date":"2018-08-28","rates":{"AUD":1.5924,"BGN":1.9558,"BRL":4.7909,"CAD":1.5128,"CHF":1.1427,"CNY":7.9641,"CZK":25.713,"DKK":7.4574,"GBP":0.9068,"HKD":9.1922,"HRK":7.4325,"HUF":323.79,"IDR":17122.0,"ILS":4.2431,"INR":82.096,"ISK":124.7,"JPY":130.03,"KRW":1294.7,"MXN":21.95,"MYR":4.797,"NOK":9.7243,"NZD":1.7444,"PHP":62.387,"PLN":4.2723,"RON":4.6464,"RUB":79.073,"SEK":10.663,"SGD":1.5945,"THB":38.098,"TRY":7.3316,"USD":1.171,"ZAR":16.589}}'

# %%
# looks like a dict, except this doesnt work. why?
data["base"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-799f23ea1f9f> in <module>()
#       1 # looks like a dict, except it is text. not so great
# ----> 2 data["base"]
#       3 # then
#       4 type(data)
#
# TypeError: string indices must be integers

# %%
# then: it is just text
type(data)
# Out:
# str

# %%
# Can also use data = response.json()
# Much easier to load in json to get a dictionary
data = json.loads(response.text)
data
# Out:
# {'base': 'EUR',
#  'date': '2018-08-28',
#  'rates': {'AUD': 1.5924,
#   'BGN': 1.9558,
#   'BRL': 4.7909,
#   'CAD': 1.5128,
#   'CHF': 1.1427,
#   'CNY': 7.9641,
#   'CZK': 25.713,
#   'DKK': 7.4574,
#   'GBP': 0.9068,
#   'HKD': 9.1922,
#   'HRK': 7.4325,
#   'HUF': 323.79,
#   'IDR': 17122.0,
#   'ILS': 4.2431,
#   'INR': 82.096,
#   'ISK': 124.7,
#   'JPY': 130.03,
#   'KRW': 1294.7,
#   'MXN': 21.95,
#   'MYR': 4.797,
#   'NOK': 9.7243,
#   'NZD': 1.7444,
#   'PHP': 62.387,
#   'PLN': 4.2723,
#   'RON': 4.6464,
#   'RUB': 79.073,
#   'SEK': 10.663,
#   'SGD': 1.5945,
#   'THB': 38.098,
#   'TRY': 7.3316,
#   'USD': 1.171,
#   'ZAR': 16.589}}

# %%
# Data is in the dictionary format
# Note that rates then has a dict inside a dictionary. 
type(data)
# Out:
# dict

# %%
# What is the rate of EUR to CHF?
data["rates"]
# Out:
# {'AUD': 1.5924,
#  'BGN': 1.9558,
#  'BRL': 4.7909,
#  'CAD': 1.5128,
#  'CHF': 1.1427,
#  'CNY': 7.9641,
#  'CZK': 25.713,
#  'DKK': 7.4574,
#  'GBP': 0.9068,
#  'HKD': 9.1922,
#  'HRK': 7.4325,
#  'HUF': 323.79,
#  'IDR': 17122.0,
#  'ILS': 4.2431,
#  'INR': 82.096,
#  'ISK': 124.7,
#  'JPY': 130.03,
#  'KRW': 1294.7,
#  'MXN': 21.95,
#  'MYR': 4.797,
#  'NOK': 9.7243,
#  'NZD': 1.7444,
#  'PHP': 62.387,
#  'PLN': 4.2723,
#  'RON': 4.6464,
#  'RUB': 79.073,
#  'SEK': 10.663,
#  'SGD': 1.5945,
#  'THB': 38.098,
#  'TRY': 7.3316,
#  'USD': 1.171,
#  'ZAR': 16.589}

# %%
data["rates"]["CHF"]
# Out:
# 1.1427

# %% [markdown]
# # Exercise 1
#
# Request the USD to JPY rate on 7th of March 2018. Hint: check the website on how to define the url.

# %%
url = "https://api.exchangeratesapi.io/2018-03-07?base=USD"
# Define the result we get as "response". Request.get(webpage argument) loads the page. 
response = requests.get(url)
# This converts a given string into a dictionary (unicode): allows you to access your JSON data
# Can also use data = response.json()
data = json.loads(response.text)
data['rates']["JPY"]
# Out:
# 105.83

# %% [markdown]
# # Exercise 2: Count the Number of Victims of US Drone Strikes
# The API [https://dronestre.am/](https://dronestre.am/) provides information on all reported US drone strikes. Write a few lines of code to access the Raw JSON data and parse them. Calculate the lower bound of the number of victims (deaths_min) of US drone strikes.

# %%
url = "http://api.dronestre.am/data"
response = requests.get(url)
data = json.loads(response.text)
data
# Out:
# {'status': 'OK',
#  'strike': [{'_id': '55c79e711cbee48856a30886',
#    'number': 1,
#    'country': 'Yemen',
#    'date': '2002-11-03T00:00:00.000Z',
#    'narrative': 'In the first known US targeted assassination using a drone, a CIA Predator struck a car, killing 6 people.',
#    'town': '',
#    'location': 'Marib Province',
#    'deaths': '6',
#    'deaths_min': '6',
#    'deaths_max': '6',
#    'civilians': '0',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '278544689483890688',
#    'bureau_id': 'YEM001',
#    'bij_summary_short': 'In the first known US targeted assassination using a drone, a CIA Predator struck a car killing six al Qaeda suspects.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2012/03/29/yemen-reported-us-covert-actions-since-2001/',
#    'target': '',
#    'lat': '15.47467',
#    'lon': '45.322755',
#    'articles': [],
#    'names': ["Qa'id Salim Sinan al-Harithi, Abu Ahmad al-Hijazi, Salih Hussain Ali al-Nunu, Awsan Ahmad al-Tarihi, Munir Ahmad Abdallah al-Sauda, Adil Nasir al-Sauda'"]},
#   {'_id': '55c79e711cbee48856a30887',
#    'number': 2,
#    'country': 'Pakistan',
#    'date': '2004-06-17T00:00:00.000Z',
#    'narrative': 'The first known fatal US drone strike inside Pakistan killed 6-8 people, including 2 children.',
#    'town': 'Wana',
#    'location': 'South Waziristan',
#    'deaths': '6-8',
#    'deaths_min': '6',
#    'deaths_max': '8',
#    'civilians': '2',
#    'injuries': '1',
#    'children': '2',
#    'tweet_id': '278544750867533824',
#    'bureau_id': 'B1',
#    'bij_summary_short': 'First known drone strike in Pakistan kills at least six, including infamous Taliban leader Nek Mohammad and two children. Wana, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Nek Mohammed',
#    'lat': '32.30512565',
#    'lon': '69.57624435',
#    'articles': [],
#    'names': ['Nek Mohammad, Fakhar Zaman, Azmat Khan, Marez Khan, Shahrukh Khan, Leetak, Sher Zaman Ashrafkhel']},
#   {'_id': '55c79e711cbee48856a30888',
#    'number': 3,
#    'country': 'Pakistan',
#    'date': '2005-05-08T00:00:00.000Z',
#    'narrative': "2 people killed in a Predator strike which reportedly targeted Haitham al-Yemeni's mobile phone.",
#    'town': 'Toorikhel',
#    'location': 'North Waziristan',
#    'deaths': '2',
#    'deaths_min': '2',
#    'deaths_max': '2',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '278544812255367168',
#    'bureau_id': 'B2',
#    'bij_summary_short': 'Two killed, including Haitham al-Yemeni an al Qaeda explosives expert, near Mir Ali, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Haitham al-Yemeni',
#    'lat': '32.98677989',
#    'lon': '70.26082993',
#    'articles': [],
#    'names': ['Haitham al-Yemeni, Samiullah Khan']},
#   {'_id': '55c79e721cbee48856a30889',
#    'number': 4,
#    'country': 'Pakistan',
#    'date': '2005-11-05T00:00:00.000Z',
#    'narrative': "A failed strike destroyed Abu Hamza Rabia's house and killed 8 people, including 3 young girls.",
#    'town': 'Mosaki',
#    'location': 'North Waziristan',
#    'deaths': '8',
#    'deaths_min': '8',
#    'deaths_max': '8',
#    'civilians': '3-8',
#    'injuries': '1',
#    'children': '3',
#    'tweet_id': '278544854483628032',
#    'bureau_id': 'B3',
#    'bij_summary_short': 'Failed strike against Abu Hamza Rabia ("al Qaeda\'s Number 3") kills eight including three children.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abu Hamza Rabia',
#    'lat': '32.99988191',
#    'lon': '70.34082413',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3088a',
#    'number': 5,
#    'country': 'Pakistan',
#    'date': '2005-12-01T00:00:00.000Z',
#    'narrative': "5 people were killed, including 2 children, when drones fired on a house 'for about 8 minutes.'",
#    'town': 'Haisori',
#    'location': 'North Waziristan',
#    'deaths': '5',
#    'deaths_min': '5',
#    'deaths_max': '5',
#    'civilians': '2',
#    'injuries': '',
#    'children': '2',
#    'tweet_id': '278544895789133825',
#    'bureau_id': 'B4',
#    'bij_summary_short': 'Syrian Abu Hamza Rabia, the senior al Qaeda operative targeted in B3, was killed with two other foreign militants and two boys, aged eight and 17.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abu Hamza Rabia',
#    'lat': '33.00866349',
#    'lon': '70.04196167',
#    'articles': [],
#    'names': ['Abu Hamza Rabia, Suleiman al-Moghrabi, Amer Azizi, Noor Aziz, Abdul Wasit']},
#   {'_id': '55c79e721cbee48856a3088b',
#    'number': 6,
#    'country': 'Pakistan',
#    'date': '2006-01-06T00:00:00.000Z',
#    'narrative': '8 people were reported killed including 2 women and 1 child.',
#    'town': 'Saidgai',
#    'location': 'North Waziristan',
#    'deaths': '8',
#    'deaths_min': '8',
#    'deaths_max': '8',
#    'civilians': '3-4',
#    'injuries': '9',
#    'children': '1',
#    'tweet_id': '278544937409200129',
#    'bureau_id': 'B4c',
#    'bij_summary_short': 'An attack on an unnamed alleged al Qaeda official left eight killed, including two women and at least one child.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '33.09499311',
#    'lon': '70.05912781',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3088c',
#    'number': 7,
#    'country': 'Pakistan',
#    'date': '2006-01-13T00:00:00.000Z',
#    'narrative': '18 civilians, including 6 children, were killed when a US Predator fired on 3 houses.',
#    'town': 'Damadola',
#    'location': 'Bajaur Agency',
#    'deaths': '13-22',
#    'deaths_min': '13',
#    'deaths_max': '22',
#    'civilians': '10-18',
#    'injuries': '',
#    'children': '5',
#    'tweet_id': '278545016044011520',
#    'bureau_id': 'B5',
#    'bij_summary_short': "A strike targeted a possible militant commanders' meeting. But main target Ayman al Zawahiri was absent. Up to 22 people died, most or all civilians, including at least five children.",
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Ayman al-Zawahiri; Abu Khabab al-Masri; Abd Rahman al-Masri al-Maghribi; Abu Ubeidah al-Masri; Marwan al-Suri; Khalid Habib; Abdul Hadi al-Iraqi',
#    'lat': '34.81549453',
#    'lon': '71.4969635',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3088d',
#    'number': 8,
#    'country': 'Pakistan',
#    'date': '2006-10-30T00:00:00.000Z',
#    'narrative': '80-83 civilians, including 69 children, reported killed.',
#    'town': 'Chenegai',
#    'location': 'Bajaur Agency',
#    'deaths': '81-83',
#    'deaths_min': '81',
#    'deaths_max': '83',
#    'civilians': '80-82',
#    'injuries': '3',
#    'children': '69',
#    'tweet_id': '278545055214612482',
#    'bureau_id': 'B6',
#    'bij_summary_short': 'An attack on a madrassa (allegedly a "Taliban training camp") killed 81-83, including at least 69 children.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Maulvi Liaqat',
#    'lat': '34.83634999',
#    'lon': '71.49215698',
#    'articles': [],
#    'names': ['Maulvi Liaqat, Mohammad Tahir (16), Maulvi Khaleefa, Azizul Wahab (15), Fazal Wahab (16), Ziauddin (16), Mohammad Yunus (16), Fazal Hakim (19), Ilyas (13), Sohail (07), Asadullah (09), Shoaib (08), Khalilullah (09), Noor Mohammad (08), Khalid (12), Saifullah (09), Razi Mohammad (16), Mashooq Jan (15), Nawab (17), Sultanat Khan (16), Mohammad Yaas Khan (16), Qari Alamzeb (14), Ghulam Nabi (21), Ziaur Rahman (17), Abdullah (18), Ikramullah (17), Inayatur Rahman (16), Shahbuddin (15), Yahya Khan (16), Rahatullah, (17), Khan (21), Mohammad Salim (11), Shahjehan (15), Gul Sher Khan (15), Bakht Muneer (14), Numair (14), Mashooq Khan (16), Ihsanullah (16), Luqman (12), Salman (16), Jannatullah (13), Ismail (12), Taseel Khan (18), Zaheeruddin (16), Qari Ishaq (19), Jamshed Khan (14), Alam Nabi (11), Qari Abdul Karim (19), Rahmatullah (14), Abdus Samad (17), Siraj (16), Saeedullah (17), Abdul Waris (16), Darvesh (13), Ameer Said (15), Shaukat (14), Inayatur Rahman (17), Ziaur Rahman (13), Noor Mohammad (15), Naeemullah (17),        Hizbullah (10), Kitab Gul (12), Wilayat Khan (11), Zabihullah (16), Shehzad Gul (11), Shabir (15), Qari Sharifullah (17), Shafiullah (16), Nimatullah (14), Shakirullah (16), Talha (08), Jamroz Khan, Fazal Wahab (18), Rahman (13), Wali-ur-Rahman (17), Iftikhar (17), Inayatullah (15), Adnan (16), Najibullah (13)']},
#   {'_id': '55c79e721cbee48856a3088e',
#    'number': 9,
#    'country': 'Pakistan',
#    'date': '2007-01-16T00:00:00.000Z',
#    'narrative': '8 people, many thought to be innocent woodcutters, were killed in a likely drone/helicopter strike.',
#    'town': 'Zamazola',
#    'location': 'South Waziristan',
#    'deaths': '8',
#    'deaths_min': '8',
#    'deaths_max': '8',
#    'civilians': '8',
#    'injuries': '',
#    'children': '0-1',
#    'tweet_id': '278545097790980096',
#    'bureau_id': 'B7',
#    'bij_summary_short': 'Initial claims of 30 Taliban killed were lowered to eight deaths, who villagers insist were all innocent woodcutters.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.83575063',
#    'lon': '69.55581665',
#    'articles': [],
#    'names': ['Katoor Khan, Taj Alam']},
#   {'_id': '55c79e721cbee48856a3088f',
#    'number': 10,
#    'country': 'Pakistan',
#    'date': '2007-04-27T00:00:00.000Z',
#    'narrative': 'An attack on a religious school killed four people and injured three.',
#    'town': 'Saidgai',
#    'location': 'North Waziristan',
#    'deaths': '3-4',
#    'deaths_min': '3',
#    'deaths_max': '4',
#    'civilians': '4',
#    'injuries': '9',
#    'children': '',
#    'tweet_id': '278545157916356608',
#    'bureau_id': 'B8',
#    'bij_summary_short': 'Attack on a house and madrassa killed 3-4, reportedly all named civilians.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Maulvi Noor Mohammed',
#    'lat': '33.09499311',
#    'lon': '70.05912781',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30890',
#    'number': 11,
#    'country': 'Pakistan',
#    'date': '2007-06-19T00:00:00.000Z',
#    'narrative': '20-50 people, including children, were killed in an attack on a school and several houses.',
#    'town': 'Mami Rogha',
#    'location': 'North Waziristan',
#    'deaths': '20-34',
#    'deaths_min': '20',
#    'deaths_max': '34',
#    'civilians': '0-34',
#    'injuries': '15',
#    'children': 'Possibly',
#    'tweet_id': '278545199360245760',
#    'bureau_id': 'B9',
#    'bij_summary_short': "20-34 killed in attack on a madrassa, including 'foreigners'. All killed could have been civilians and one report said children were among the dead.",
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.98879572',
#    'lon': '70.28743744',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30891',
#    'number': 12,
#    'country': 'Pakistan',
#    'date': '2007-11-02T00:00:00.000Z',
#    'narrative': 'A missile fired from an unmanned aerial drone killed 5 and wounded 6 others.',
#    'town': 'Danda Darpakhel',
#    'location': 'North Waziristan',
#    'deaths': '5-10',
#    'deaths_min': '5',
#    'deaths_max': '10',
#    'civilians': '',
#    'injuries': '12',
#    'children': '',
#    'tweet_id': '278545281103052800',
#    'bureau_id': 'B10',
#    'bij_summary_short': 'CIA drone strike kills 5-10 alleged Haqqani Network militants.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Jalalludin Haqqani',
#    'lat': '33.020179',
#    'lon': '70.07286072',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30892',
#    'number': 13,
#    'country': 'Pakistan',
#    'date': '2007-12-03T00:00:00.000Z',
#    'narrative': 'A US drone fired at least 2 missiles early Wednesday morning at a house near North Waziristan.',
#    'town': 'Jani Khel',
#    'location': 'Bannu Frontier',
#    'deaths': 'Unknown',
#    'deaths_min': '0',
#    'deaths_max': '0',
#    'civilians': '',
#    'injuries': '1',
#    'children': '',
#    'tweet_id': '278545321959768064',
#    'bureau_id': 'B11',
#    'bij_summary_short': 'Strike injures Egyptian al Qaeda leader and ideologue Shaykh Issa al-Masri, Details later emerge via leaked US intelligence document. ',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Shaykh Issa al-Masri',
#    'lat': '32.80285902',
#    'lon': '70.48690796',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30893',
#    'number': 14,
#    'country': 'Pakistan',
#    'date': '2008-01-29T00:00:00.000Z',
#    'narrative': '5 civilians, including 3 children, were reported dead in a strike that killed 12-14 people.',
#    'town': 'Mir Ali',
#    'location': 'North Waziristan',
#    'deaths': '12-15',
#    'deaths_min': '12',
#    'deaths_max': '15',
#    'civilians': '4-6',
#    'injuries': '1',
#    'children': '3',
#    'tweet_id': '278545359465238529',
#    'bureau_id': 'B12',
#    'bij_summary_short': 'Abu Laith al-Libi, a senior al Qaeda figure, was killed along with 12-15 others.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abu Laith al-Libi',
#    'lat': '32.95826549',
#    'lon': '70.24108887',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30894',
#    'number': 15,
#    'country': 'Pakistan',
#    'date': '2008-02-28T00:00:00.000Z',
#    'narrative': 'A 2am attack on a house killed up to 13 people.',
#    'town': 'Azam Warsak',
#    'location': 'South Waziristan',
#    'deaths': '8-13',
#    'deaths_min': '8',
#    'deaths_max': '13',
#    'civilians': '0-5',
#    'injuries': '16',
#    'children': '',
#    'tweet_id': '278545406126850048',
#    'bureau_id': 'B13',
#    'bij_summary_short': 'At least 8 killed, including possibly students, in strike on a madrassa.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.30222379',
#    'lon': '69.40544128',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30895',
#    'number': 16,
#    'country': 'Pakistan',
#    'date': '2008-03-16T00:00:00.000Z',
#    'narrative': '12-15 people were killed in a strike outside Waziristan that destroyed a house and a mosque.',
#    'town': 'Dhook Pir Bagh',
#    'location': 'South Waziristan',
#    'deaths': '12-20',
#    'deaths_min': '12',
#    'deaths_max': '20',
#    'civilians': '0-4',
#    'injuries': '9',
#    'children': '',
#    'tweet_id': '278545499399790592',
#    'bureau_id': 'B14',
#    'bij_summary_short': 'At least 12 alleged militants in an attack on the home of tribal elder Noorullah Wazir.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.30802742',
#    'lon': '69.45762634',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30896',
#    'number': 17,
#    'country': 'Pakistan',
#    'date': '2008-05-14T00:00:00.000Z',
#    'narrative': '18 people were killed when 2 missiles hit a house in the village of Damadola.',
#    'town': 'Damadola',
#    'location': 'Bajaur Agency',
#    'deaths': '12-20',
#    'deaths_min': '12',
#    'deaths_max': '20',
#    'civilians': '4-6',
#    'injuries': '9',
#    'children': '3',
#    'tweet_id': '278545545218383872',
#    'bureau_id': 'B15',
#    'bij_summary_short': 'Failed attack on Abu Sulayman al Jazairi, an al Qaeda weapons expert, kills at least 12 in a rare strike outside Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abu Sulayman al-Jazairi',
#    'lat': '34.81549453',
#    'lon': '71.4969635',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30897',
#    'number': 18,
#    'country': 'Pakistan',
#    'date': '2008-06-14T00:00:00.000Z',
#    'narrative': '1 person was killed as unmanned US drones fired three guided missiles at a house.',
#    'town': 'Makeen',
#    'location': 'South Waziristan',
#    'deaths': '1',
#    'deaths_min': '1',
#    'deaths_max': '1',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '278545584460288000',
#    'bureau_id': 'B16',
#    'bij_summary_short': 'One killed in strike on Makeen, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Baitullah Mehsud',
#    'lat': '32.62780989',
#    'lon': '69.84283447',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30898',
#    'number': 19,
#    'country': 'Pakistan',
#    'date': '2008-07-28T00:00:00.000Z',
#    'narrative': "A strike on a seminary killed al Qaeda's chemical weapons team, plus 2 young boys and their mom.",
#    'town': 'Zeralita',
#    'location': 'South Waziristan',
#    'deaths': '6-12',
#    'deaths_min': '6',
#    'deaths_max': '12',
#    'civilians': '1-5',
#    'injuries': '3',
#    'children': '3',
#    'tweet_id': '278545687979900928',
#    'bureau_id': 'B17',
#    'bij_summary_short': 'A strike on a seminary killed al Qaeda\'s "chemical weapons team", one woman and up to three boys.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abu Khabab al-Masri',
#    'lat': '32.28655215',
#    'lon': '69.43222046',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a30899',
#    'number': 20,
#    'country': 'Pakistan',
#    'date': '2008-08-12T00:00:00.000Z',
#    'narrative': '2 pilotless planes fired 4 hellfire missiles at about 10pm, killing between 13 and 25 people.',
#    'town': 'Bhaggar',
#    'location': 'South Waziristan',
#    'deaths': '13-25',
#    'deaths_min': '13',
#    'deaths_max': '25',
#    'civilians': '0-5',
#    'injuries': '4',
#    'children': 'Possibly',
#    'tweet_id': '278545723862159360',
#    'bureau_id': 'B18',
#    'bij_summary_short': 'At least 13 killed, including two named Taliban. Women and children reported among casualties. Bhagar, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abdul Rehman',
#    'lat': '32.30280417',
#    'lon': '69.32510376',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3089a',
#    'number': 21,
#    'country': 'Pakistan',
#    'date': '2008-08-20T00:00:00.000Z',
#    'narrative': 'Two missiles hit a house owned by a local tribesman, killing between 8 and 12 people.',
#    'town': 'Zari Noor',
#    'location': 'South Waziristan',
#    'deaths': '8-12',
#    'deaths_min': '8',
#    'deaths_max': '12',
#    'civilians': 'Unknown',
#    'injuries': '5',
#    'children': '',
#    'tweet_id': '278545762823053313',
#    'bureau_id': 'B19',
#    'bij_summary_short': '8-12 people killed in attack on alleged militant house.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.29758063',
#    'lon': '69.60062027',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3089b',
#    'number': 22,
#    'country': 'Pakistan',
#    'date': '2008-08-27T00:00:00.000Z',
#    'narrative': "A predator drone missed its target, hitting Sardali Khan's house, wounding a woman and 3 kids.",
#    'town': 'Ganki Khel',
#    'location': 'South Waziristan',
#    'deaths': '0',
#    'deaths_min': '0',
#    'deaths_max': '0',
#    'civilians': '0',
#    'injuries': '4',
#    'children': '',
#    'tweet_id': '278545805567201280',
#    'bureau_id': 'B20',
#    'bij_summary_short': 'Attack on al Qaeda-associated meeting killed none but injured four.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.1723754',
#    'lon': '69.33147601',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3089c',
#    'number': 23,
#    'country': 'Pakistan',
#    'date': '2008-08-30T00:00:00.000Z',
#    'narrative': '4 people, including 2 Canadians, were killed when a drone missile hit a house near Wana.',
#    'town': 'Korzai',
#    'location': 'South Waziristan',
#    'deaths': '4-5',
#    'deaths_min': '4',
#    'deaths_max': '5',
#    'civilians': '',
#    'injuries': '4',
#    'children': '',
#    'tweet_id': '278545843206909952',
#    'bureau_id': 'B21',
#    'bij_summary_short': 'Five killed including two Arab-Canadians. Korzai, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.3219546',
#    'lon': '69.52079773',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3089d',
#    'number': 24,
#    'country': 'Pakistan',
#    'date': '2008-08-30T00:00:00.000Z',
#    'narrative': '6 people were killed and 8 others injured in a mysterious missile attack on a residential area.',
#    'town': 'Miranshah',
#    'location': 'North Waziristan',
#    'deaths': '6-8',
#    'deaths_min': '6',
#    'deaths_max': '8',
#    'civilians': '2',
#    'injuries': '8',
#    'children': 'Yes',
#    'tweet_id': '278545880926265344',
#    'bureau_id': 'B22',
#    'bij_summary_short': "Woman and child killed along with four suspected militants, including two 'commanders'. Ghundi, North Waziristan.",
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '33.0020414',
#    'lon': '70.06084442',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3089e',
#    'number': 25,
#    'country': 'Pakistan',
#    'date': '2008-09-02T00:00:00.000Z',
#    'narrative': 'No details are known about this strike, though it appears in a leaked US intelligence report.',
#    'town': 'Unknown',
#    'location': 'North Waziristan',
#    'deaths': '4-10',
#    'deaths_min': '4',
#    'deaths_max': '10',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '278545915269230592',
#    'bureau_id': 'B23',
#    'bij_summary_short': 'Attack in unknown location kills 4-10 alleged al Qaeda militants.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abu Wafa al-Saudi',
#    'lat': '32.98677989',
#    'lon': '70.26082993',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a3089f',
#    'number': 26,
#    'country': 'Pakistan',
#    'date': '2008-09-04T00:00:00.000Z',
#    'narrative': '5 people were killed when a drone fired 3 missiles at a house near the Afghan border.',
#    'town': 'Mohammad Khel',
#    'location': 'North Waziristan',
#    'deaths': '5-7',
#    'deaths_min': '5',
#    'deaths_max': '7',
#    'civilians': '',
#    'injuries': '4',
#    'children': '',
#    'tweet_id': '278545956255956992',
#    'bureau_id': 'B24',
#    'bij_summary_short': 'Named al Qaeda militant killed along with 4-6 others. Momadkhel, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abu Wafa al-Saudi',
#    'lat': '32.99714649',
#    'lon': '69.72644806',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a0',
#    'number': 27,
#    'country': 'Pakistan',
#    'date': '2008-09-05T00:00:00.000Z',
#    'narrative': 'Up to 7 civilians, all women and children, were reported killed in a US drone strike.',
#    'town': 'Gurwak',
#    'location': 'North Waziristan',
#    'deaths': '5-12',
#    'deaths_min': '5',
#    'deaths_max': '12',
#    'civilians': '7',
#    'injuries': '',
#    'children': '4',
#    'tweet_id': '278545991664279552',
#    'bureau_id': 'B25',
#    'bij_summary_short': "Three women and four children killed in attack on two houses in Miranshah, North Waziristan. Five 'militants' also reported killed by some sources.",
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '33.03860068',
#    'lon': '69.53933716',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a1',
#    'number': 28,
#    'country': 'Pakistan',
#    'date': '2008-09-08T00:00:00.000Z',
#    'narrative': "Missiles fired by US drones killed 23 people, including 8 of the target's grandchildren.",
#    'town': 'Miranshah',
#    'location': 'North Waziristan',
#    'deaths': '17-23',
#    'deaths_min': '17',
#    'deaths_max': '23',
#    'civilians': '11-14',
#    'injuries': '25',
#    'children': '8',
#    'tweet_id': '278546035700269057',
#    'bureau_id': 'B26',
#    'bij_summary_short': 'At least 11 civilians, mostly girls, killed with six others including four named militants.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Jalalludin Haqqani',
#    'lat': '33.0020414',
#    'lon': '70.06084442',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a2',
#    'number': 29,
#    'country': 'Pakistan',
#    'date': '2008-09-12T00:00:00.000Z',
#    'narrative': 'An early morning attack on a former school killed between 10 and 15 people.',
#    'town': 'Tol Khel',
#    'location': 'North Waziristan',
#    'deaths': '10-15',
#    'deaths_min': '10',
#    'deaths_max': '15',
#    'civilians': '',
#    'injuries': '14',
#    'children': '',
#    'tweet_id': '278546070982762496',
#    'bureau_id': 'B27',
#    'bij_summary_short': '10-15 alleged militants killed in Tol Khel, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Qari Imran',
#    'lat': '33.00211338',
#    'lon': '70.0756073',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a3',
#    'number': 30,
#    'country': 'Pakistan',
#    'date': '2008-09-17T00:00:00.000Z',
#    'narrative': 'At least 5 people were killed in a suspected missile attack by a US drone.',
#    'town': 'Baghar Cheena',
#    'location': 'South Waziristan',
#    'deaths': '4-7',
#    'deaths_min': '4',
#    'deaths_max': '7',
#    'civilians': '',
#    'injuries': '3',
#    'children': '',
#    'tweet_id': '278546105246023681',
#    'bureau_id': 'B28',
#    'bij_summary_short': '4-7 killed including possibly Abu Ubaydh Al Tunisi, identified as a High Value Target in a leaked US intelligence document.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.50339198',
#    'lon': '69.28459167',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a4',
#    'number': 31,
#    'country': 'Pakistan',
#    'date': '2008-09-30T00:00:00.000Z',
#    'narrative': 'After tribesmen fired on 3 drones circling their village, a Predator killed up to 8 people.',
#    'town': 'Khushali',
#    'location': 'South Waziristan',
#    'deaths': '4-8',
#    'deaths_min': '4',
#    'deaths_max': '8',
#    'civilians': '0-8',
#    'injuries': '9',
#    'children': '',
#    'tweet_id': '278546136686555136',
#    'bureau_id': 'B29',
#    'bij_summary_short': '4-8 killed, 9 injured in attack on Toorikhel, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.96863543',
#    'lon': '70.35301208',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a5',
#    'number': 32,
#    'country': 'Pakistan',
#    'date': '2008-10-03T00:00:00.000Z',
#    'narrative': 'Two women and a child were killed in a 5:30am strike on 2 houses which also injured 5 men.',
#    'town': 'Datta Khel',
#    'location': 'North Waziristan',
#    'deaths': '3',
#    'deaths_min': '3',
#    'deaths_max': '3',
#    'civilians': '3',
#    'injuries': '5',
#    'children': '1',
#    'tweet_id': '278546173269254144',
#    'bureau_id': 'B30',
#    'bij_summary_short': 'Two women and a child killed in a strike on two houses in Datta Khel, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '33.151242',
#    'lon': '70.434707',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a6',
#    'number': 33,
#    'country': 'Pakistan',
#    'date': '2008-10-03T00:00:00.000Z',
#    'narrative': 'The second US drone strike of the day killed at least 20 people.',
#    'town': 'Datta Khel',
#    'location': 'North Waziristan',
#    'deaths': '21',
#    'deaths_min': '21',
#    'deaths_max': '21',
#    'civilians': '7-14',
#    'injuries': '',
#    'children': '3',
#    'tweet_id': '278546211399667713',
#    'bureau_id': 'B31',
#    'bij_summary_short': '21 killed including a woman and a child. Datta Khel, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '33.151242',
#    'lon': '70.434707',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a7',
#    'number': 34,
#    'country': 'Pakistan',
#    'date': '2008-10-09T00:00:00.000Z',
#    'narrative': 'Two missiles hit a house, killing 9 people.',
#    'town': 'Tati',
#    'location': 'North Waziristan',
#    'deaths': '4-9',
#    'deaths_min': '4',
#    'deaths_max': '9',
#    'civilians': '4-9',
#    'injuries': '2',
#    'children': '4-Mar',
#    'tweet_id': '278546249148416000',
#    'bureau_id': 'B32',
#    'bij_summary_short': '4-9 people killed, including women and children.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Hafiz Sahar Gul',
#    'lat': '32.994267',
#    'lon': '70.1653862',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a8',
#    'number': 35,
#    'country': 'Pakistan',
#    'date': '2008-10-11T00:00:00.000Z',
#    'narrative': 'Unmanned drones targeted a house on Saturday night, killing 4 people and injuring 2 others.',
#    'town': 'Miranshah',
#    'location': 'North Waziristan',
#    'deaths': '4-5',
#    'deaths_min': '4',
#    'deaths_max': '5',
#    'civilians': '0-5',
#    'injuries': '2',
#    'children': '',
#    'tweet_id': '278546280647643136',
#    'bureau_id': 'B33',
#    'bij_summary_short': 'The house of Rahmat Jahan is attacked killing five and wounding two. Miranshah, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '33.0020414',
#    'lon': '70.06084442',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308a9',
#    'number': 36,
#    'country': 'Pakistan',
#    'date': '2008-10-16T00:00:00.000Z',
#    'narrative': 'A US Predator drone killed 6 people and wounded 5 others in the village of Sam.',
#    'town': 'Taparghai',
#    'location': 'South Waziristan',
#    'deaths': '5-9',
#    'deaths_min': '5',
#    'deaths_max': '9',
#    'civilians': '4',
#    'injuries': '7',
#    'children': '',
#    'tweet_id': '278546312549498880',
#    'bureau_id': 'B34',
#    'bij_summary_short': 'Named al Qaeda leader killed along with 4 militants and 4 civilians. Tapargai, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Khalid Habib',
#    'lat': '32.54131432',
#    'lon': '69.85279083',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308aa',
#    'number': 37,
#    'country': 'Pakistan',
#    'date': '2008-10-23T00:00:00.000Z',
#    'narrative': 'US drones struck a seminary on Thursday, killing 10 people and wounding 3.',
#    'town': 'Danda Darpakhel',
#    'location': 'North Waziristan',
#    'deaths': '7-11',
#    'deaths_min': '7',
#    'deaths_max': '11',
#    'civilians': '0-7',
#    'injuries': '11',
#    'children': 'Possibly',
#    'tweet_id': '278546342681403392',
#    'bureau_id': 'B35',
#    'bij_summary_short': '7-11 killed, possibly including children, in attack on Danda Darpakhel, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '33.020179',
#    'lon': '70.07286072',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308ab',
#    'number': 38,
#    'country': 'Pakistan',
#    'date': '2008-10-26T00:00:00.000Z',
#    'narrative': 'A missile from a US drone killed 20 people on Sunday.',
#    'town': 'Mandata',
#    'location': 'South Waziristan',
#    'deaths': '15-20',
#    'deaths_min': '15',
#    'deaths_max': '20',
#    'civilians': '4-9',
#    'injuries': '2',
#    'children': '0-3',
#    'tweet_id': '278546374788792320',
#    'bureau_id': 'B36',
#    'bij_summary_short': 'Failed strike on Haji Omar kills 15-20, including at least four civilians.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Maulvi Nazir',
#    'lat': '32.55100944',
#    'lon': '69.60783005',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308ac',
#    'number': 39,
#    'country': 'Pakistan',
#    'date': '2008-10-31T00:00:00.000Z',
#    'narrative': 'More than 20 people were killed when a drone fired 2 missiles, destroying a house near Mir Ali.',
#    'town': 'Asori',
#    'location': 'North Waziristan',
#    'deaths': '4-25',
#    'deaths_min': '4',
#    'deaths_max': '25',
#    'civilians': '0-20',
#    'injuries': '0',
#    'children': '',
#    'tweet_id': '278546410444578816',
#    'bureau_id': 'B37',
#    'bij_summary_short': 'Between 4 and 25 killed, possibly including civilians, in failed attack on al Qaeda targets. Mir Ali, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abu Jihad al-Masri; Abdur Rehman abu Akash',
#    'lat': '32.97583606',
#    'lon': '70.26906967',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308ad',
#    'number': 40,
#    'country': 'Pakistan',
#    'date': '2008-10-31T00:00:00.000Z',
#    'narrative': 'In the second strike of the day, US drones blew up a truck, killing between 4 and 12 people.',
#    'town': 'Kari Kot',
#    'location': 'South Waziristan',
#    'deaths': '4-12',
#    'deaths_min': '4',
#    'deaths_max': '12',
#    'civilians': '',
#    'injuries': '30',
#    'children': '',
#    'tweet_id': '278546446343610371',
#    'bureau_id': 'B38',
#    'bij_summary_short': 'Up to 12 killed and Taliban leader Maulvi Nazir among 30 wounded.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Maulvi Nazir',
#    'lat': '32.31760259',
#    'lon': '69.50054169',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308ae',
#    'number': 41,
#    'country': 'Pakistan',
#    'date': '2008-11-07T00:00:00.000Z',
#    'narrative': 'Up to 14 people were killed in a US drone strike, including 6 reported civilians.',
#    'town': 'Kumsham',
#    'location': 'North Waziristan',
#    'deaths': '11-16',
#    'deaths_min': '11',
#    'deaths_max': '16',
#    'civilians': '6',
#    'injuries': '17',
#    'children': '',
#    'tweet_id': '278546482364313602',
#    'bureau_id': 'B39',
#    'bij_summary_short': "Up to 16 killed, including 'Westerners and US citizens'. Kumsham, Miramshah, North Waziristan.",
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Hafiz Gul Bahadar',
#    'lat': '32.74396995',
#    'lon': '70.06736755',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308af',
#    'number': 42,
#    'country': 'Pakistan',
#    'date': '2008-11-14T00:00:00.000Z',
#    'narrative': '11-13 people were killed when a US drone struck a residential area in Shagai.',
#    'town': 'Garyom',
#    'location': 'North Waziristan',
#    'deaths': '11-13',
#    'deaths_min': '11',
#    'deaths_max': '13',
#    'civilians': '3-11',
#    'injuries': '2',
#    'children': 'Yes',
#    'tweet_id': '278546510952673280',
#    'bureau_id': 'B40',
#    'bij_summary_short': '11-13 killed including at least three civilians. Garyom, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Hakimullah Mehsud; Baitullah Mehsud',
#    'lat': '32.7028111',
#    'lon': '69.86875534',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b0',
#    'number': 43,
#    'country': 'Pakistan',
#    'date': '2008-11-19T00:00:00.000Z',
#    'narrative': 'A US drone strike in Bannu killed 4 people and injured 5 others.',
#    'town': 'Jani Khel',
#    'location': 'Bannu Frontier',
#    'deaths': '4-6',
#    'deaths_min': '4',
#    'deaths_max': '6',
#    'civilians': '',
#    'injuries': '7',
#    'children': '',
#    'tweet_id': '278546543869566976',
#    'bureau_id': 'B41',
#    'bij_summary_short': 'Al Qaeda operative Abdullah Azzam al Saudi killed with up to five others in attack outside FATA which causes uproar.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Abdullah Azzam al-Saudi',
#    'lat': '32.80285902',
#    'lon': '70.48690796',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b1',
#    'number': 44,
#    'country': 'Pakistan',
#    'date': '2008-11-22T00:00:00.000Z',
#    'narrative': 'A pre-dawn attack on a house in North Waziristan killed between 4 and 6 people.',
#    'town': 'Ali Khel',
#    'location': 'North Waziristan',
#    'deaths': '4-6',
#    'deaths_min': '4',
#    'deaths_max': '6',
#    'civilians': '',
#    'injuries': '6',
#    'children': '',
#    'tweet_id': '278546582121615361',
#    'bureau_id': 'B42',
#    'bij_summary_short': 'Two named militants and up to four others killed in Ali Khel, Miranshah, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Zubair al-Masri',
#    'lat': '32.98015615',
#    'lon': '70.06530762',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b2',
#    'number': 45,
#    'country': 'Pakistan',
#    'date': '2008-11-27T00:00:00.000Z',
#    'narrative': '5 people were killed in an attack on a moving vehicle Wednesday, caused by either an IED or a drone.',
#    'town': 'Wana',
#    'location': 'South Waziristan',
#    'deaths': '5',
#    'deaths_min': '5',
#    'deaths_max': '5',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '278546660429283328',
#    'bureau_id': 'B43',
#    'bij_summary_short': 'Drone strike destroys vehicle killing five alleged Pakistan Taliban.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.30512565',
#    'lon': '69.57624435',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b3',
#    'number': 46,
#    'country': 'Pakistan',
#    'date': '2008-11-29T00:00:00.000Z',
#    'narrative': "A US drone fired a missile at a Professor's house, killing 2 or 3 people.",
#    'town': 'Chashma',
#    'location': 'North Waziristan',
#    'deaths': '2-3',
#    'deaths_min': '2',
#    'deaths_max': '3',
#    'civilians': '0-3',
#    'injuries': '3',
#    'children': 'Possibly',
#    'tweet_id': '278546693165834240',
#    'bureau_id': 'B44',
#    'bij_summary_short': 'Two or three killed, possibly all civilians. Chashma, Miranshah, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.98649192',
#    'lon': '70.04608154',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b4',
#    'number': 47,
#    'country': 'Pakistan',
#    'date': '2008-12-05T00:00:00.000Z',
#    'narrative': '3 people were killed in a missile attack by a suspected US drone.',
#    'town': 'Kateera',
#    'location': 'North Waziristan',
#    'deaths': '3-4',
#    'deaths_min': '3',
#    'deaths_max': '4',
#    'civilians': '',
#    'injuries': '2',
#    'children': '',
#    'tweet_id': '278546734169333761',
#    'bureau_id': 'B45',
#    'bij_summary_short': '3-4 alleged Taliban killed in Kateera, Mir Ali, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.59125977',
#    'lon': '70.15396057',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b5',
#    'number': 48,
#    'country': 'Pakistan',
#    'date': '2008-12-11T00:00:00.000Z',
#    'narrative': 'A missile, suspected to be from a pilotless US drone, killed 7 people on Thursday.',
#    'town': 'Azam Warsak',
#    'location': 'South Waziristan',
#    'deaths': '6-7',
#    'deaths_min': '6',
#    'deaths_max': '7',
#    'civilians': '0-7',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '278546769334386688',
#    'bureau_id': 'B46',
#    'bij_summary_short': "Six or seven killed, either some 'foreigners' or all civilians, Azam Warzak, South Waziristan.",
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.30222379',
#    'lon': '69.40544128',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b6',
#    'number': 49,
#    'country': 'Pakistan',
#    'date': '2008-12-15T00:00:00.000Z',
#    'narrative': '2 people were killed in a night-time strike that set a house on fire.',
#    'town': 'Tapi Tool',
#    'location': 'North Waziristan',
#    'deaths': '2-3',
#    'deaths_min': '2',
#    'deaths_max': '3',
#    'civilians': '0-2',
#    'injuries': '3',
#    'children': '',
#    'tweet_id': '278546919876358144',
#    'bureau_id': 'B47',
#    'bij_summary_short': 'At least two killed in Tapi Tool, Miran Shah, North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.97958015',
#    'lon': '70.08590698',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b7',
#    'number': 50,
#    'country': 'Pakistan',
#    'date': '2008-12-22T00:00:00.000Z',
#    'narrative': 'Two US drone missiles killed 8 in Karikot and Shin Warsak, causing huge fires in both villages',
#    'town': 'Kari Kot',
#    'location': 'South Waziristan',
#    'deaths': '3',
#    'deaths_min': '3',
#    'deaths_max': '3',
#    'civilians': '',
#    'injuries': '5',
#    'children': '',
#    'tweet_id': '278546957289529344',
#    'bureau_id': 'B48',
#    'bij_summary_short': 'Three killed in attack on a truck in Kari Kot, Wana, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Maulvi Nazir',
#    'lat': '32.31760259',
#    'lon': '69.50054169',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b8',
#    'number': 51,
#    'country': 'Pakistan',
#    'date': '2008-12-22T00:00:00.000Z',
#    'narrative': 'Between 2 and 4 people were killed and 4 injured in a further strike on an anti-aircraft truck.',
#    'town': 'Shin Warsak',
#    'location': 'South Waziristan',
#    'deaths': '2-4',
#    'deaths_min': '2',
#    'deaths_max': '4',
#    'civilians': '',
#    'injuries': '4',
#    'children': '',
#    'tweet_id': '278547000440549377',
#    'bureau_id': 'B49',
#    'bij_summary_short': 'At least two killed in attack on truck in Shin Warzak, Wana, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Maulvi Nazir',
#    'lat': '32.29337255',
#    'lon': '69.49728012',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308b9',
#    'number': 52,
#    'country': 'Pakistan',
#    'date': '2009-01-01T00:00:00.000Z',
#    'narrative': 'A CIA drone strike killed up to 5 people in South Waziristan.',
#    'town': 'Kari Kot',
#    'location': 'South Waziristan',
#    'deaths': '3-5',
#    'deaths_min': '3',
#    'deaths_max': '5',
#    'civilians': '',
#    'injuries': '2',
#    'children': '',
#    'tweet_id': '278547122054369280',
#    'bureau_id': 'B50',
#    'bij_summary_short': 'Two named al Qaeda militants and up to thee other people killed in strike on vehicle, Kari Kot, Wana, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': '',
#    'lat': '32.31760259',
#    'lon': '69.50054169',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308ba',
#    'number': 53,
#    'country': 'Pakistan',
#    'date': '2009-01-02T00:00:00.000Z',
#    'narrative': "In the final strike of Bush's presidency, an attack on an abandoned girls' school killed 3-4 people.",
#    'town': 'Madin Village',
#    'location': 'South Waziristan',
#    'deaths': '3-4',
#    'deaths_min': '3',
#    'deaths_max': '4',
#    'civilians': '',
#    'injuries': '5',
#    'children': '',
#    'tweet_id': '278547164349739008',
#    'bureau_id': 'B51',
#    'bij_summary_short': 'Three to four killed in last strike of Bush presidency.  Madin, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/',
#    'target': 'Baitullah Mehsud',
#    'lat': '32.53986719',
#    'lon': '69.88197327',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308bb',
#    'number': 54,
#    'country': 'Pakistan',
#    'date': '2009-01-23T00:00:00.000Z',
#    'narrative': "President Obama's first drone strike killed between 7 and 15 people, including 1 child.",
#    'town': 'Zharki',
#    'location': 'North Waziristan',
#    'deaths': '7-15',
#    'deaths_min': '7',
#    'deaths_max': '15',
#    'civilians': '7-11',
#    'injuries': '1',
#    'children': '1',
#    'tweet_id': '278547217638367233',
#    'bureau_id': 'Ob1',
#    'bij_summary_short': '7 civilians and 4 or more militants reported killed in strike on house in Zharki, Mir Ali,North Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/obama-2009-strikes/',
#    'target': 'Baitullah Mehsud ally',
#    'lat': '32.95340416',
#    'lon': '70.26224613',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308bc',
#    'number': 55,
#    'country': 'Pakistan',
#    'date': '2009-01-23T00:00:00.000Z',
#    'narrative': 'Second strike of the day killed between 5 and 8 people, including 3 children.',
#    'town': 'Ganki Khel',
#    'location': 'South Waziristan',
#    'deaths': '5-10',
#    'deaths_min': '5',
#    'deaths_max': '10',
#    'civilians': '5-8',
#    'injuries': '',
#    'children': '3',
#    'tweet_id': '278547253046685696',
#    'bureau_id': 'Ob2',
#    'bij_summary_short': '7-11 people killed, including several members of a family killed including at least three children in strike on wrong house in Dilfar, Wana, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/obama-2009-strikes/',
#    'target': 'Maulvi Nazir',
#    'lat': '32.1723754',
#    'lon': '69.33147601',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308bd',
#    'number': 56,
#    'country': 'Pakistan',
#    'date': '2009-02-14T00:00:00.000Z',
#    'narrative': 'Two missiles fired from a US drone killed more than 30 people, including an 8-year old boy.',
#    'town': 'Narsi Khel',
#    'location': 'South Waziristan',
#    'deaths': '26-35',
#    'deaths_min': '26',
#    'deaths_max': '35',
#    'civilians': '9',
#    'injuries': '15',
#    'children': '1',
#    'tweet_id': '278547289637801986',
#    'bureau_id': 'Ob3',
#    'bij_summary_short': '26-35 alleged militants and 8-year old boy killed in strike on house and madrassa in Zangari, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/obama-2009-strikes/',
#    'target': 'Baitullah Mehsud',
#    'lat': '32.51613104',
#    'lon': '69.86515045',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308be',
#    'number': 57,
#    'country': 'Pakistan',
#    'date': '2009-02-16T00:00:00.000Z',
#    'narrative': '25 killed, several injured in Central Kurram drone strikes.',
#    'town': 'Sur Pul',
#    'location': 'Kurram Agency',
#    'deaths': '30-31',
#    'deaths_min': '30',
#    'deaths_max': '31',
#    'civilians': '0',
#    'injuries': '7',
#    'children': '',
#    'tweet_id': '278547319727726592',
#    'bureau_id': 'Ob4',
#    'bij_summary_short': '30-31 killed in a strike on a camp in Sarpal, Kurram Agency',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/obama-2009-strikes/',
#    'target': 'Bahram Khan Kochi',
#    'lat': '33.68035403',
#    'lon': '70.29361725',
#    'articles': [],
#    'names': ['']},
#   {'_id': '55c79e721cbee48856a308bf',
#    'number': 58,
#    'country': 'Pakistan',
#    'date': '2009-03-01T00:00:00.000Z',
#    'narrative': 'Two missiles fired Sunday from American remotely piloted aircraft killed at least 8 people.',
#    'town': 'Sararogha',
#    'location': 'South Waziristan',
#    'deaths': '7-12',
#    'deaths_min': '7',
#    'deaths_max': '12',
#    'civilians': '',
#    'injuries': '3',
#    'children': '',
#    'tweet_id': '278547352896274432',
#    'bureau_id': 'Ob5',
#    'bij_summary_short': 'At least seven killed in an attack on alleged TTP facility in Sararogha, Wana, South Waziristan.',
#    'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/obama-2009-strikes/',
#    'target': 'Baitullah Mehsud',
#    'lat': '32.48891359',
# ...
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2012/02/22/get-the-data-somalias-hidden-war/#SOM038',
#    'target': '',
#    'lat': '2.114609',
#    'lon': '45.150474',
#    'articles': [],
#    'names': ['']},
#   {'_id': '5775a0d7395e4f60f00bca19',
#    'number': 625,
#    'country': 'Yemen',
#    'date': '2016-05-19T00:00:00.000Z',
#    'narrative': 'On Thursday, in the middle of the desert, two drone missiles destroyed a car. 2 people killed.',
#    'town': '',
#    'location': '',
#    'deaths': '2',
#    'deaths_min': '2',
#    'deaths_max': '2',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '733389310154657792',
#    'bureau_id': 'YEM230',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM230',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '5775a0d7395e4f60f00bca18',
#    'number': 626,
#    'country': 'Pakistan',
#    'date': '2016-05-21T00:00:00.000Z',
#    'narrative': 'Maybe it was Mr. Mansour. Several US drones lit up a car near Ahmad Wal, killing 2 people.',
#    'town': 'Ahmad Wal',
#    'location': 'Balochistan',
#    'deaths': '2',
#    'deaths_min': '2',
#    'deaths_max': '2',
#    'civilians': '1',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '734170592874799104',
#    'bureau_id': 'Ob373',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/11/obama-2016-pakistan-drone-strikes/#Ob373',
#    'target': '',
#    'lat': '29.382158',
#    'lon': '65.923181',
#    'articles': [],
#    'names': ['']},
#   {'_id': '5775a0d7395e4f60f00bca15',
#    'number': 627,
#    'country': 'Somalia',
#    'date': '2016-05-27T00:00:00.000Z',
#    'narrative': "On Friday, in south-central Somalia, the United States fired a missile at Mr. Da'ud.",
#    'town': '',
#    'location': 'South-central Somalia',
#    'deaths': '1',
#    'deaths_min': '1',
#    'deaths_max': '1',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '738434605833965568',
#    'bureau_id': 'SOM039',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2012/02/22/get-the-data-somalias-hidden-war/#SOM039',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '5775a0d7395e4f60f00bca16',
#    'number': 628,
#    'country': 'Yemen',
#    'date': '2016-06-12T00:00:00.000Z',
#    'narrative': 'Three U.S. drone strikes killed six people across Bayda, Marib, and Shabwah.',
#    'town': '',
#    'location': 'Al Bayda, Marib, and Shabwah Province',
#    'deaths': '6',
#    'deaths_min': '6',
#    'deaths_max': '6',
#    'civilians': '',
#    'injuries': '1',
#    'children': '',
#    'tweet_id': '748568695597826049',
#    'bureau_id': 'YEM233',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM233',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '5775a0d7395e4f60f00bca17',
#    'number': 629,
#    'country': 'Yemen',
#    'date': '2016-06-27T00:00:00.000Z',
#    'narrative': 'On Monday, a drone missile hit a home, ending the lives of 5 people.',
#    'town': 'Mahfad',
#    'location': 'Abyan Province',
#    'deaths': '5',
#    'deaths_min': '5',
#    'deaths_max': '5',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '748569029070168064',
#    'bureau_id': 'YEM234',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM234',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d82aba395e4f60f00bca50',
#    'number': 630,
#    'country': 'Yemen',
#    'date': '2016-07-01T00:00:00.000Z',
#    'narrative': 'While the U.S. announced its drone strike statistics, three people were killed in an SUV.',
#    'town': 'Gardan',
#    'location': 'Shabwah Province',
#    'deaths': '3',
#    'deaths_min': '3',
#    'deaths_max': '3',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '748995365433643008',
#    'bureau_id': 'YEM234',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM235',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d82aba395e4f60f00bca4a',
#    'number': 631,
#    'country': 'Yemen',
#    'date': '2016-07-04T00:00:00.000Z',
#    'narrative': 'Fireworks. Or something like it. A missile from the sky. Three people were burned in their car.',
#    'town': 'Musaina',
#    'location': 'Shabwah Province',
#    'deaths': '3',
#    'deaths_min': '3',
#    'deaths_max': '3',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '750369932249067520',
#    'bureau_id': 'YEM235',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM235',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d82aba395e4f60f00bca4c',
#    'number': 632,
#    'country': 'Yemen',
#    'date': '2016-07-10T00:00:00.000Z',
#    'narrative': 'A U.S. drone fired missiles at a car, wounding 4 people.',
#    'town': 'Jabul',
#    'location': 'Marib Province',
#    'deaths': '4',
#    'deaths_min': '4',
#    'deaths_max': '4',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '753269436568797184',
#    'bureau_id': 'YEM237',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM237',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d82aba395e4f60f00bca4e',
#    'number': 633,
#    'country': 'Yemen',
#    'date': '2016-07-16T00:00:00.000Z',
#    'narrative': 'On Saturday, 3 people were killed in a car.',
#    'town': 'Al Uqlah',
#    'location': 'Shabwah Province',
#    'deaths': '3',
#    'deaths_min': '3',
#    'deaths_max': '3',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '755065990631845888',
#    'bureau_id': 'YEM238',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM238',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d82aba395e4f60f00bca4b',
#    'number': 634,
#    'country': 'Yemen',
#    'date': '2016-08-04T00:00:00.000Z',
#    'narrative': '3 people killed.',
#    'town': 'Azzan',
#    'location': 'Shabwah Province',
#    'deaths': '3',
#    'deaths_min': '3',
#    'deaths_max': '3',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '775716671285788672',
#    'bureau_id': 'YEM239',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM239',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d82aba395e4f60f00bca4d',
#    'number': 635,
#    'country': 'Yemen',
#    'date': '2016-08-24T00:00:00.000Z',
#    'narrative': 'Three drone strikes. In a military press release, the United States announced the end of 13 people.',
#    'town': '',
#    'location': 'Shabwah Province',
#    'deaths': '4',
#    'deaths_min': '4',
#    'deaths_max': '4',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '775717701381742592',
#    'bureau_id': 'YEM240',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM240',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d82aba395e4f60f00bca51',
#    'number': 636,
#    'country': 'Yemen',
#    'date': '2016-08-30T00:00:00.000Z',
#    'narrative': 'Three drone strikes. In a military press release, the United States announced the end of 13 people.',
#    'town': '',
#    'location': 'Shabwah Province',
#    'deaths': '3',
#    'deaths_min': '3',
#    'deaths_max': '3',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '775717701381742592',
#    'bureau_id': 'YEM241',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM241',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d82aba395e4f60f00bca4f',
#    'number': 637,
#    'country': 'Yemen',
#    'date': '2016-09-04T00:00:00.000Z',
#    'narrative': 'Three drone strikes. In a military press release, the United States announced the end of 13 people.',
#    'town': '',
#    'location': 'Shabwah Province',
#    'deaths': '6',
#    'deaths_min': '6',
#    'deaths_max': '6',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '775717701381742592',
#    'bureau_id': 'YEM242',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM242',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '57d97656395e4f60f00bca52',
#    'number': 638,
#    'country': 'Yemen',
#    'date': '2016-09-13T00:00:00.000Z',
#    'narrative': "Missiles struck a car in Rada'a, killing 5 people.",
#    'town': "Rada'a",
#    'location': 'Al Bayda Province',
#    'deaths': '5',
#    'deaths_min': '5',
#    'deaths_max': '5',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '776087683659628544',
#    'bureau_id': 'YEM243',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM243',
#    'target': '',
#    'lat': '14.334986',
#    'lon': '44.930992',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58866b0d102b468c639e19a7',
#    'number': 639,
#    'country': 'Yemen',
#    'date': '2016-12-22T00:00:00.000Z',
#    'narrative': 'Nine new strikes. 28 people.',
#    'town': 'Multiple cities',
#    'location': 'Al Bayda, Marib, and Shabwah Province',
#    'deaths': '28',
#    'deaths_min': '28',
#    'deaths_max': '28',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '814878299990216705',
#    'bureau_id': 'YEM254',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM254',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58866b0d102b468c639e19a8',
#    'number': 640,
#    'country': 'Yemen',
#    'date': '2016-12-29T00:00:00.000Z',
#    'narrative': 'Jalal was driving through al-Baydah when a missile ended his life. 2 people killed.',
#    'town': 'Sawmaa',
#    'location': 'Al Bayda Province',
#    'deaths': '2',
#    'deaths_min': '2',
#    'deaths_max': '2',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '822481852355248130',
#    'bureau_id': 'YEM255',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2016/01/18/yemen-reported-us-covert-actions-2016/#YEM255',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58866b0d102b468c639e19a9',
#    'number': 641,
#    'country': 'Yemen',
#    'date': '2017-01-08T00:00:00.000Z',
#    'narrative': 'A Sunday drone strike, the last of the Obama years, killed one person "in a remote area."',
#    'town': '',
#    'location': 'Al Bayda Province',
#    'deaths': '1',
#    'deaths_min': '1',
#    'deaths_max': '1',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '822486894349058049',
#    'bureau_id': 'YEM256',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2017/01/13/yemen-reported-us-covert-actions-2017/#YEM256',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58866b0d102b468c639e19aa',
#    'number': 642,
#    'country': 'Yemen',
#    'date': '2017-01-21T00:00:00.000Z',
#    'narrative': "While the world was marching, Donald Trump's first drone strike killed 3 people in a car.",
#    'town': 'Sawmaa',
#    'location': 'Al Bayda Province',
#    'deaths': '3',
#    'deaths_min': '3',
#    'deaths_max': '3',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '823215682565341186',
#    'bureau_id': 'YEM257',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2017/01/13/yemen-reported-us-covert-actions-2017/#YEM257',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58b5e677102b468c639e19ab',
#    'number': 643,
#    'country': 'Yemen',
#    'date': '2017-01-29T00:00:00.000Z',
#    'narrative': "Carnage is the word. U.S. drones and commandos killed 30 people, including Dr. Awlaki's 8-year old granddaughter.",
#    'town': 'Yakla',
#    'location': 'Al Bayda Province',
#    'deaths': '39',
#    'deaths_min': '39',
#    'deaths_max': '39',
#    'civilians': '25',
#    'injuries': '7',
#    'children': '',
#    'tweet_id': '825749070761361410',
#    'bureau_id': 'YEM258',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2017/01/13/yemen-reported-us-covert-actions-2017/#YEM258',
#    'target': '',
#    'lat': '14.51287',
#    'lon': '44.922427',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58d15be4102b468c639e19ac',
#    'number': 644,
#    'country': 'Pakistan',
#    'date': '2017-03-02T00:00:00.000Z',
#    'narrative': 'Two men were riding a motorcycle. A drone missile came out of the sky.',
#    'town': 'Sra Ghundai',
#    'location': 'Kurram Agency',
#    'deaths': '2',
#    'deaths_min': '2',
#    'deaths_max': '2',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '837357382229504000',
#    'bureau_id': 'T001',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/drone-war/data/pakistan-covert-us-reported-actions-2017',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58d15be4102b468c639e19ad',
#    'number': 645,
#    'country': 'Yemen',
#    'date': '2017-03-02T00:00:00.000Z',
#    'narrative': "More than 20 air strikes--both drone and 'manned'--were launched in Abyan, Al Bayda and Shabwah.",
#    'town': 'Shaqra',
#    'location': 'Abyan, Al Bayda, and Shabwah Province',
#    'deaths': '2-12',
#    'deaths_min': '2',
#    'deaths_max': '12',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '837364497446756356',
#    'bureau_id': 'YEM260',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2017/01/13/yemen-reported-us-covert-actions-2017/#YEM259',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58d15be4102b468c639e19ae',
#    'number': 646,
#    'country': 'Yemen',
#    'date': '2017-03-02T00:00:00.000Z',
#    'narrative': 'Abdul saw it all. "The drone chased them." As the taxi drove past a farm, four people were swallowed by fire.',
#    'town': '',
#    'location': 'Abyan Province',
#    'deaths': '4',
#    'deaths_min': '4',
#    'deaths_max': '4',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '839249951410565120',
#    'bureau_id': 'YEM261',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2017/01/13/yemen-reported-us-covert-actions-2017/#YEM260',
#    'target': '',
#    'lat': '',
#    'lon': '',
#    'articles': [],
#    'names': ['']},
#   {'_id': '58d15be4102b468c639e19af',
#    'number': 647,
#    'country': 'Yemen',
#    'date': '2017-03-06T00:00:00.000Z',
#    'narrative': 'Two brothers--Ahmed and Mohammed--were walking down the road. A missile whistled in. They never made 15.',
#    'town': 'Yakla',
#    'location': 'Al Bayda Province',
#    'deaths': '2',
#    'deaths_min': '2',
#    'deaths_max': '2',
#    'civilians': '',
#    'injuries': '',
#    'children': '',
#    'tweet_id': '839262954130395138',
#    'bureau_id': 'YEM262',
#    'bij_summary_short': '',
#    'bij_link': 'https://www.thebureauinvestigates.com/2017/01/13/yemen-reported-us-covert-actions-2017/#YEM261',
#    'target': '',
#    'lat': '14.593117',
#    'lon': '45.040226',
#    'articles': [],
#    'names': ['']}]}

# %%
data["strike"]
data["strike"][0]
data["strike"][0]["deaths_min"]
data["strike"][5]["deaths_min"]
# Out:
# '8'

# %%
#Let s try a loop
lower_bound = 0

# Element is each strike, identified by the strike id. Let's see how to acess them. 
for element in data['strike']:
    print(element)
    print(type(element))
# Out:
# {'_id': '55c79e711cbee48856a30888', 'number': 3, 'country': 'Pakistan', 'date': '2005-05-08T00:00:00.000Z', 'narrative': "2 people killed in a Predator strike which reportedly targeted Haitham al-Yemeni's mobile phone.", 'town': 'Toorikhel', 'location': 'North Waziristan', 'deaths': '2', 'deaths_min': '2', 'deaths_max': '2', 'civilians': '', 'injuries': '', 'children': '', 'tweet_id': '278544812255367168', 'bureau_id': 'B2', 'bij_summary_short': 'Two killed, including Haitham al-Yemeni an al Qaeda explosives expert, near Mir Ali, North Waziristan.', 'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/', 'target': 'Haitham al-Yemeni', 'lat': '32.98677989', 'lon': '70.26082993', 'articles': [], 'names': ['Haitham al-Yemeni, Samiullah Khan']}
# <class 'dict'>
# {'_id': '55c79e721cbee48856a30889', 'number': 4, 'country': 'Pakistan', 'date': '2005-11-05T00:00:00.000Z', 'narrative': "A failed strike destroyed Abu Hamza Rabia's house and killed 8 people, including 3 young girls.", 'town': 'Mosaki', 'location': 'North Waziristan', 'deaths': '8', 'deaths_min': '8', 'deaths_max': '8', 'civilians': '3-8', 'injuries': '1', 'children': '3', 'tweet_id': '278544854483628032', 'bureau_id': 'B3', 'bij_summary_short': 'Failed strike against Abu Hamza Rabia ("al Qaeda\'s Number 3") kills eight including three children.', 'bij_link': 'http://www.thebureauinvestigates.com/2011/08/10/the-bush-years-2004-2009/', 'target': 'Abu Hamza Rabia', 'lat': '32.99988191', 'lon': '70.34082413', 'articles': [], 'names': ['']}
# <class 'dict'>

# %%
#Let s try a loop
lower_bound = 0

# Now that we know it is a dictionary (if we didnt before), we know how to extract stuff. 
# Element is each strike, identified by the strike id. For each element in the strike dictionary, get the death min data. 
# I want a number, so I define that I want the element as an integer
for element in data['strike']:
    # define what we want to extract and see if it works
    lower_bound = element['deaths_min']
    #print(lower_bound)
    # Then check what type it is because what I want is a number
    print(type(lower_bound))
    
    # Ok string is not so optimal. we want an integer
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# We need to convert the string into integer 
# Let s google a bit
# https://www.digitalocean.com/community/tutorials/how-to-convert-data-types-in-python-3
# have to use the int() transformation to transform string into integer

# %%
lower_bound = 0

for element in data["strike"]:
        lower_bound += int(element['deaths_min'])
        print(lower_bound)
        # maybe sth with the type
        print(type(lower_bound))

print("This is my result", lower_bound)
# Still doesnt work. Ok what next. Error messages built into your code helps a lot.
# Out:
# 6
# <class 'int'>
# 12
# <class 'int'>
# 14
# <class 'int'>
# 22
# <class 'int'>
# 27
# <class 'int'>
# 35
# <class 'int'>
# 48
# <class 'int'>
# 129
# <class 'int'>
# 137
# <class 'int'>
# 140
# <class 'int'>
# 160
# <class 'int'>
# 165
# <class 'int'>
# 165
# <class 'int'>
# 177
# <class 'int'>
# 185
# <class 'int'>
# 197
# <class 'int'>
# 209
# <class 'int'>
# 210
# <class 'int'>
# 216
# <class 'int'>
# 229
# <class 'int'>
# 237
# <class 'int'>
# 237
# <class 'int'>
# 241
# <class 'int'>
# 247
# <class 'int'>
# 251
# <class 'int'>
# 256
# <class 'int'>
# 261
# <class 'int'>
# 278
# <class 'int'>
# 288
# <class 'int'>
# 292
# <class 'int'>
# 296
# <class 'int'>
# 299
# <class 'int'>
# 320
# <class 'int'>
# 324
# <class 'int'>
# 328
# <class 'int'>
# 333
# <class 'int'>
# 340
# <class 'int'>
# 355
# <class 'int'>
# 359
# <class 'int'>
# 363
# <class 'int'>
# 374
# <class 'int'>
# 385
# <class 'int'>
# 389
# <class 'int'>
# 393
# <class 'int'>
# 398
# <class 'int'>
# 400
# <class 'int'>
# 403
# <class 'int'>
# 409
# <class 'int'>
# 411
# <class 'int'>
# 414
# <class 'int'>
# 416
# <class 'int'>
# 419
# <class 'int'>
# 422
# <class 'int'>
# 429
# <class 'int'>
# 434
# <class 'int'>
# 460
# <class 'int'>
# 490
# <class 'int'>
# 497
# <class 'int'>
# 511
# <class 'int'>
# 513
# <class 'int'>
# 520
# <class 'int'>
# 524
# <class 'int'>
# 536
# <class 'int'>
# 549
# <class 'int'>
# 553
# <class 'int'>
# 553
# <class 'int'>
# 559
# <class 'int'>
# 568
# <class 'int'>
# 576
# <class 'int'>
# 601
# <class 'int'>
# 604
# <class 'int'>
# 616
# <class 'int'>
# 616
# <class 'int'>
# 622
# <class 'int'>
# 689
# <class 'int'>
# 689
# <class 'int'>
# 702
# <class 'int'>
# 718
# <class 'int'>
# 726
# <class 'int'>
# 761
# <class 'int'>
# 764
# <class 'int'>
# 764
# <class 'int'>
# 769
# <class 'int'>
# 771
# <class 'int'>
# 785
# <class 'int'>
# 802
# <class 'int'>
# 810
# <class 'int'>
# 815
# <class 'int'>
# 825
# <class 'int'>
# 830
# <class 'int'>
# 840
# <class 'int'>
# 845
# <class 'int'>
# 849
# <class 'int'>
# 857
# <class 'int'>
# 860
# <class 'int'>
# 863
# <class 'int'>
# 883
# <class 'int'>
# 887
# <class 'int'>
# 890
# <class 'int'>
# 893
# <class 'int'>
# 897
# <class 'int'>
# 903
# <class 'int'>
# 905
# <class 'int'>
# 917
# <class 'int'>
# 922
# <class 'int'>
# 936
# <class 'int'>
# 939
# <class 'int'>
# 942
# <class 'int'>
# 947
# <class 'int'>
# 952
# <class 'int'>
# 957
# <class 'int'>
# 962
# <class 'int'>
# 966
# <class 'int'>
# 981
# <class 'int'>
# 986
# <class 'int'>
# 992
# <class 'int'>
# 1012
# <class 'int'>
# 1017
# <class 'int'>
# 1026
# <class 'int'>
# 1049
# <class 'int'>
# 1049
# <class 'int'>
# 1058
# <class 'int'>
# 1058
# <class 'int'>
# 1065
# <class 'int'>
# 1069
# <class 'int'>
# 1073
# <class 'int'>
# 1077
# <class 'int'>
# 1082
# <class 'int'>
# 1091
# <class 'int'>
# 1099
# <class 'int'>
# 1106
# <class 'int'>
# 1116
# <class 'int'>
# 1121
# <class 'int'>
# 1126
# <class 'int'>
# 1131
# <class 'int'>
# 1137
# <class 'int'>
# 1141
# <class 'int'>
# 1146
# <class 'int'>
# 1159
# <class 'int'>
# 1163
# <class 'int'>
# 1166
# <class 'int'>
# 1173
# <class 'int'>
# 1179
# <class 'int'>
# 1183
# <class 'int'>
# 1193
# <class 'int'>
# 1206
# <class 'int'>
# 1213
# <class 'int'>
# 1218
# <class 'int'>
# 1228
# <class 'int'>
# 1236
# <class 'int'>
# 1243
# <class 'int'>
# 1256
# <class 'int'>
# 1272
# <class 'int'>
# 1274
# <class 'int'>
# 1280
# <class 'int'>
# 1287
# <class 'int'>
# 1297
# <class 'int'>
# 1313
# <class 'int'>
# 1327
# <class 'int'>
# 1331
# <class 'int'>
# 1335
# <class 'int'>
# 1349
# <class 'int'>
# 1353
# <class 'int'>
# 1373
# <class 'int'>
# 1378
# <class 'int'>
# 1387
# <class 'int'>
# 1387
# <class 'int'>
# 1390
# <class 'int'>
# 1396
# <class 'int'>
# 1398
# <class 'int'>
# 1406
# <class 'int'>
# 1412
# <class 'int'>
# 1422
# <class 'int'>
# 1426
# <class 'int'>
# 1436
# <class 'int'>
# 1442
# <class 'int'>
# 1447
# <class 'int'>
# 1458
# <class 'int'>
# 1462
# <class 'int'>
# 1474
# <class 'int'>
# 1479
# <class 'int'>
# 1483
# <class 'int'>
# 1489
# <class 'int'>
# 1496
# <class 'int'>
# 1512
# <class 'int'>
# 1520
# <class 'int'>
# 1524
# <class 'int'>
# 1528
# <class 'int'>
# 1531
# <class 'int'>
# 1533
# <class 'int'>
# 1536
# <class 'int'>
# 1540
# <class 'int'>
# 1549
# <class 'int'>
# 1557
# <class 'int'>
# 1562
# <class 'int'>
# 1567
# <class 'int'>
# 1570
# <class 'int'>
# 1574
# <class 'int'>
# 1578
# <class 'int'>
# 1583
# <class 'int'>
# 1590
# <class 'int'>
# 1601
# <class 'int'>
# 1605
# <class 'int'>
# 1608
# <class 'int'>
# 1615
# <class 'int'>
# 1619
# <class 'int'>
# 1623
# <class 'int'>
# 1628
# <class 'int'>
# 1634
# <class 'int'>
# 1638
# <class 'int'>
# 1642
# <class 'int'>
# 1646
# <class 'int'>
# 1655
# <class 'int'>
# 1659
# <class 'int'>
# 1664
# <class 'int'>
# 1668
# <class 'int'>
# 1688
# <class 'int'>
# 1691
# <class 'int'>
# 1697
# <class 'int'>
# 1702
# <class 'int'>
# 1705
# <class 'int'>
# 1705
# <class 'int'>
# 1710
# <class 'int'>
# 1712
# <class 'int'>
# 1716
# <class 'int'>
# 1719
# <class 'int'>
# 1726
# <class 'int'>
# 1733
# <class 'int'>
# 1744
# <class 'int'>
# 1776
# <class 'int'>
# 1794
# <class 'int'>
# 1798
# <class 'int'>
# 1803
# <class 'int'>
# 1808
# <class 'int'>
# 1817
# <class 'int'>
# 1821
# <class 'int'>
# 1829
# <class 'int'>
# 1834
# <class 'int'>
# 1838
# <class 'int'>
# 1842
# <class 'int'>
# 1846
# <class 'int'>
# 1849
# <class 'int'>
# 1852
# <class 'int'>
# 1856
# <class 'int'>
# 1858
# <class 'int'>
# 1862
# <class 'int'>
# 1868
# <class 'int'>
# 1875
# <class 'int'>
# 1880
# <class 'int'>
# 1885
# <class 'int'>
# 1890
# <class 'int'>
# 1896
# <class 'int'>
# 1901
# <class 'int'>
# 1905
# <class 'int'>
# 1905
# <class 'int'>
# 1911
# <class 'int'>
# 1914
# <class 'int'>
# 1918
# <class 'int'>
# 1944
# <class 'int'>
# 1950
# <class 'int'>
# 1975
# <class 'int'>
# 1977
# <class 'int'>
# 1992
# <class 'int'>
# 1995
# <class 'int'>
# 2002
# <class 'int'>
# 2005
# <class 'int'>
# 2009
# <class 'int'>
# 2012
# <class 'int'>
# 2016
# <class 'int'>
# 2020
# <class 'int'>
# 2027
# <class 'int'>
# 2035
# <class 'int'>
# 2042
# <class 'int'>
# 2050
# <class 'int'>
# 2053
# <class 'int'>
# 2071
# <class 'int'>
# 2075
# <class 'int'>
# 2076
# <class 'int'>
# 2078
# <class 'int'>
# 2081
# <class 'int'>
# 2081
# <class 'int'>
# 2086
# <class 'int'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-9a4b2399bcc8> in <module>()
#       2
#       3 for element in data["strike"]:
# ----> 4         lower_bound += int(element['deaths_min'])
#       5         print(lower_bound)
#       6         # maybe sth with the type
#
# ValueError: invalid literal for int() with base 10: ''

# %%
lower_bound = 0

for element in data["strike"]:
    try:
        lower_bound += int(element['deaths_min'])
    except:
        print("error here:", element)
       

print("This is my result:", lower_bound)
# Out:
# error here: {'_id': '55c79e721cbee48856a309a0', 'number': 283, 'country': 'Yemen', 'date': '2011-06-18T00:00:00.000Z', 'narrative': 'At least 6 Yemeni civilians wounded by a US drone.', 'town': 'Jaar', 'location': 'Abyan Province', 'deaths': '0', 'deaths_min': '', 'deaths_max': '', 'civilians': '', 'injuries': '6', 'children': '', 'tweet_id': '299605330252398593', 'bureau_id': 'YEM015', 'bij_summary_short': "Six civilians were wounded in an apparent drone strike targeting 'senior jihadists'. However, no AQAP militants were reported to be hit in the attack.", 'bij_link': 'http://www.thebureauinvestigates.com/2012/03/29/yemen-reported-us-covert-actions-since-2001/', 'target': '', 'lat': '13.218055', 'lon': '45.307832', 'articles': [], 'names': ['']}
# error here: {'_id': '55c79e721cbee48856a309d4', 'number': 335, 'country': 'Yemen', 'date': '2011-11-08T00:00:00.000Z', 'narrative': "Five US drone strikes' killed an unknown number of people in Rumeila.", 'town': 'Rumeila', 'location': 'Abyan Province', 'deaths': 'Unknown', 'deaths_min': '?', 'deaths_max': '?', 'civilians': '', 'injuries': '', 'children': '', 'tweet_id': '309463189454716928', 'bureau_id': 'YEM038', 'bij_summary_short': "The militant stronghold of Rumeila was targeted by 'five US drone strikes,' killing an unknown number of people.\r", 'bij_link': 'http://www.thebureauinvestigates.com/2012/03/29/yemen-reported-us-covert-actions-since-2001/', 'target': '', 'lat': '13.612304', 'lon': '46.106282', 'articles': [], 'names': ['']}
# error here: {'_id': '55c79e721cbee48856a30a17', 'number': 402, 'country': 'Yemen', 'date': '2012-06-14T00:00:00.000Z', 'narrative': "A US drone strike hit the town of Azzan. 'Casualty figures were unknown'.", 'town': 'Azzan', 'location': 'Shabwah Province', 'deaths': 'Unknown', 'deaths_min': '?', 'deaths_max': '?', 'civilians': '', 'injuries': '', 'children': '', 'tweet_id': '337636403427028992', 'bureau_id': 'YEM097', 'bij_summary_short': "The Yemen Times reported a US drone strike hit Azzan in Shabwa province, described as AQAP's 'last stronghold' in the province.", 'bij_link': 'http://www.thebureauinvestigates.com/2012/05/08/yemen-reported-us-covert-action-2012/', 'target': '', 'lat': '14.33936309', 'lon': '47.44163168', 'articles': [], 'names': ['']}
# This is my result: 4012

# %%
# I can just code these as missing values by adding zero. 

lower_bound = 0

for element in data["strike"]:
    try:
        lower_bound += int(element['deaths_min'])
    except ValueError:
        lower_bound += 0

print(lower_bound)
# Out:
# 4012

# %% [markdown]
# # 3. Scraping Static Webpages with BeautifulSoup
#
# - If there is no API, we need to extract content by "brute force"
# - Scraping consists of two main components
#
# 1) Reproducing the content of a webpage: easy part
# 2) Extracting the part that we are intersted in: hard part
#
# Let's try with a simple practice example:
# http://pythonscraping.com/pages/page1.html

# %%
import requests
url = "http://pythonscraping.com/pages/page1.html"
html = requests.get(url) 
print(html)
# 200 is a status code which means it downloaded successfully. 4 or 5 usually mean there was an error.
# Out:
# <Response [200]>

# %%
html.text
# Out:
# '<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
# This doesnt look very pretty. 
# If you display a whole webpage like that and then find your info in there, it might get a bit annoying

# %% [markdown]
# ## Extracting Information: BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup as bs
html = requests.get("http://pythonscraping.com/pages/page1.html") 
soup = bs(html.text, "lxml")
# lxml is a parser used by bs. 
soup
# Out:
# <html>
# <head>
# <title>A Useful Page</title>
# </head>
# <body>
# <h1>An Interesting Title</h1>
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>
# </body>
# </html>

# %%
# Even nicer when you use prettify within bs, esp for a long page the indents help. 
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A Useful Page
#   </title>
#  </head>
#  <body>
#   <h1>
#    An Interesting Title
#   </h1>
#   <div>
#    Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
#   </div>
#  </body>
# </html>

# %% [markdown]
# ### The Components of a Webpage
#
# When you visit a web page, your web browser makes a request to a web server. This request is called a GET request, since we’re getting files from the server. The server then sends back files that tell our browser how to render the page for you. The files fall into a few main types:
#
# * HTML -- contain the main content of the page
# * CSS -- add styling to make the page look nicer
# * JS -- Javascript files add interactivity to web pages
# * Images -- image formats, such as JPG and PNG allow web pages to show pictures
#
#
# ### A Primer in HTML
#
# After your browser receives all the files, it renders the page and displays it to you. There’s a lot that happens behind the scenes to render a page nicely, but we don’t need to worry about most of it when we’re web scraping. When we perform web scraping, we’re interested in the main content of the web page, so we look at the HTML (HyperText Markup Language). Note that HTML is not a programming lanuage (like Python) but a markup language that tells a browser how to layout content. HTML allows you to do similar things to what you do in a word processor like Microsoft Word – make text bold, create paragraphs, and so on. Because HTML isn’t a programming language, it isn’t nearly as complex as Python.
#
# HTML consists of elements called tags. All HTML pages (at least all well-formatted ones) are surrounded by opening and cloing `<html> </html>` tags, with `<head>` and `<body>` tags in between. Other tags populate these page headers and page bodies to form the structure and content of the page.
#
# In the example above, the page title (this is the text that is seen in a tab in your browser) is "A Useful Page" and the first header "An Interesting Title" is contained in the `<h1>` tag. Immediately below that is a `div` ("divider") tag of the class "body", containing what might be a main article or longer piece of text.
#
# You may notice that the `head` and `body` tags are inside the `html` tag. In HTML, tags are nested, and can go inside other tags. Tags have commonly used names that depend on their position in relation to other tags:
#
# * `child` -- a child is a tag inside another tag. So the `div` tag above is a child of the `body` tag
# * `parent` – a parent is the tag another tag is inside. Above, the `html` tag is the parent of the `body` tag.
# * `sibiling` – a sibiling is a tag that is nested inside the same parent as another tag. For example, `head` and `body` are siblings, since they’re both inside `html`. `h1` and `div` are siblings, since they’re both inside `body`.
#
# The tags above are extremely common html tags. Here are a few others:
#
# * p -- creates a paragraph
# * a -- renders a link to another webpage; it often comes with the `href` property that determines where the link goes
# * table – creates a table
# * form – creates an input form
#
# You can find a full list of HTML tags [here](https://developer.mozilla.org/en-US/docs/Web/HTML/Element).
#
# Before we move into actual web scraping, let’s learn about the `class` and `id` properties. These special properties give HTML elements names, and make them easier to interact with when we’re scraping. One element can have multiple classes, and a class can be shared between elements. Each element can only have one id, and an id can only be used once on a page. Classes and ids are optional, and not all elements will have them. They do not change how the tags are rendered.

# %%
# How to extract infos from the above? Use the tags
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A Useful Page
#   </title>
#  </head>
#  <body>
#   <h1>
#    An Interesting Title
#   </h1>
#   <div>
#    Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
#   </div>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>A Useful Page</title>

# %%
soup.div
# Out:
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>

# %%
# If you just want the text: Output is a string. 
soup.div.text
# Out:
# '\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n'

# %%
# You can also access the tags by their family structure
# skip this

# %%
# Using the tags for scraping is very useful

# %% [markdown]
# ## Exercise: open the following webpage and display with bs
# https://www.pythonscraping.com/pages/warandpeace.html

# %%
import requests
from bs4 import BeautifulSoup as bs
url = "http://www.pythonscraping.com/pages/warandpeace.html"
html = requests.get(url) 
soup = bs(html.text, "lxml")
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <style>
#    .green{
# 	color:#55ff55;
# }
# .red{
# 	color:#ff5555;
# }
# #text{
# 	width:50%;
# }
#   </style>
#  </head>
#  <body>
#   <h1>
#    War and Peace
#   </h1>
#   <h2>
#    Chapter 1
#   </h2>
#   <div id="text">
#    "
#    <span class="red">
#     Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.
#    </span>
#    "
#    <p>
#    </p>
#    It was in July, 1805, and the speaker was the well-known
#    <span class="green">
#     Anna
# Pavlovna Scherer
#    </span>
#    , maid of honor and favorite of the
#    <span class="green">
#     Empress Marya
# Fedorovna
#    </span>
#    . With these words she greeted
#    <span class="green">
#     Prince Vasili Kuragin
#    </span>
#    , a man
# of high rank and importance, who was the first to arrive at her
# reception.
#    <span class="green">
#     Anna Pavlovna
#    </span>
#    had had a cough for some days. She was, as
# she said, suffering from la grippe; grippe being then a new word in
#    <span class="green">
#     St. Petersburg
#    </span>
#    , used only by the elite.
#    <p>
#    </p>
#    All her invitations without exception, written in French, and
# delivered by a scarlet-liveried footman that morning, ran as follows:
#    <p>
#    </p>
#    "
#    <span class="red">
#     If you have nothing better to do, Count [or Prince], and if the
# prospect of spending an evening with a poor invalid is not too
# terrible, I shall be very charmed to see you tonight between 7 and 10-
# Annette Scherer.
#    </span>
#    "
#    <p>
#    </p>
#    "
#    <span class="red">
#     Heavens! what a virulent attack!
#    </span>
#    " replied
#    <span class="green">
#     the prince
#    </span>
#    , not in the
# least disconcerted by this reception. He had just entered, wearing
# an embroidered court uniform, knee breeches, and shoes, and had
# stars on his breast and a serene expression on his flat face. He spoke
# in that refined French in which our grandfathers not only spoke but
# thought, and with the gentle, patronizing intonation natural to a
# man of importance who had grown old in society and at court. He went
# up to
#    <span class="green">
#     Anna Pavlovna
#    </span>
#    , kissed her hand, presenting to her his bald,
# scented, and shining head, and complacently seated himself on the
# sofa.
#    <p>
#    </p>
#    "
#    <span class="red">
#     First of all, dear friend, tell me how you are. Set your friend's
# mind at rest,
#    </span>
#    " said he without altering his tone, beneath the
# politeness and affected sympathy of which indifference and even
# irony could be discerned.
#    <p>
#    </p>
#    "
#    <span class="red">
#     Can one be well while suffering morally? Can one be calm in times
# like these if one has any feeling?
#    </span>
#    " said
#    <span class="green">
#     Anna Pavlovna
#    </span>
#    . "
#    <span class="red">
#     You are
# staying the whole evening, I hope?
#    </span>
#    "
#    <p>
#    </p>
#    "
#    <span class="red">
#     And the fete at the English ambassador's? Today is Wednesday. I
# must put in an appearance there,
#    </span>
#    " said
#    <span class="green">
#     the prince
#    </span>
#    . "
#    <span class="red">
#     My daughter is
# coming for me to take me there.
#    </span>
#    "
#    <p>
#    </p>
#    "
#    <span class="red">
#     I thought today's fete had been canceled. I confess all these
# festivities and fireworks are becoming wearisome.
#    </span>
#    "
#    <p>
#    </p>
#    "
#    <span class="red">
#     If they had known that you wished it, the entertainment would
# have been put off,
#    </span>
#    " said
#    <span class="green">
#     the prince
#    </span>
#    , who, like a wound-up clock, by
# force of habit said things he did not even wish to be believed.
#    <p>
#    </p>
#    "
#    <span class="red">
#     Don't tease! Well, and what has been decided about Novosiltsev's
# dispatch? You know everything.
#    </span>
#    "
#    <p>
#    </p>
#    "
#    <span class="red">
#     What can one say about it?
#    </span>
#    " replied
#    <span class="green">
#     the prince
#    </span>
#    in a cold,
# listless tone. "
#    <span class="red">
#     What has been decided? They have decided that
# Buonaparte has burnt his boats, and I believe that we are ready to
# burn ours.
#    </span>
#    "
#    <p>
#    </p>
#    <span class="green">
#     Prince Vasili
#    </span>
#    always spoke languidly, like an actor repeating a
# stale part.
#    <span class="green">
#     Anna Pavlovna
#    </span>
#    Scherer on the contrary, despite her forty
# years, overflowed with animation and impulsiveness. To be an
# enthusiast had become her social vocation and, sometimes even when she
# did not feel like it, she became enthusiastic in order not to
# disappoint the expectations of those who knew her. The subdued smile
# which, though it did not suit her faded features, always played
# round her lips expressed, as in a spoiled child, a continual
# consciousness of her charming defect, which she neither wished, nor
# could, nor considered it necessary, to correct.
#    <p>
#    </p>
#    In the midst of a conversation on political matters
#    <span class="green">
#     Anna Pavlovna
#    </span>
#    burst out:
#    <p>
#    </p>
#    "
#    <span class="red">
#     Oh, don't speak to me of Austria. Perhaps I don't understand
# things, but Austria never has wished, and does not wish, for war.
# She is betraying us! Russia alone must save Europe. Our gracious
# sovereign recognizes his high vocation and will be true to it. That is
# the one thing I have faith in! Our good and wonderful sovereign has to
# perform the noblest role on earth, and he is so virtuous and noble
# that God will not forsake him. He will fulfill his vocation and
# crush the hydra of revolution, which has become more terrible than
# ever in the person of this murderer and villain! We alone must
# avenge the blood of the just one.... Whom, I ask you, can we rely
# on?... England with her commercial spirit will not and cannot
# understand the Emperor Alexander's loftiness of soul. She has
# refused to evacuate Malta. She wanted to find, and still seeks, some
# secret motive in our actions. What answer did Novosiltsev get? None.
# The English have not understood and cannot understand the
# self-abnegation of our Emperor who wants nothing for himself, but only
# desires the good of mankind. And what have they promised? Nothing! And
# what little they have promised they will not perform! Prussia has
# always declared that Buonaparte is invincible, and that all Europe
# is powerless before him.... And I don't believe a word that Hardenburg
# says, or Haugwitz either. This famous Prussian neutrality is just a
# trap. I have faith only in God and the lofty destiny of our adored
# monarch. He will save Europe!
#    </span>
#    "
#    <p>
#    </p>
#    She suddenly paused, smiling at her own impetuosity.
#    <p>
#    </p>
#    "
#    <span class="red">
#     I think,
#    </span>
#    " said
#    <span class="green">
#     the prince
#    </span>
#    with a smile, "
#    <span class="red">
#     that if you had been
# sent instead of our dear
#     <span class="green">
#      Wintzingerode
#     </span>
#     you would have captured the
#     <span class="green">
#      King of Prussia
#     </span>
#     's consent by assault. You are so eloquent. Will you
# give me a cup of tea?
#    </span>
#    "
#    <p>
#    </p>
#    "
#    <span class="red">
#     In a moment. A propos,
#    </span>
#    " she added, becoming calm again, "
#    <span class="red">
#     I am
# expecting two very interesting men tonight,
#     <span class="green">
#      le Vicomte de Mortemart
#     </span>
#     ,
# who is connected with the
#     <span class="green">
#      Montmorencys
#     </span>
#     through the
#     <span class="green">
#      Rohans
#     </span>
#     , one of
# the best French families. He is one of the genuine emigres, the good
# ones. And also the
#     <span class="green">
#      Abbe Morio
#     </span>
#     . Do you know that profound thinker? He
# has been received by
#     <span class="green">
#      the Emperor
#     </span>
#     . Had you heard?
#    </span>
#    "
#    <p>
#    </p>
#    "
#    <span class="red">
#     I shall be delighted to meet them,
#    </span>
#    " said
#    <span class="green">
#     the prince
#    </span>
#    . "
#    <span class="red">
#     But tell me,
#    </span>
#    "
# he added with studied carelessness as if it had only just occurred
# to him, though the question he was about to ask was the chief motive
# of his visit, "
#    <span class="red">
#     is it true that the Dowager Empress wants Baron Funke
# to be appointed first secretary at Vienna? The baron by all accounts
# is a poor creature.
#    </span>
#    "
#    <p>
#    </p>
#    <span class="green">
#     Prince Vasili
#    </span>
#    wished to obtain this post for his son, but others
# were trying through the
#    <span class="green">
#     Dowager Empress Marya Fedorovna
#    </span>
#    to secure it
# for
#    <span class="green">
#     the baron
#    </span>
#    .
#    <p>
#    </p>
#    <span class="green">
#     Anna Pavlovna
#    </span>
#    almost closed her eyes to indicate that neither she
# nor anyone else had a right to criticize what
#    <span class="green">
#     the Empress
#    </span>
#    desired or
# was pleased with.
#    <p>
#    </p>
#    "
#    <span class="red">
#     Baron Funke has been recommended to the Dowager Empress by her
# sister,
#    </span>
#    " was all she said, in a dry and mournful tone.
#    <p>
#    </p>
#    As she named
#    <span class="green">
#     the Empress
#    </span>
#    ,
#    <span class="green">
#     Anna Pavlovna's
#    </span>
#    face suddenly assumed an
# expression of profound and sincere devotion and respect mingled with
# sadness, and this occurred every time she mentioned her illustrious
# patroness. She added that
#    <span class="green">
#     Her Majesty
#    </span>
#    had deigned to show
#    <span class="green">
#     Baron
# Funke
#    </span>
#    , and again her face clouded over with sadness.
#    <p>
#    </p>
#    <span class="green">
#     The prince
#    </span>
#    was silent and looked indifferent. But, with the
# womanly and courtierlike quickness and tact habitual to her,
#    <span class="green">
#     Anna
# Pavlovna
#    </span>
#    wished both to rebuke him (for daring to speak he had done of
# a man recommended to
#    <span class="green">
#     the Empress
#    </span>
#    ) and at the same time to console him,
# so she said:
#    <p>
#    </p>
#    "
#    <span class="red">
#     Now about your family. Do you know that since your daughter came
# out everyone has been enraptured by her? They say she is amazingly
# beautiful.
#    </span>
#    "
#    <p>
#    </p>
#    <span class="green">
#     The prince
#    </span>
#    bowed to signify his respect and gratitude.
#    <p>
#    </p>
#    "
#    <span class="red">
#     I often think,
#    </span>
#    " she continued after a short pause, drawing nearer
# to the prince and smiling amiably at him as if to show that
# political and social topics were ended and the time had come for
# intimate conversation- "
#    <span class="red">
#     I often think how unfairly sometimes the
# joys of life are distributed. Why has fate given you two such splendid
# children? I don't speak of
#     <span class="green">
#      Anatole
#     </span>
#     , your youngest. I don't like
# him,
#    </span>
#    " she added in a tone admitting of no rejoinder and raising her
# eyebrows. "
#    <span class="red">
#     Two such charming children. And really you appreciate
# them less than anyone, and so you don't deserve to have them.
#    </span>
#    "
#    <p>
#    </p>
#    And she smiled her ecstatic smile.
#    <p>
#    </p>
#    "
#    <span class="red">
#     I can't help it,
#    </span>
#    " said
#    <span class="green">
#     the prince
#    </span>
#    . "
#    <span class="red">
#     Lavater would have said I
# lack the bump of paternity.
#    </span>
#    "
#    <p>
#    </p>
#    "
#    <span class="red">
#     Don't joke; I mean to have a serious talk with you. Do you know I
# am dissatisfied with your younger son? Between ourselves
#    </span>
#    " (and her
# face assumed its melancholy expression), "
#    <span class="red">
#     he was mentioned at Her
# Majesty's and you were pitied....
#    </span>
#    "
#    <p>
#    </p>
#    <span class="green">
#     The prince
#    </span>
#    answered nothing, but she looked at him significantly,
# awaiting a reply. He frowned.
#    <p>
#    </p>
#    "
#    <span class="red">
#     What would you have me do?
#    </span>
#    " he said at last. "
#    <span class="red">
#     You know I did all
# a father could for their education, and they have both turned out
# fools. Hippolyte is at least a quiet fool, but Anatole is an active
# one. That is the only difference between them.
#    </span>
#    " He said this smiling
# in a way more natural and animated than usual, so that the wrinkles
# round his mouth very clearly revealed something unexpectedly coarse
# and unpleasant.
#    <p>
#    </p>
#    "
#    <span class="red">
#     And why are children born to such men as you? If you were not a
# father there would be nothing I could reproach you with,
#    </span>
#    " said
#    <span class="green">
#     Anna
# Pavlovna
#    </span>
#    , looking up pensively.
#    <p>
#    </p>
#    "
#    <span class="red">
#     I am your faithful slave and to you alone I can confess that my
# children are the bane of my life. It is the cross I have to bear. That
# is how I explain it to myself. It can't be helped!
#    </span>
#    "
#    <p>
#    </p>
#    He said no more, but expressed his resignation to cruel fate by a
# gesture.
#    <span class="green">
#     Anna Pavlovna
#    </span>
#    meditated.
#   </div>
#  </body>
# </html>

# %% [markdown]
# This website has a few CSS elemnts to control for font colour and text size. The following will return a list of all header tags in a document:

# %%
soup.find_all({"h1", "h2"})
# Out:
# [<h1>War and Peace</h1>, <h2>Chapter 1</h2>]

# %%
soup.find_all("span")
# Out:
# [<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
#  Buonapartes. But I warn you, if you don't tell me that this means war,
#  if you still try to defend the infamies and horrors perpetrated by
#  that Antichrist- I really believe he is Antichrist- I will have
#  nothing more to do with you and you are no longer my friend, no longer
#  my 'faithful slave,' as you call yourself! But how do you do? I see
#  I have frightened you- sit down and tell me all the news.</span>,
#  <span class="green">Anna
#  Pavlovna Scherer</span>,
#  <span class="green">Empress Marya
#  Fedorovna</span>,
#  <span class="green">Prince Vasili Kuragin</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="green">St. Petersburg</span>,
#  <span class="red">If you have nothing better to do, Count [or Prince], and if the
#  prospect of spending an evening with a poor invalid is not too
#  terrible, I shall be very charmed to see you tonight between 7 and 10-
#  Annette Scherer.</span>,
#  <span class="red">Heavens! what a virulent attack!</span>,
#  <span class="green">the prince</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="red">First of all, dear friend, tell me how you are. Set your friend's
#  mind at rest,</span>,
#  <span class="red">Can one be well while suffering morally? Can one be calm in times
#  like these if one has any feeling?</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="red">You are
#  staying the whole evening, I hope?</span>,
#  <span class="red">And the fete at the English ambassador's? Today is Wednesday. I
#  must put in an appearance there,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">My daughter is
#  coming for me to take me there.</span>,
#  <span class="red">I thought today's fete had been canceled. I confess all these
#  festivities and fireworks are becoming wearisome.</span>,
#  <span class="red">If they had known that you wished it, the entertainment would
#  have been put off,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">Don't tease! Well, and what has been decided about Novosiltsev's
#  dispatch? You know everything.</span>,
#  <span class="red">What can one say about it?</span>,
#  <span class="green">the prince</span>,
#  <span class="red">What has been decided? They have decided that
#  Buonaparte has burnt his boats, and I believe that we are ready to
#  burn ours.</span>,
#  <span class="green">Prince Vasili</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="red">Oh, don't speak to me of Austria. Perhaps I don't understand
#  things, but Austria never has wished, and does not wish, for war.
#  She is betraying us! Russia alone must save Europe. Our gracious
#  sovereign recognizes his high vocation and will be true to it. That is
#  the one thing I have faith in! Our good and wonderful sovereign has to
#  perform the noblest role on earth, and he is so virtuous and noble
#  that God will not forsake him. He will fulfill his vocation and
#  crush the hydra of revolution, which has become more terrible than
#  ever in the person of this murderer and villain! We alone must
#  avenge the blood of the just one.... Whom, I ask you, can we rely
#  on?... England with her commercial spirit will not and cannot
#  understand the Emperor Alexander's loftiness of soul. She has
#  refused to evacuate Malta. She wanted to find, and still seeks, some
#  secret motive in our actions. What answer did Novosiltsev get? None.
#  The English have not understood and cannot understand the
#  self-abnegation of our Emperor who wants nothing for himself, but only
#  desires the good of mankind. And what have they promised? Nothing! And
#  what little they have promised they will not perform! Prussia has
#  always declared that Buonaparte is invincible, and that all Europe
#  is powerless before him.... And I don't believe a word that Hardenburg
#  says, or Haugwitz either. This famous Prussian neutrality is just a
#  trap. I have faith only in God and the lofty destiny of our adored
#  monarch. He will save Europe!</span>,
#  <span class="red">I think,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">that if you had been
#  sent instead of our dear <span class="green">Wintzingerode</span> you would have captured the
#  <span class="green">King of Prussia</span>'s consent by assault. You are so eloquent. Will you
#  give me a cup of tea?</span>,
#  <span class="green">Wintzingerode</span>,
#  <span class="green">King of Prussia</span>,
#  <span class="red">In a moment. A propos,</span>,
#  <span class="red">I am
#  expecting two very interesting men tonight, <span class="green">le Vicomte de Mortemart</span>,
#  who is connected with the <span class="green">Montmorencys</span> through the <span class="green">Rohans</span>, one of
#  the best French families. He is one of the genuine emigres, the good
#  ones. And also the <span class="green">Abbe Morio</span>. Do you know that profound thinker? He
#  has been received by <span class="green">the Emperor</span>. Had you heard?</span>,
#  <span class="green">le Vicomte de Mortemart</span>,
#  <span class="green">Montmorencys</span>,
#  <span class="green">Rohans</span>,
#  <span class="green">Abbe Morio</span>,
#  <span class="green">the Emperor</span>,
#  <span class="red">I shall be delighted to meet them,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">But tell me,</span>,
#  <span class="red">is it true that the Dowager Empress wants Baron Funke
#  to be appointed first secretary at Vienna? The baron by all accounts
#  is a poor creature.</span>,
#  <span class="green">Prince Vasili</span>,
#  <span class="green">Dowager Empress Marya Fedorovna</span>,
#  <span class="green">the baron</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="green">the Empress</span>,
#  <span class="red">Baron Funke has been recommended to the Dowager Empress by her
#  sister,</span>,
#  <span class="green">the Empress</span>,
#  <span class="green">Anna Pavlovna's</span>,
#  <span class="green">Her Majesty</span>,
#  <span class="green">Baron
#  Funke</span>,
#  <span class="green">The prince</span>,
#  <span class="green">Anna
#  Pavlovna</span>,
#  <span class="green">the Empress</span>,
#  <span class="red">Now about your family. Do you know that since your daughter came
#  out everyone has been enraptured by her? They say she is amazingly
#  beautiful.</span>,
#  <span class="green">The prince</span>,
#  <span class="red">I often think,</span>,
#  <span class="red">I often think how unfairly sometimes the
#  joys of life are distributed. Why has fate given you two such splendid
#  children? I don't speak of <span class="green">Anatole</span>, your youngest. I don't like
#  him,</span>,
#  <span class="green">Anatole</span>,
#  <span class="red">Two such charming children. And really you appreciate
#  them less than anyone, and so you don't deserve to have them.</span>,
#  <span class="red">I can't help it,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">Lavater would have said I
#  lack the bump of paternity.</span>,
#  <span class="red">Don't joke; I mean to have a serious talk with you. Do you know I
#  am dissatisfied with your younger son? Between ourselves</span>,
#  <span class="red">he was mentioned at Her
#  Majesty's and you were pitied....</span>,
#  <span class="green">The prince</span>,
#  <span class="red">What would you have me do?</span>,
#  <span class="red">You know I did all
#  a father could for their education, and they have both turned out
#  fools. Hippolyte is at least a quiet fool, but Anatole is an active
#  one. That is the only difference between them.</span>,
#  <span class="red">And why are children born to such men as you? If you were not a
#  father there would be nothing I could reproach you with,</span>,
#  <span class="green">Anna
#  Pavlovna</span>,
#  <span class="red">I am your faithful slave and to you alone I can confess that my
#  children are the bane of my life. It is the cross I have to bear. That
#  is how I explain it to myself. It can't be helped!</span>,
#  <span class="green">Anna Pavlovna</span>]

# %%
greens = soup.find_all("span", {"class":"green"})

# %%
greens[0]
# Out:
# <span class="green">Anna
# Pavlovna Scherer</span>

# %% [markdown]
# ### Example: Salaries of All Employees at Tennessee Public Schools

# %%
import requests
from bs4 import BeautifulSoup as bs
url = "https://www.tbr.edu/hr/salaries"
html = requests.get(url) 
soup = bs(html.text, "lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="ie6 ie" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 7]>    <html class="ie7 ie" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 8]>    <html class="ie8 ie" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9 ie" lang="en" dir="ltr"> <![endif]-->
# <!--[if !IE]> -->
# <html dir="ltr" lang="en">
#  <!-- <![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.tbr.edu/profiles/tbr_hosting/themes/tbr_bootstrap_new/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <meta content="Drupal 7 (http://drupal.org)" name="generator"/>
#   <link href="https://www.tbr.edu/hr/salaries" rel="canonical"/>
#   <link href="https://www.tbr.edu/hr/salaries" rel="shortlink"/>
#   <meta content="Tennessee Board of Regents" property="og:site_name"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://www.tbr.edu/hr/salaries" property="og:url"/>
#   <meta content="Salary Database" property="og:title"/>
#   <!-- Set the viewport width to device width for mobile -->
#   <meta content="width=device-width,minimum-scale=1.0,maximum-scale=10.0,initial-scale=1.0" id="viewport" name="viewport"/>
#   <meta content="private" http-equiv="Cache-control"/>
#   <title>
#    Salary Database | Tennessee Board of Regents
#   </title>
#   <link href="//fonts.googleapis.com/css?family=Source+Sans+Pro:200,300,400,600,700,900,200italic,300italic,400italic,600italic,700italic,900italic" rel="stylesheet" type="text/css"/>
#   <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300&amp;subset=latin,greek,cyrillic,vietnamese" rel="stylesheet" type="text/css"/>
#   <link href="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/icons/touch/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/icons/touch/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/icons/touch/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/icons/touch/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/icons/touch/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="https://www.tbr.edu/sites/tbr.edu/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet"/>
#   <link href="https://www.tbr.edu/sites/tbr.edu/files/css/css_soR1i-0wfp61Paf2yvT30wFaEMGwAHM1FcOBoYSH98M.css" media="all" rel="stylesheet"/>
#   <link href="https://www.tbr.edu/sites/tbr.edu/files/css/css_oLNZ0YgFE144RN7uV20xaJVz72RUu3nb3RpcYSRIBso.css" media="all" rel="stylesheet"/>
#   <link href="https://www.tbr.edu/sites/tbr.edu/files/css/css_WF88EEGULEtHwt6EKZu0QlYq7O6TOywwf4SbVNC61vQ.css" media="all" rel="stylesheet"/>
#   <link href="https://www.tbr.edu/sites/tbr.edu/files/css/css_hcQgRbGQ8FP1DhOXWzZkL3eKQuepVt3SHhkonvjaJYc.css" media="print" rel="stylesheet"/>
#   <link href="https://www.tbr.edu/sites/tbr.edu/files/css/css_maQxBb4o5n0K4eh_yWIvs-Yb9mwaqzuwomI2Qj2Bslo.css" media="all" rel="stylesheet"/>
#   <style>
#    #header-unit .container #header-unit-inner {
# 	  		  background: #fff url("/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/headers/hr.jpg");
# 		   }
#   </style>
#   <script src="https://www.tbr.edu/sites/tbr.edu/files/js/js_ao3FWjhLM8zBNxaFRfvii7Rb1as8WJo8JLul-6zP1IE.js">
#   </script>
#   <script src="https://www.tbr.edu/profiles/tbr_hosting/libraries/respondjs/respond.min.js?pe43sl">
#   </script>
#   <script src="https://www.tbr.edu/sites/tbr.edu/files/js/js_x0MhBQfHNAIO1NwkQgzf_TGN4b8eMmKre3nqUfoQv3w.js">
#   </script>
#   <script src="https://www.tbr.edu/sites/tbr.edu/files/js/js_f_6-OzlFXjayKlsU5sJKLwjz7LFQvdIZDm-Mt6jKwyM.js">
#   </script>
#   <script src="https://www.tbr.edu/sites/tbr.edu/files/js/js_4tjjgBC25iqW12Rfxk7Gi_5Kgj4GNqqM0uBTvAS6EXU.js">
#   </script>
#   <script>
#    window.CKEDITOR_BASEPATH = '/profiles/tbr_hosting/libraries/ckeditor/'
#   </script>
#   <script src="https://www.tbr.edu/sites/tbr.edu/files/js/js_GCOdTWJZ56TKPVEjQ5ytUuFzOsczGyA8LfJci0n-wVM.js">
#   </script>
#   <script>
#    jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"tbr_bootstrap_new","theme_token":"iwr5P7K6RDqfVzB-T8_ZcxBlLxRXNIMoliEQROknwdg","js":{"public:\/\/google_tag\/google_tag.script.js":1,"profiles\/tbr_hosting\/libraries\/respondjs\/respond.min.js":1,"profiles\/tbr_hosting\/modules\/jquery_update\/replace\/jquery\/1.8\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"profiles\/tbr_hosting\/modules\/google_cse\/google_cse.js":1,"profiles\/tbr_hosting\/libraries\/colorbox\/jquery.colorbox-min.js":1,"profiles\/tbr_hosting\/modules\/colorbox\/js\/colorbox.js":1,"profiles\/tbr_hosting\/modules\/colorbox\/styles\/default\/colorbox_style.js":1,"profiles\/tbr_hosting\/modules\/colorbox\/js\/colorbox_load.js":1,"profiles\/tbr_hosting\/modules\/colorbox\/js\/colorbox_inline.js":1,"profiles\/tbr_hosting\/modules\/better_exposed_filters\/better_exposed_filters.js":1,"misc\/tableheader.js":1,"0":1,"profiles\/tbr_hosting\/themes\/open_framework\/bootstrap\/js\/bootstrap.min.js":1,"profiles\/tbr_hosting\/themes\/open_framework\/js\/open_framework.js":1,"profiles\/tbr_hosting\/themes\/open_framework\/js\/override.js":1,"profiles\/tbr_hosting\/themes\/tbr_bootstrap_new\/js\/breakpoints.js":1,"profiles\/tbr_hosting\/themes\/tbr_bootstrap_new\/js\/script.js":1,"profiles\/tbr_hosting\/themes\/tbr_bootstrap_new\/js\/jquery.doubleScroll.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"profiles\/tbr_hosting\/modules\/ldap\/ldap_user\/ldap_user.css":1,"modules\/aggregator\/aggregator.css":1,"profiles\/tbr_hosting\/modules\/calendar\/css\/calendar_multiday.css":1,"profiles\/tbr_hosting\/modules\/date\/date_api\/date.css":1,"profiles\/tbr_hosting\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"profiles\/tbr_hosting\/modules\/google_cse\/google_cse.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"profiles\/tbr_hosting\/modules\/youtube\/css\/youtube.css":1,"profiles\/tbr_hosting\/modules\/views\/css\/views.css":1,"profiles\/tbr_hosting\/modules\/colorbox\/styles\/default\/colorbox_style.css":1,"profiles\/tbr_hosting\/modules\/ctools\/css\/ctools.css":1,"profiles\/tbr_hosting\/modules\/facebook_pull\/facebook_pull.css":1,"profiles\/tbr_hosting\/modules\/ldap\/ldap_servers\/ldap_servers.admin.css":1,"profiles\/tbr_hosting\/modules\/panels\/css\/panels.css":1,"profiles\/tbr_hosting\/modules\/path_breadcrumbs\/css\/path_breadcrumbs.css":1,"profiles\/tbr_hosting\/themes\/open_framework\/bootstrap\/css\/bootstrap.min.css":1,"profiles\/tbr_hosting\/themes\/open_framework\/bootstrap\/css\/bootstrap-responsive.min.css":1,"profiles\/tbr_hosting\/themes\/open_framework\/fontawesome\/css\/font-awesome.min.css":1,"profiles\/tbr_hosting\/themes\/open_framework\/css\/open_framework.css":1,"profiles\/tbr_hosting\/themes\/open_framework\/css\/ie.css":1,"profiles\/tbr_hosting\/themes\/tbr_bootstrap_new\/css\/style.css":1,"profiles\/tbr_hosting\/themes\/tbr_bootstrap_new\/css\/font-awesome.min.css":1,"profiles\/tbr_hosting\/themes\/open_framework\/css\/open_framework_print.css":1,"profiles\/tbr_hosting\/themes\/tbr_bootstrap_new\/dist\/css\/print.css":1,"profiles\/tbr_hosting\/themes\/tbr_bootstrap_new\/css\/host-www.css":1}},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":true,"mobiledevicewidth":"480px"},"googleCSE":{"cx":"000855052858091299634:vdn1pvbv97k","language":"","resultsWidth":200,"domain":"www.google.com","showWaterMark":0},"better_exposed_filters":{"datepicker":false,"slider":false,"settings":[],"autosubmit":false,"views":{"tbr_salary_data":{"displays":{"page":{"filters":{"firstname":{"required":false},"lastname":{"required":false},"department":{"required":fal ...
#   </script>
#   <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-53ea780006145c89" type="text/javascript">
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:900|Open+Sans" rel="stylesheet"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/bulma/0.6.1/css/bulma.min.css" rel="stylesheet"/>
#   <link href="/profiles/tbr_hosting/themes/tbr_bootstrap_new/dist/css/main.css" rel="stylesheet"/>
#  </head>
#  <body class="html not-front not-logged-in no-sidebars page-hr page-hr-salaries www ">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NBTW67K" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="element-invisible" id="skipnav">
#    <div class="container">
#     <p>
#      Skip to:
#     </p>
#     <ul>
#      <li>
#       <a class="element-invisible element-focusable" href="#content">
#        Skip to content
#       </a>
#      </li>
#      <li>
#       <a class="element-invisible element-focusable" href="#main-menu">
#        Skip to navigation
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <!-- /#skipnav -->
#   <div class="searchbar">
#    <form action="/search/google/" method="get">
#     <fieldset>
#      <div class="searchbar__left is-hidden-touch">
#       <input class="radiosearch" id="search-site-section" name="sitesearch" type="radio" value="site:policies.tbr.edu"/>
#       <label class="search-area" for="search-site-section">
#        Policies &amp; Guidelines
#       </label>
#       <input checked="yes" class="radiosearch" id="search-all-tbr" name="sitesearch" type="radio" value=""/>
#       <label class="search-area" for="search-all-tbr">
#        All of TBR.edu
#       </label>
#      </div>
#      <div class="searchbar__right">
#       <legend>
#        TBR Search Form
#       </legend>
#       <input id="q" name="q" placeholder="Enter your search terms here" type="search"/>
#       <button id="do-site-search">
#       </button>
#      </div>
#     </fieldset>
#    </form>
#    <a class="close-search">
#     X
#    </a>
#   </div>
#   <!-- /#emergency-header -->
#   <div class="clearfix block block-block" id="block-block-headermenu">
#    <div class="content">
#     <div aria-label="main navigation" class="main-menu sticky" role="navigation">
#      <nav class="navbar">
#       <div class="navbar-brand">
#        <div class="navbar-burger">
#         <span>
#         </span>
#         <span>
#         </span>
#         <span>
#         </span>
#        </div>
#       </div>
#       <section aria-hidden="false" id="isMobile">
#        <div class="navbar-menu">
#         <div class="navbar-item has-dropdown is-hidden-desktop startMobile">
#          <a class="navbar-link">
#           Get Started
#          </a>
#          <div class="navbar-dropdown">
#           <a class="navbar-item" href="/node/30686">
#            Future Students
#           </a>
#           <a class="navbar-item" href="/node/30685">
#            Adult Learners
#           </a>
#           <a class="navbar-item" href="/node/30674">
#            Online Learners
#           </a>
#           <a class="navbar-item" href="/node/30687">
#            Military &amp; Veterans
#           </a>
#           <a class="navbar-item" href="/node/31167">
#            K - 12 Initiatives
#           </a>
#           <a class="navbar-item" href="/node/30684">
#            Business &amp; Industry
#           </a>
#           <a class="navbar-item" href="/node/30681">
#            Data and Research
#           </a>
#           <a class="navbar-item" href="/node/30688">
#            Job Seekers
#           </a>
#           <a class="navbar-item" href="https://policies.tbr.edu">
#            Policies &amp; Guidelines
#           </a>
#           <a class="navbar-item" href="/purchasing/how-do-business-tbr">
#            How to Do Business with the TBR
#           </a>
#           <a class="navbar-item" href="/node/30689">
#            Faculty &amp; Staff
#           </a>
#          </div>
#         </div>
#         <a class="navbar-item" href="https://www.tbr.edu/institutions/our-institutions">
#          Our Colleges
#         </a>
#         <div class="dropup navbar-item has-dropdown has-dropdown-up is-hoverable">
#          <a class="navbar-link">
#           Offices
#          </a>
#          <div class="navbar-dropdown">
#           <div class="columns is-desktop">
#            <div class="column">
#             <a class="navbar-item" href="https://www.tbr.edu/board/tennessee-board-regents">
#              Board of Regents
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/chancellor/office-chancellor">
#              Chancellor
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/academics/office-academic-affairs">
#              Academic Affairs
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/administration/office-administration-and-facilities-development">
#              Administration and Facilities Development
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/business/office-business-and-finance">
#              Business and Finance
#             </a>
#            </div>
#            <div class="column">
#             <a class="navbar-item" href="https://www.tbr.edu/ecd/office-economic-and-community-development">
#              Economic and Community Development
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/external-affairs/office-external-affairs">
#              External Affairs
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/generalcounsel/office-general-counsel">
#              General Counsel
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/it/office-information-technology">
#              Information Technology
#             </a>
#            </div>
#            <div class="column">
#             <a class="navbar-item" href="https://www.tbr.edu/oesi/office-organizational-effectiveness">
#              Organizational Effectiveness
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/policy-strategy/office-policy-and-strategy">
#              Policy and Strategy
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/student-success/office-student-success">
#              Student Success
#             </a>
#             <a class="navbar-item" href="https://www.tbr.edu/audit/office-system-wide-internal-audit">
#              System-wide Internal Audit
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#         <!-- REMOVED RESOURCES MENU
#                 <div class="dropup navbar-item has-dropdown has-dropdown-up is-hoverable">
#                     <a class="navbar-link">Resources</a>
#                     <div class="navbar-dropdown">
#                         <div class="columns is-desktop">
#                             <div class="column">
#                                 <a href="https://policies.tbr.edu" class="navbar-item">Policies & Guidelines</a>
#                                 <a href="https://www.tbr.edu/hr/employment-opportunities" class="navbar-item">Employment Opportunities</a>
#                                 <a href="https://www.tbr.edu/hr/employee-benefits" class="navbar-item">Employee Benefits</a>
#                                 <a href="https://www.tbr.edu/academics/research-and-assessment" class="navbar-item">Data and Research</a>
#                                 <a href="https://www.tbr.edu/purchasing/how-do-business-tbr" class="navbar-item">Vendors / Contracts</a>
#                             </div>
#                             <div class="column">
#                                 <a href="https://www.tbr.edu/facilities/doing-business-tbr-facilities" class="navbar-item">Facilities Bid Opportunities</a>
#                                 <a href="https://www.tbr.edu/institutions" class="navbar-item">Our Institutions</a>
#                                 <a href="https://www.tbr.edu/institutions/getting-started" class="navbar-item">Getting Started as a Student at a TBR Institution</a>
#                                 <a href="https://www.tbr.edu/academics/programs" class="navbar-item">Academic Programs at Our Institutions</a>
#                                 <a href="https://www.tbr.edu/initiatives/online-learning-tn-ecampus" class="navbar-item">Online Learning / TN eCampus</a>
#                             </div>
#                             <div class="column">
#                                 <a href="https://www.tbr.edu/business/tuition-and-fees" class="navbar-item">Tuition and Fees</a>
#                                 <a href="https://www.tbr.edu/communications" class="navbar-item">Communications & Marketing</a>
#                                 <a href="https://www.tbr.edu/sharedservices" class="navbar-item">Shared Services Initiative</a>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#                 -->
#         <a class="navbar-item" href="https://www.tbr.edu/communications/news">
#          News &amp; Events
#         </a>
#         <a class="navbar-item" href="https://www.tbr.edu/board">
#          About
#         </a>
#         <a class="navbar-item" href="https://www.tbr.edu/contacts/contact-tbr">
#          Contact
#         </a>
#         <div class="searchbar is-hidden-desktop sbmobile" id="sbmobile">
#          <form action="/search/google/" method="get">
#           <fieldset>
#            <div class="searchbar__left is-hidden-touch">
#             <input class="radiosearch" id="search-site-section" name="sitesearch" type="radio" value="site:policies.tbr.edu"/>
#             <label class="search-area" for="search-site-section">
#              Policies &amp; Guidelines
#             </label>
#             <input checked="yes" class="radiosearch" id="search-all-tbr" name="sitesearch" type="radio" value=""/>
#             <label class="search-area" for="search-all-tbr">
#              All of TBR.edu
#             </label>
#            </div>
#            <div class="searchbar__right ">
#             <input id="q" name="q" placeholder="Enter your search terms here" type="search"/>
#             <button id="do-site-search">
#             </button>
#            </div>
#           </fieldset>
#          </form>
#         </div>
#         <a class="navbar-item is-hidden-touch" id="showSearch">
#          <svg height="32" version="1.1" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#           <title>
#            search
#           </title>
#           <g id="Canvas" transform="translate(8559 -2968)">
#            <clippath clip-rule="evenodd" id="clip-0">
#             <path d="M -8559 2968L -8527 2968L -8527 3000L -8559 3000L -8559 2968Z" fill="#FFFFFF" id="searchicon">
#             </path>
#            </clippath>
#            <g clip-path="url(#clip-0)" id="search">
#             <g id="Search">
#              <use fill="#FFFFFF" id="searchicon" transform="translate(-8559 2968)" xlink:href="#path0_fill">
#              </use>
#             </g>
#            </g>
#           </g>
#           <defs>
#            <path d="M 13.2739 0.000273157C 5.97239 0.000273157 1.13133e-07 5.959 1.13133e-07 13.2601C 1.13133e-07 20.56 5.97395 26.534 13.2739 26.534C 16.0801 26.534 18.6804 25.6346 20.8239 24.1423L 28.0006 31.3049C 28.9136 32.2317 30.406 32.2317 31.319 31.3049C 32.232 30.3919 32.232 28.9133 31.319 28.0002L 24.1408 20.8236C 25.6484 18.6667 26.5325 16.0675 26.5325 13.2598C 26.5325 5.9599 20.5585 1.19087e-09 13.2726 1.19087e-09L 13.2739 0.000273157ZM 13.2739 4.67399C 18.0299 4.67399 21.8467 8.49086 21.8467 13.2605C 21.8467 18.0302 18.0299 21.847 13.2739 21.847C 8.50417 21.847 4.68738 18.0301 4.68738 13.2605C 4.68738 8.49078 8.50424 4.67399 13.2739 4.67399L 13.2739 4.67399Z" id="path0_fill">
#            </path>
#           </defs>
#          </svg>
#         </a>
#        </div>
#       </section>
#      </nav>
#     </div>
#     <div class="secondary-menu is-hidden-touch">
#      <nav aria-label="secondary navigation" class="navbar" role="navigation">
#       <div class="navbar menu">
#        <div class="navbar-end">
#         <!-- <a href="/academics/programs" class="navbar-item">Find A Program</a> -->
#         <a class="navbar-item" href="/node/17609">
#          Apply
#         </a>
#         <a class="navbar-item" href="/node/30682">
#          Make a Gift
#         </a>
#         <div class="navbar-item has-dropdown is-hoverable">
#          <a class="navbar-link">
#           Get Started
#          </a>
#          <div class="navbar-dropdown is-right">
#           <a class="navbar-item" href="/student-success/future-students">
#            Future Students
#           </a>
#           <a class="navbar-item" href="/student-success/adult-learners">
#            Adult Learners
#           </a>
#           <a class="navbar-item" href="/student-success/online-learners">
#            Online Learners
#           </a>
#           <a class="navbar-item" href="/student-success/military-veterans">
#            Military &amp; Veterans
#           </a>
#           <a class="navbar-item" href="/initiatives/sails">
#            K - 12 Initiatives
#           </a>
#           <a class="navbar-item" href="/ecd/business-industry">
#            Business &amp; Industry
#           </a>
#           <a class="navbar-item" href="/policy-strategy/data-and-research">
#            Data and Research
#           </a>
#           <a class="navbar-item" href="/hr/job-seekers">
#            Job Seekers
#           </a>
#           <a class="navbar-item" href="https://policies.tbr.edu">
#            Policies &amp; Guidelines
#           </a>
#           <a class="navbar-item" href="/purchasing/how-do-business-tbr">
#            Vendors / Contracts
#           </a>
#           <a class="navbar-item" href="/hr/faculty-staff">
#            Faculty &amp; Staff
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <div class="secondary is-hidden-touch">
#      <nav aria-label="Get Started Button" class="navbar" role="navigation">
#       <div class="navbar menu">
#        <div class="navbar-end">
#         <div class="start-btn special navbar-item has-dropdown is-hoverable">
#          <a class="navbar-link ">
#           Get Started
#          </a>
#          <div class="navbar-dropdown is-right">
#           <a class="navbar-item" href="/student-success/future-students">
#            Future Students
#           </a>
#           <a class="navbar-item" href="/student-success/adult-learners">
#            Adult Learners
#           </a>
#           <a class="navbar-item" href="/student-success/online-learners">
#            Online Learners
#           </a>
#           <a class="navbar-item" href="/student-success/military-veterans">
#            Military &amp; Veterans
#           </a>
#           <a class="navbar-item" href="/initiatives/sails">
#            K - 12 Initiatives
#           </a>
#           <a class="navbar-item" href="/ecd/business-industry">
#            Business &amp; Industry
#           </a>
#           <a class="navbar-item" href="/policy-strategy/data-and-research">
#            Data and Research
#           </a>
#           <a class="navbar-item" href="/hr/job-seekers">
#            Job Seekers
#           </a>
#           <a class="navbar-item" href="https://policies.tbr.edu">
#            Policies &amp; Guidelines
#           </a>
#           <a class="navbar-item" href="/purchasing/how-do-business-tbr">
#            Vendors / Contracts
#           </a>
#           <a class="navbar-item" href="/hr/faculty-staff">
#            Faculty &amp; Staff
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <style>
#      #main-menu
#     </style>
#    </div>
#   </div>
#   <div class="hero__logo">
#    <a href="/">
#     <img alt="The College System of Tennessee Logo" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/logos/cstn-logo.svg"/>
#    </a>
#   </div>
#   <!--/#header-unit -->
#   <div class="clearfix" id="main">
#    <div class="container">
#     <div id="breadcrumb">
#      <h2 class="element-invisible">
#       You are here
#      </h2>
#      <div class="breadcrumb">
#       <div class="inline odd first" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a href="https://www.tbr.edu/" itemprop="url">
#         <span itemprop="title">
#          Home
#         </span>
#        </a>
#       </div>
#       <span class="delimiter">
#        /
#       </span>
#       <div class="inline even" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a href="https://www.tbr.edu/hr/department-human-resources-and-payroll-services" itemprop="url">
#         <span itemprop="title">
#          Office of Business and Finance
#         </span>
#        </a>
#       </div>
#       <span class="delimiter">
#        /
#       </span>
#       <div class="inline odd last" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a href="https://www.tbr.edu/hr/department-human-resources-and-payroll-services" itemprop="url">
#         <span itemprop="title">
#          Human Resources
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="columns is-desktop" id="main-content">
#      <div class="column is-12-desktop" id="content">
#       <div id="content-wrapper">
#        <div class="row-fluid" id="content-head">
#         <div class="clearfix" id="highlighted">
#         </div>
#         <h1 class="title" id="page-title">
#          Salary Database
#         </h1>
#         <div class="tabs">
#         </div>
#        </div>
#        <div class="row-fluid" id="content-body">
#         <div class="region region-content clearfix">
#          <div class="clearfix block block-system" id="block-system-main">
#           <div class="content">
#            <div class="view view-tbr-salary-data view-id-tbr_salary_data view-display-id-page view-dom-id-d2282194b311f2a2a1db0553d03e730a">
#             <div class="view-header">
#              <p>
#               Salaries listed are base salary and are exclusive of longevity, stipends, and additional salary for temporary or additional duties.
#              </p>
#             </div>
#             <div class="view-filters">
#              <form accept-charset="UTF-8" action="/hr/salaries" id="views-exposed-form-tbr-salary-data-page" method="get">
#               <div>
#                <div class="views-exposed-form">
#                 <div class="views-exposed-widgets clearfix">
#                  <div class="views-exposed-widget views-widget-filter-firstname" id="edit-firstname-wrapper">
#                   <label for="edit-firstname">
#                    First Name
#                   </label>
#                   <div class="views-widget">
#                    <div class="form-item form-type-textfield form-item-firstname">
#                     <input class="form-text" id="edit-firstname" maxlength="128" name="firstname" size="30" type="text" value=""/>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="views-exposed-widget views-widget-filter-lastname" id="edit-lastname-wrapper">
#                   <label for="edit-lastname">
#                    Last Name
#                   </label>
#                   <div class="views-widget">
#                    <div class="form-item form-type-textfield form-item-lastname">
#                     <input class="form-text" id="edit-lastname" maxlength="128" name="lastname" size="30" type="text" value=""/>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="views-exposed-widget views-widget-filter-department" id="edit-department-wrapper">
#                   <label for="edit-department">
#                    Department
#                   </label>
#                   <div class="views-widget">
#                    <div class="form-item form-type-textfield form-item-department">
#                     <input class="form-text" id="edit-department" maxlength="128" name="department" size="30" type="text" value=""/>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="views-exposed-widget views-widget-filter-jobtitle" id="edit-jobtitle-wrapper">
#                   <label for="edit-jobtitle">
#                    Job Title
#                   </label>
#                   <div class="views-widget">
#                    <div class="form-item form-type-textfield form-item-jobtitle">
#                     <input class="form-text" id="edit-jobtitle" maxlength="128" name="jobtitle" size="30" type="text" value=""/>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="views-exposed-widget views-widget-filter-institution" id="edit-institution-wrapper">
#                   <label for="edit-institution">
#                    Institution
#                   </label>
#                   <div class="views-widget">
#                    <div class="form-item form-type-select form-item-institution">
#                     <select class="form-select" id="edit-institution" name="institution">
#                      <option selected="selected" value="">
#                       -- Select --
#                      </option>
#                      <option value="Chattanooga State Comm College">
#                       Chattanooga State Comm College
#                      </option>
#                      <option value="Cleveland State Comm College">
#                       Cleveland State Comm College
#                      </option>
#                      <option value="Columbia State Comm College">
#                       Columbia State Comm College
#                      </option>
#                      <option value="Dyersburg State Comm College">
#                       Dyersburg State Comm College
#                      </option>
#                      <option value="Jackson State Comm College">
#                       Jackson State Comm College
#                      </option>
#                      <option value="Motlow State Comm College">
#                       Motlow State Comm College
#                      </option>
#                      <option value="Nashville State Comm College">
#                       Nashville State Comm College
#                      </option>
#                      <option value="Northeast State Comm College">
#                       Northeast State Comm College
#                      </option>
#                      <option value="Pellissippi State Comm Coll">
#                       Pellissippi State Comm Coll
#                      </option>
#                      <option value="Pellissippi State Comm College">
#                       Pellissippi State Comm College
#                      </option>
#                      <option value="Roane State Comm College">
#                       Roane State Comm College
#                      </option>
#                      <option value="Southwest TN Comm College">
#                       Southwest TN Comm College
#                      </option>
#                      <option value="TCAT Athens">
#                       TCAT Athens
#                      </option>
#                      <option value="TCAT Chattanooga">
#                       TCAT Chattanooga
#                      </option>
#                      <option value="TCAT Covington">
#                       TCAT Covington
#                      </option>
#                      <option value="TCAT Crossville">
#                       TCAT Crossville
#                      </option>
#                      <option value="TCAT Crump">
#                       TCAT Crump
#                      </option>
#                      <option value="TCAT Dickson">
#                       TCAT Dickson
#                      </option>
#                      <option value="TCAT Elizabethton">
#                       TCAT Elizabethton
#                      </option>
#                      <option value="TCAT Harriman">
#                       TCAT Harriman
#                      </option>
#                      <option value="TCAT Hartsville">
#                       TCAT Hartsville
#                      </option>
#                      <option value="TCAT Hohenwald">
#                       TCAT Hohenwald
#                      </option>
#                      <option value="TCAT Jacksboro">
#                       TCAT Jacksboro
#                      </option>
#                      <option value="TCAT Jackson">
#                       TCAT Jackson
#                      </option>
#                      <option value="TCAT Knoxville">
#                       TCAT Knoxville
#                      </option>
#                      <option value="TCAT Livingston">
#                       TCAT Livingston
#                      </option>
#                      <option value="TCAT McKenzie">
#                       TCAT McKenzie
#                      </option>
#                      <option value="TCAT McMinnville">
#                       TCAT McMinnville
#                      </option>
#                      <option value="TCAT Memphis">
#                       TCAT Memphis
#                      </option>
#                      <option value="TCAT Morristown">
#                       TCAT Morristown
#                      </option>
#                      <option value="TCAT Murfreesboro">
#                       TCAT Murfreesboro
#                      </option>
#                      <option value="TCAT Nashville">
#                       TCAT Nashville
#                      </option>
#                      <option value="TCAT Newbern">
#                       TCAT Newbern
#                      </option>
#                      <option value="TCAT Oneida">
#                       TCAT Oneida
#                      </option>
#                      <option value="TCAT Paris">
#                       TCAT Paris
#                      </option>
#                      <option value="TCAT Pulaski">
#                       TCAT Pulaski
#                      </option>
#                      <option value="TCAT Ripley">
#                       TCAT Ripley
#                      </option>
#                      <option value="TCAT Shelbyville">
#                       TCAT Shelbyville
#                      </option>
#                      <option value="TCAT Whiteville">
#                       TCAT Whiteville
#                      </option>
#                      <option value="Tennessee Board of Regents">
#                       Tennessee Board of Regents
#                      </option>
#                      <option value="Volunteer State Comm College">
#                       Volunteer State Comm College
#                      </option>
#                      <option value="Walters State Comm College">
#                       Walters State Comm College
#                      </option>
#                     </select>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="views-exposed-widget views-submit-button">
#                   <input class="form-submit" id="edit-submit-tbr-salary-data" name="" type="submit" value="Apply Filters"/>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </form>
#             </div>
#             <div class="view-content">
#              <table class="views-table sticky-enabled cols-7">
#               <thead>
#                <tr>
#                 <th class="views-field views-field-institution-1" scope="col">
#                  <a class="active" href="/hr/salaries?firstname=&amp;lastname=&amp;department=&amp;jobtitle=&amp;institution=&amp;order=institution_1&amp;sort=asc" title="sort by Institution">
#                   Institution
#                  </a>
#                 </th>
#                 <th class="views-field views-field-lastname" scope="col">
#                  <a class="active" href="/hr/salaries?firstname=&amp;lastname=&amp;department=&amp;jobtitle=&amp;institution=&amp;order=lastname&amp;sort=asc" title="sort by Last Name">
#                   Last Name
#                  </a>
#                 </th>
#                 <th class="views-field views-field-firstname" scope="col">
#                  <a class="active" href="/hr/salaries?firstname=&amp;lastname=&amp;department=&amp;jobtitle=&amp;institution=&amp;order=firstname&amp;sort=asc" title="sort by First Name">
#                   First Name
#                  </a>
#                 </th>
#                 <th class="views-field views-field-jobtitle" scope="col">
#                  <a class="active" href="/hr/salaries?firstname=&amp;lastname=&amp;department=&amp;jobtitle=&amp;institution=&amp;order=jobtitle&amp;sort=asc" title="sort by Job Title">
#                   Job Title
#                  </a>
#                 </th>
#                 <th class="views-field views-field-department" scope="col">
#                  <a class="active" href="/hr/salaries?firstname=&amp;lastname=&amp;department=&amp;jobtitle=&amp;institution=&amp;order=department&amp;sort=asc" title="sort by Department">
#                   Department
#                  </a>
#                 </th>
#                 <th class="views-field views-field-php" scope="col">
#                  <a class="active" href="/hr/salaries?firstname=&amp;lastname=&amp;department=&amp;jobtitle=&amp;institution=&amp;order=php&amp;sort=asc" title="sort by Salary">
#                   Salary
#                  </a>
#                 </th>
#                 <th class="views-field views-field-fte" scope="col">
#                  <a class="active" href="/hr/salaries?firstname=&amp;lastname=&amp;department=&amp;jobtitle=&amp;institution=&amp;order=fte&amp;sort=asc" title="sort by FTE">
#                   FTE
#                  </a>
#                 </th>
#                </tr>
#               </thead>
#               <tbody>
#                <tr class="odd views-row-first">
#                 <td class="views-field views-field-institution-1">
#                  Walters State Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Aarons
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Andrew
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Associate Professor
#                 </td>
#                 <td class="views-field views-field-department">
#                  Industrial Technology
#                 </td>
#                 <td class="views-field views-field-php">
#                  $61,983
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-institution-1">
#                  Southwest TN Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Abadie
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Cynthia
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Associate Professor
#                 </td>
#                 <td class="views-field views-field-department">
#                  Business and Legal Studies
#                 </td>
#                 <td class="views-field views-field-php">
#                  $60,636
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-institution-1">
#                  Chattanooga State Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Abbott
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Joyce
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Admissions Records Clerk Pt
#                 </td>
#                 <td class="views-field views-field-department">
#                  Customer Response Center
#                 </td>
#                 <td class="views-field views-field-php">
#                  $22,558
#                 </td>
#                 <td class="views-field views-field-fte">
#                  0.8
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-institution-1">
#                  Tennessee Board of Regents
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Abdulle
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Harun
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  System Adm Specialist
#                 </td>
#                 <td class="views-field views-field-department">
#                  TNeCampus
#                 </td>
#                 <td class="views-field views-field-php">
#                  $60,558
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-institution-1">
#                  Nashville State Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Abel
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Edward
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Stock Clerk 3
#                 </td>
#                 <td class="views-field views-field-department">
#                  Property Management
#                 </td>
#                 <td class="views-field views-field-php">
#                  $32,853
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-institution-1">
#                  Tennessee Board of Regents
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Able
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Mary
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Payroll Associate
#                 </td>
#                 <td class="views-field views-field-department">
#                  Shared Services Initiative
#                 </td>
#                 <td class="views-field views-field-php">
#                  $46,985
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-institution-1">
#                  Chattanooga State Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Abraham
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Roni
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Academic Specialist
#                 </td>
#                 <td class="views-field views-field-department">
#                  Academic Completion Specialists
#                 </td>
#                 <td class="views-field views-field-php">
#                  $43,632
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-institution-1">
#                  Nashville State Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Abu-Orf
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Rebecca
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Department Head
#                 </td>
#                 <td class="views-field views-field-department">
#                  Payroll
#                 </td>
#                 <td class="views-field views-field-php">
#                  $73,936
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-institution-1">
#                  Motlow State Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Abunaemeh
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Malek
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Instructor
#                 </td>
#                 <td class="views-field views-field-department">
#                  Mechatronics
#                 </td>
#                 <td class="views-field views-field-php">
#                  $55,000
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-institution-1">
#                  Southwest TN Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Acoff
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Janura
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Coordinator
#                 </td>
#                 <td class="views-field views-field-department">
#                  TECTA Grant
#                 </td>
#                 <td class="views-field views-field-php">
#                  $39,168
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-institution-1">
#                  Jackson State Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Acree
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Ronald
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Director, Sbdc
#                 </td>
#                 <td class="views-field views-field-department">
#                  Small Business Development Center
#                 </td>
#                 <td class="views-field views-field-php">
#                  $57,419
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-institution-1">
#                  TCAT Pulaski
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Adair
#                 </td>
#                 <td class="views-field views-field-firstname">
#                  Tobie
#                 </td>
#                 <td class="views-field views-field-jobtitle">
#                  Associate Instructor (Ttcp)
#                 </td>
#                 <td class="views-field views-field-department">
#                  Practical Nursing - Summer
#                 </td>
#                 <td class="views-field views-field-php">
#                  $47,380
#                 </td>
#                 <td class="views-field views-field-fte">
#                  1
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-institution-1">
#                  Volunteer State Comm College
#                 </td>
#                 <td class="views-field views-field-lastname">
#                  Adair
#                 </td>
# ...
#               </li>
#               <li class="pager-item">
#                <a href="/hr/salaries?page=1" title="Go to page 2">
#                 2
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/hr/salaries?page=2" title="Go to page 3">
#                 3
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/hr/salaries?page=3" title="Go to page 4">
#                 4
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/hr/salaries?page=4" title="Go to page 5">
#                 5
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/hr/salaries?page=5" title="Go to page 6">
#                 6
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/hr/salaries?page=6" title="Go to page 7">
#                 7
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/hr/salaries?page=7" title="Go to page 8">
#                 8
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/hr/salaries?page=8" title="Go to page 9">
#                 9
#                </a>
#               </li>
#               <li class="pager-ellipsis">
#                …
#               </li>
#               <li class="pager-next">
#                <a href="/hr/salaries?page=1" title="Go to next page">
#                 next ›
#                </a>
#               </li>
#               <li class="pager-last last">
#                <a href="/hr/salaries?page=121" title="Go to last page">
#                 last »
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="view-footer">
#              <span class="note">
#               Please Note: Salary data is provided for full time (0.8) employees of the TBR system office and its institutions. The data is updated semi-annually. Current data is effective as of
#               <strong>
#                03/2018
#               </strong>
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <!-- /.region -->
#        </div>
#       </div>
#       <!-- /#content-wrap -->
#      </div>
#      <!-- /#content -->
#     </div>
#    </div>
#   </div>
#   <!-- /#main, /#main-wrapper -->
#   <div class="region region-footer clearfix">
#    <div class="clearfix block block-block" id="block-block-47">
#     <div class="content">
#      <footer>
#       <div class="container is-fluid">
#        <div class="columns">
#         <div class="column">
#          <h4>
#           Offices
#          </h4>
#          <ul>
#           <li>
#            <a href="https://www.tbr.edu/board/tennessee-board-regents">
#             Board of Regents
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/chancellor/office-chancellor">
#             Chancellor
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/academics/office-academic-affairs">
#             Academic Affairs
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/administration/office-administration-and-facilities-development">
#             Administration and Facilities Development
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/business/office-business-and-finance">
#             Business and Finance
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/ecd/office-economic-and-community-development">
#             Economic and Community Development
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/external-affairs/office-external-affairs">
#             External Affairs
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/generalcounsel/office-general-counsel">
#             General Counsel
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/it/office-information-technology">
#             Information Technology
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/oesi/office-organizational-effectiveness">
#             Organizational Effectiveness
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/policy-strategy">
#             Policy and Strategy
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/student-success/office-student-success">
#             Student Success
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/audit/office-system-wide-internal-audit">
#             System-wide Internal Audit
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="column">
#          <h4>
#           In Depth
#          </h4>
#          <ul>
#           <li>
#            <a href="https://www.tbr.edu/hr/employment-opportunities">
#             Job Opportunities
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/purchasing/how-do-business-tbr">
#             Vendors and Bid Opportunities
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/facilities/projects-requiring-designers">
#             Facilities Bid Opportunities
#            </a>
#           </li>
#           <li>
#            <a href="https://policies.tbr.edu/">
#             Policies
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/contacts/contact-tbr">
#             Contacts / Staff Directory
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/external-affairs/college-system-tennessee-community-newsletter">
#             Newsletter | Subscribe
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/initiatives/online-learning-tn-ecampus">
#             Online Learning (TN eCampus)
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/initiatives/tennessee-transfer-pathway">
#             Tennessee Transfer Pathways
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/initiatives/tn-promise-0">
#             Tennessee Promise
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/initiatives/tn-reconnect-0">
#             Tennessee Reconnect
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="column">
#          <h4>
#           About This Site
#          </h4>
#          <ul>
#           <li>
#            <a href="https://www.tbr.edu/marketing/web-accessibility">
#             Accessibility
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/search">
#             Search
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/marketing/tennessee-board-regents-privacy-statement">
#             Privacy
#            </a>
#           </li>
#           <li>
#            <a href="https://www.tbr.edu/marketing/report-website-issue">
#             Website Feedback
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="column is-half">
#          <div class="clearfix block block-block" id="block-block-48">
#           <div class="content">
#            <ul class="institution-logos">
#             <li>
#              <a href="https://www.tbr.edu/institutions/chattanooga-state-community-college">
#               <img alt="Chattanooga State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_chattstate_0.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/cleveland-state-community-college">
#               <img alt="Cleveland State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_cleveland.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/columbia-state-community-college">
#               <img alt="Columbia State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_columbia.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/dyersburg-state-community-college">
#               <img alt="Dyersburg State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_dyersburg.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/jackson-state-community-college">
#               <img alt="Jackson State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_jackson.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/motlow-state-community-college">
#               <img alt="Motlow State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_motlow.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/nashville-state-community-college">
#               <img alt="Nashville State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_nashstate.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/northeast-state-community-college">
#               <img alt="Northeast State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_northeast.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/pellissippi-state-community-college">
#               <img alt="Pellissippi State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_pellissippi.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/roane-state-community-college">
#               <img alt="Roane State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_roane.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/southwest-tennessee-community-college">
#               <img alt="Southwest Tennessee Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_southwest.png?" width="150px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/volunteer-state-community-college">
#               <img alt="Volunteer State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_volstate.png?" width="120px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/walters-state-community-college">
#               <img alt="Walters State Community College" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/logo_cc_walters.png?" width="140px"/>
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tbr.edu/institutions/colleges-applied-technology">
#               <img alt="Tennessee Colleges of Applied Technology" height="35px" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/institutions/white/tcats.png" width="150px"/>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <hr/>
#       </div>
#       <div class="container is-fluid eeo">
#        <p>
#         The College System of Tennessee, Governed by the Tennessee Board of Regents (TBR), is Tennessee's largest higher education system, governing 40 post-secondary educational institutions with over 200 teaching locations. The TBR system includes 13 community colleges and 27 colleges of applied technology, and TN eCampus, providing programs to students across the state, country, and world.
#        </p>
#        <p>
#         The Tennessee Board of Regents does not discriminate on the basis of race, color, religion, creed, ethnic or national origin, sex, sexual orientation, gender identity/expression, disability, age (as applicable), status as a covered veteran, genetic information, and any other category protected by federal or state civil rights law with respect to all employment, programs and activities sponsored by the Board.
#         <a href="https://policies.tbr.edu/system-office/system-office-non-discrimination-policy" title="Non-Discrimination Policy">
#          Full Non-Discrimination Policy.
#         </a>
#        </p>
#        <div class="footerlogin">
#         <a data-toggle="modal" href="https://tbr.edu/user">
#          <i class="fa fa-circle-o-notch">
#          </i>
#          <span class="sr-only">
#           Login
#          </span>
#         </a>
#         <a href="https://portal.tbr.edu/">
#          <img alt="MyBridge" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/logos/MyBridge_logo.png"/>
#         </a>
#        </div>
#       </div>
#      </footer>
#      <footer class="sub">
#       <div class="container is-fluid">
#        <div class="level">
#         <div class="level-left">
#          <div class="level-item" id="main-address" itemscope="" itemtype="http://schema.org/ContactPoint" style="flex-direction: column;">
#           <div itemscope="" itemtype="schema.org/PostalAddress">
#            <span class="address-street" itemprop="streetAddress">
#             1 Bridgestone Park
#            </span>
#            <span class="address-city" itemprop="addressLocality">
#             Nashville
#            </span>
#            <span class="address-state" itemprop="addressRegion">
#             TN
#            </span>
#            <span class="address-zip" itemprop="postalCode">
#             37214
#            </span>
#           </div>
#           <span class="telephone" itemprop="telephone">
#            615-366-4400
#           </span>
#          </div>
#         </div>
#         <div class="level-right">
#          <a href="https://twitter.com/CollegeSystemTN">
#           <img alt="twitter logo" class="level-item" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/icons/twitter_logo.svg"/>
#          </a>
#          <a href="https://www.instagram.com/collegesystemtn/">
#           <img alt="instragram logo" class="level-item" src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/images/icons/ig_logo.svg"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <!-- /.region -->
#   <!-- /#footer -->
#   <div class="btn btn-large" id="toTop">
#   </div>
#   <!-- /#to-top -->
#   <!-- /#global-footer -->
#   <!-- Javascript file -->
#   <script src="https://code.jquery.com/jquery-3.2.1.slim.min.js">
#   </script>
#   <script src="/profiles/tbr_hosting/themes/tbr_bootstrap_new/dist/js/script.js" type="text/javascript">
#   </script>
#  </body>
#  <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-38033554-1', 'auto');
#   ga('require', 'linkid', 'linkid.js');
#   ga('send', 'pageview');
#  </script>
#  <!-- /analytics-script -->
# </html>

# %%
# let's try to get walters institution
inst = soup.find("td", {"class":"views-field views-field-institution-1"})
inst
# Out:
# <td class="views-field views-field-institution-1">
#             Walters State Comm College          </td>

# %%
# Let s try to get all the institutions here. This is a list. we can access single elements
inst = soup.find_all("td", {"class":"views-field views-field-institution-1"})
inst
inst[0]
# Out:
# <td class="views-field views-field-institution-1">
#             Walters State Comm College          </td>

# %%
# let s use some useful python syntax to get the same result and then make it easier to work with the data by getting it as text
inst_all = [i.text for i in soup.find_all("td", {"class":"views-field views-field-institution-1"})]
inst_all
# Out:
# ['\n            Walters State Comm College          ',
#  '\n            Southwest TN Comm College          ',
#  '\n            Chattanooga State Comm College          ',
#  '\n            Tennessee Board of Regents          ',
#  '\n            Nashville State Comm College          ',
#  '\n            Tennessee Board of Regents          ',
#  '\n            Chattanooga State Comm College          ',
#  '\n            Nashville State Comm College          ',
#  '\n            Motlow State Comm College          ',
#  '\n            Southwest TN Comm College          ',
#  '\n            Jackson State Comm College          ',
#  '\n            TCAT Pulaski          ',
#  '\n            Volunteer State Comm College          ',
#  '\n            Dyersburg State Comm College          ',
#  '\n            Pellissippi State Comm Coll          ',
#  '\n            Dyersburg State Comm College          ',
#  '\n            Tennessee Board of Regents          ',
#  '\n            Northeast State Comm College          ',
#  '\n            Northeast State Comm College          ',
#  '\n            Southwest TN Comm College          ',
#  '\n            Southwest TN Comm College          ',
#  '\n            Walters State Comm College          ',
#  '\n            TCAT Memphis          ',
#  '\n            Chattanooga State Comm College          ',
#  '\n            Chattanooga State Comm College          ',
#  '\n            Motlow State Comm College          ',
#  '\n            Pellissippi State Comm Coll          ',
#  '\n            Nashville State Comm College          ',
#  '\n            TCAT Jackson          ',
#  '\n            TCAT Shelbyville          ',
#  '\n            Dyersburg State Comm College          ',
#  '\n            TCAT Ripley          ',
#  '\n            TCAT Nashville          ',
#  '\n            TCAT Pulaski          ',
#  '\n            Chattanooga State Comm College          ',
#  '\n            Northeast State Comm College          ',
#  '\n            Northeast State Comm College          ',
#  '\n            Nashville State Comm College          ',
#  '\n            Chattanooga State Comm College          ',
#  '\n            TCAT Jacksboro          ',
#  '\n            TCAT Ripley          ',
#  '\n            Roane State Comm College          ',
#  '\n            Roane State Comm College          ',
#  '\n            Roane State Comm College          ',
#  '\n            Roane State Comm College          ',
#  '\n            Nashville State Comm College          ',
#  '\n            Pellissippi State Comm Coll          ',
#  '\n            Roane State Comm College          ',
#  '\n            Chattanooga State Comm College          ',
#  '\n            Pellissippi State Comm Coll          ']

# %%
inst_text = [i.strip() for i in inst_all]
inst_text
# Out:
# ['Walters State Comm College',
#  'Southwest TN Comm College',
#  'Chattanooga State Comm College',
#  'Tennessee Board of Regents',
#  'Nashville State Comm College',
#  'Tennessee Board of Regents',
#  'Chattanooga State Comm College',
#  'Nashville State Comm College',
#  'Motlow State Comm College',
#  'Southwest TN Comm College',
#  'Jackson State Comm College',
#  'TCAT Pulaski',
#  'Volunteer State Comm College',
#  'Dyersburg State Comm College',
#  'Pellissippi State Comm Coll',
#  'Dyersburg State Comm College',
#  'Tennessee Board of Regents',
#  'Northeast State Comm College',
#  'Northeast State Comm College',
#  'Southwest TN Comm College',
#  'Southwest TN Comm College',
#  'Walters State Comm College',
#  'TCAT Memphis',
#  'Chattanooga State Comm College',
#  'Chattanooga State Comm College',
#  'Motlow State Comm College',
#  'Pellissippi State Comm Coll',
#  'Nashville State Comm College',
#  'TCAT Jackson',
#  'TCAT Shelbyville',
#  'Dyersburg State Comm College',
#  'TCAT Ripley',
#  'TCAT Nashville',
#  'TCAT Pulaski',
#  'Chattanooga State Comm College',
#  'Northeast State Comm College',
#  'Northeast State Comm College',
#  'Nashville State Comm College',
#  'Chattanooga State Comm College',
#  'TCAT Jacksboro',
#  'TCAT Ripley',
#  'Roane State Comm College',
#  'Roane State Comm College',
#  'Roane State Comm College',
#  'Roane State Comm College',
#  'Nashville State Comm College',
#  'Pellissippi State Comm Coll',
#  'Roane State Comm College',
#  'Chattanooga State Comm College',
#  'Pellissippi State Comm Coll']

# %%
# Let s get some more info from that page
lastname    = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-lastname"})]
firstname   = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-firstname"})]
jobtitle    = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-jobtitle"})]
department  = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-department"})]
salary      = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-php"})]
fte         = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-fte"})]

# %%
import pandas as pd
tennessee_salaries_df = pd.DataFrame({
    "institution": inst_text, 
    "last_name": lastname, 
    "first_name": firstname,
    "job_title": jobtitle,
    "department": department,
    "salary": salary,
    "fte": fte
    })
tennessee_salaries_df
# Out:
#                        institution     last_name   first_name  \
# 0       Walters State Comm College        Aarons       Andrew
# 1        Southwest TN Comm College        Abadie      Cynthia
# 2   Chattanooga State Comm College        Abbott        Joyce
# 3       Tennessee Board of Regents       Abdulle        Harun
# 4     Nashville State Comm College          Abel       Edward
# 5       Tennessee Board of Regents          Able         Mary
# 6   Chattanooga State Comm College       Abraham         Roni
# 7     Nashville State Comm College       Abu-Orf      Rebecca
# 8        Motlow State Comm College     Abunaemeh        Malek
# 9        Southwest TN Comm College         Acoff       Janura
# 10      Jackson State Comm College         Acree       Ronald
# 11                    TCAT Pulaski         Adair        Tobie
# 12    Volunteer State Comm College         Adair      Rebecca
# 13    Dyersburg State Comm College         Adair        James
# 14     Pellissippi State Comm Coll      Adamczyk       Leslie
# 15    Dyersburg State Comm College         Adams       Teresa
# 16      Tennessee Board of Regents         Adams        James
# 17    Northeast State Comm College         Adams      Anthony
# 18    Northeast State Comm College         Adams       Amanda
# 19       Southwest TN Comm College         Adams      Timothy
# 20       Southwest TN Comm College         Adams       Raquel
# 21      Walters State Comm College         Adams    Elizabeth
# 22                    TCAT Memphis         Adams         Anhi
# 23  Chattanooga State Comm College         Adams        Cinda
# 24  Chattanooga State Comm College         Adams      Deborah
# 25       Motlow State Comm College         Adams      Phyllis
# 26     Pellissippi State Comm Coll         Adams        Steve
# 27    Nashville State Comm College         Adams        David
# 28                    TCAT Jackson         Adams       Steven
# 29                TCAT Shelbyville         Adams        Erika
# 30    Dyersburg State Comm College         Adams       Shawna
# 31                     TCAT Ripley  Adams-Arnold        Ravan
# 32                  TCAT Nashville        Adcock        Randi
# 33                    TCAT Pulaski        Adcock  Christopher
# 34  Chattanooga State Comm College        Adcock       Marvin
# 35    Northeast State Comm College         Adcox         John
# 36    Northeast State Comm College     Addington        Donna
# 37    Nashville State Comm College      Adkerson         Dawn
# 38  Chattanooga State Comm College        Adkins  Christopher
# 39                  TCAT Jacksboro        Adkins        Leann
# 40                     TCAT Ripley        Adkins       Ashley
# 41        Roane State Comm College        Adkins       Joshua
# 42        Roane State Comm College        Adkins         Rena
# 43        Roane State Comm College      Adkisson        Tasha
# 44        Roane State Comm College      Adkisson     Michelle
# 45    Nashville State Comm College        Adunas        Gilma
# 46     Pellissippi State Comm Coll     Affholter     Kathleen
# 47        Roane State Comm College         Ahler  Christopher
# 48  Chattanooga State Comm College        Aitken         John
# 49     Pellissippi State Comm Coll         Akard        Kevin
#
#                          job_title                               department  \
# 0              Associate Professor                    Industrial Technology
# 1              Associate Professor               Business and Legal Studies
# 2      Admissions Records Clerk Pt                 Customer Response Center
# 3            System Adm Specialist                                TNeCampus
# 4                    Stock Clerk 3                      Property Management
# 5                Payroll Associate               Shared Services Initiative
# 6              Academic Specialist          Academic Completion Specialists
# 7                  Department Head                                  Payroll
# 8                       Instructor                             Mechatronics
# 9                      Coordinator                              TECTA Grant
# 10                  Director, Sbdc        Small Business Development Center
# 11     Associate Instructor (Ttcp)               Practical Nursing - Summer
# 12              Completion Advisor                          Advising Center
# 13             Associate Professor                                     Math
# 14     Assistant Professor 9 Month                          Natural Science
# 15            Secretary Iii - Trio                     Upward Bound 2017-18
# 16  Dir Of Construction Management          Facilities and Capital Projects
# 17  Computer Laboratory Technician           Computer User Support Services
# 18            Director - Marketing                                Marketing
# 19                        Designer                        Creative Services
# 20                      Instructor           Commun, Graphics and Fine Arts
# 21         Financial Aid Assistant                            Financial Aid
# 22            Associate Instructor                          Dental Lab Tech
# 23             Associate Professor                               Management
# 24                  Vice President         Office of VP for Student Affairs
# 25                       Professor                           Communications
# 26            Maintenance Mechanic                     Building Maintenance
# 27                      Instructor                      Business Management
# 28      Sr. Instructortool And Die                             Tool and Die
# 29              Financial Aid Lead          Student Services Administration
# 30                      Instructor                                  Biology
# 31                     Coordinator               Student Affairs Counseling
# 32      Facilities Support Assoc 1      Operations And Maintenance Of Plant
# 33     Associate Instructor (Ttcp)                   Industrial Electricity
# 34                      Instructor                               Management
# 35            Va - Technical Clerk      Dir of Enrollment & Adm and Records
# 36      Program Specialist/Advisor  Student Support Services              .
# 37             Associate Professor                                  English
# 38                     Coordinator                        r-VW GOA Contract
# 39                       Technican                     Administrator Office
# 40     Associate Instructor Ripley           Clerical Steno and Secretarial
# 41             Success Coach - Sip                      Title III SIP Grant
# 42             Success Coach - Sip                      Title III SIP Grant
# 43            Enrollment Assistant              Student Enrollment One-Stop
# 44   Director Morgan County Center                     Morgan County Center
# 45             Assistant Professor                                  Physics
# 46               Professor 9 Month                          Natural Science
# 47  Assistant Professor - Business                            Business Mgmt
# 48          Specialist-Multi Media                           Media Services
# 49              Instructor 9 Month        Mechanical Engineering Technology
#
#       salary   fte
# 0    $61,983     1
# 1    $60,636     1
# 2    $22,558   0.8
# 3    $60,558     1
# 4    $32,853     1
# 5    $46,985     1
# 6    $43,632     1
# 7    $73,936     1
# 8    $55,000     1
# 9    $39,168     1
# 10   $57,419     1
# 11   $47,380     1
# 12   $40,556     1
# 13   $54,397     1
# 14   $47,980     1
# 15   $32,811     1
# 16   $96,762     1
# 17   $45,480     1
# 18   $61,020     1
# 19   $37,536     1
# 20   $38,292     1
# 21   $33,157     1
# 22   $47,400     1
# 23   $58,449     1
# 24  $134,550     1
# 25   $62,320     1
# 26   $36,890     1
# 27   $44,750     1
# 28   $61,381     1
# 29   $38,000     1
# 30   $45,865     1
# 31   $34,907     1
# 32   $24,720     1
# 33   $52,530     1
# 34   $44,480     1
# 35   $26,483     1
# 36   $16,507  0.67
# 37   $58,717     1
# 38   $69,937     1
# 39   $38,092     1
# 40   $46,300     1
# 41   $40,756     1
# 42   $48,441     1
# 43   $26,712     1
# 44   $58,614     1
# 45   $48,791     1
# 46   $64,870     1
# 47   $46,206     1
# 48   $50,011     1
# 49   $52,520     1

# %%
# But what if I want all the pages?
# https://www.tbr.edu/hr/salaries?page=121
# There are 122 pages: compare last and first page

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
# Open a dictionary to store information in. 

tennessee_salaries_df = pd.DataFrame({
    "institution": [], 
    "last_name": [], 
    "first_name": [],
    "job_title": [],
    "department": [],
    "salary": [],
    "fte": []
    })

# %%
pages = list(range(1,4)) # there are 122 pages. for now only do a few so to not break it down. 

for page in pages:
    
    url  = "https://www.tbr.edu/hr/salaries?firstname=&lastname=&department=&jobtitle=&institution=&page=" + str(page)
    # Define the url. Deal with the 0 page later. 
    html = requests.get(url) 
    soup = bs(html.text, "lxml")
    
    # retrieve the elements on each page as before
    institutions = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-institution-1"})]
    lastname     = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-lastname"})]
    firstname    = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-firstname"})]
    jobtitle     = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-jobtitle"})]
    department   = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-department"})]
    salary       = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-php"})]
    fte          = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-fte"})]
    
    # Pass them into the dictionary
    salaries = pd.DataFrame({
        "institution": institutions, 
        "last_name": lastname, 
        "first_name": firstname,
        "job_title": jobtitle,
        "department": department,
        "salary": salary,
        "fte": fte
        })
    
    # Append this to the already existing list
    tennessee_salaries_df = tennessee_salaries_df.append(salaries)
    
tennessee_salaries_df[0:20]
# Out:
#                        institution        last_name first_name  \
# 0                TCAT Murfreesboro            Akers    Jessica
# 1         Roane State Comm College            Akers   Mariella
# 2                 TCAT McMinnville            Akers      Debra
# 3     Nashville State Comm College            Akers   Kathleen
# 4        Southwest TN Comm College             Akin    Tiffany
# 5                     TCAT Newbern            Akins       John
# 6                     TCAT Jackson            Akins       Lori
# 7     Nashville State Comm College           Akther     Jesmin
# 8                TCAT Murfreesboro           Albers      Jenny
# 9     Northeast State Comm College         Albright      Kathy
# 10  Chattanooga State Comm College        Albritton     Sheila
# 11      Walters State Comm College           Alcorn      Kathy
# 12      Walters State Comm College           Alcorn     Steven
# 13      Walters State Comm College         Alderman    Lee Ann
# 14                 TCAT Morristown           Aldred     Darren
# 15    Nashville State Comm College         Aldridge     George
# 16       Southwest TN Comm College  Alekseyeva-Logs      Irina
# 17    Cleveland State Comm College        Alexander    Melodee
# 18      Walters State Comm College        Alexander      Julie
# 19    Volunteer State Comm College        Alexander     Robert
#
#                          job_title                               department  \
# 0         Senior Instructor (Ttcu)              Business Systems Technology
# 1                  Technical Clerk                    Oak Ridge Instruction
# 2                Master Instructor                 Computer Oper Technology
# 3                         Director               Clarksville Administration
# 4                       Instructor                 Languages and Literature
# 5     Assoc Instructor Ttc Newbern                        Injection Welding
# 6                Master Instructor              Practical Nursing Lexington
# 7                       Instructor                                Chemistry
# 8       Acad & Student Sup Assoc 4                            Other General
# 9   Secretary 2 - Testing Services          Counseling and Testing Services
# 10                        Director                         Success Coaching
# 11             Associate Professor                          R and D Reading
# 12             Associate Professor                                  English
# 13                        Director                     Sevier County Center
# 14               Senior Instructor                                 Drafting
# 15                    Police Chief               Safety And Security Legacy
# 16                 Technical Clerk  Honors Academy                        .
# 17                      Instructor                               Psychology
# 18      Human Resources Specialist                          Human Resources
# 19                       Custodian                                Custodial
#
#      salary    fte
# 0   $53,581      1
# 1   $31,968      1
# 2   $68,337      1
# 3   $75,000      1
# 4   $38,292      1
# 5   $54,000      1
# 6   $60,554      1
# 7   $42,918      1
# 8   $31,591      1
# 9   $23,250      1
# 10  $71,276      1
# 11  $50,260      1
# 12  $53,303      1
# 13  $65,000      1
# 14  $67,451      1
# 15  $54,500      1
# 16  $21,960  0.853
# 17  $47,532      1
# 18  $41,220      1
# 19  $24,499      1

# %%
# Now, how to deal with the first page? 

# Open a dictionary to store information in. 

tennessee_salaries_df = pd.DataFrame({
    "institution": [], 
    "last_name": [], 
    "first_name": [],
    "job_title": [],
    "department": [],
    "salary": [],
    "fte": []
    })

# Need to add an exception, can use e.g. a counter
pages = list(range(0,4))
counter = 0 

for page in pages:
    
    if counter == 0:
        
        url  = "https://www.tbr.edu/hr/salaries" 
        
    
    if counter > 0:
        
        url  = "https://www.tbr.edu/hr/salaries?firstname=&lastname=&department=&jobtitle=&institution=&page=" + str(page)
    
    html = requests.get(url) 
    soup = bs(html.text, "lxml")

    # retrieve the elements on each page as before
    institutions = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-institution-1"})]
    lastname     = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-lastname"})]
    firstname    = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-firstname"})]
    jobtitle     = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-jobtitle"})]
    department   = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-department"})]
    salary       = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-php"})]
    fte          = [i.text.strip() for i in soup.findAll("td", {"class":"views-field views-field-fte"})]

    # Pass them into the dictionary
    salaries = pd.DataFrame({
        "institution": institutions, 
        "last_name": lastname, 
        "first_name": firstname,
        "job_title": jobtitle,
        "department": department,
        "salary": salary,
        "fte": fte
        })

    # Append this to the already existing list
    tennessee_salaries_df = tennessee_salaries_df.append(salaries)

    counter += 1
    
tennessee_salaries_df[0:20]
# Out:
#                        institution  last_name first_name  \
# 0       Walters State Comm College     Aarons     Andrew
# 1        Southwest TN Comm College     Abadie    Cynthia
# 2   Chattanooga State Comm College     Abbott      Joyce
# 3       Tennessee Board of Regents    Abdulle      Harun
# 4     Nashville State Comm College       Abel     Edward
# 5       Tennessee Board of Regents       Able       Mary
# 6   Chattanooga State Comm College    Abraham       Roni
# 7     Nashville State Comm College    Abu-Orf    Rebecca
# 8        Motlow State Comm College  Abunaemeh      Malek
# 9        Southwest TN Comm College      Acoff     Janura
# 10      Jackson State Comm College      Acree     Ronald
# 11                    TCAT Pulaski      Adair      Tobie
# 12    Volunteer State Comm College      Adair    Rebecca
# 13    Dyersburg State Comm College      Adair      James
# 14     Pellissippi State Comm Coll   Adamczyk     Leslie
# 15    Dyersburg State Comm College      Adams     Teresa
# 16      Tennessee Board of Regents      Adams      James
# 17    Northeast State Comm College      Adams    Anthony
# 18    Northeast State Comm College      Adams     Amanda
# 19       Southwest TN Comm College      Adams    Timothy
#
#                          job_title                         department  \
# 0              Associate Professor              Industrial Technology
# 1              Associate Professor         Business and Legal Studies
# 2      Admissions Records Clerk Pt           Customer Response Center
# 3            System Adm Specialist                          TNeCampus
# 4                    Stock Clerk 3                Property Management
# 5                Payroll Associate         Shared Services Initiative
# 6              Academic Specialist    Academic Completion Specialists
# 7                  Department Head                            Payroll
# 8                       Instructor                       Mechatronics
# 9                      Coordinator                        TECTA Grant
# 10                  Director, Sbdc  Small Business Development Center
# 11     Associate Instructor (Ttcp)         Practical Nursing - Summer
# 12              Completion Advisor                    Advising Center
# 13             Associate Professor                               Math
# 14     Assistant Professor 9 Month                    Natural Science
# 15            Secretary Iii - Trio               Upward Bound 2017-18
# 16  Dir Of Construction Management    Facilities and Capital Projects
# 17  Computer Laboratory Technician     Computer User Support Services
# 18            Director - Marketing                          Marketing
# 19                        Designer                  Creative Services
#
#      salary  fte
# 0   $61,983    1
# 1   $60,636    1
# 2   $22,558  0.8
# 3   $60,558    1
# 4   $32,853    1
# 5   $46,985    1
# 6   $43,632    1
# 7   $73,936    1
# 8   $55,000    1
# 9   $39,168    1
# 10  $57,419    1
# 11  $47,380    1
# 12  $40,556    1
# 13  $54,397    1
# 14  $47,980    1
# 15  $32,811    1
# 16  $96,762    1
# 17  $45,480    1
# 18  $61,020    1
# 19  $37,536    1

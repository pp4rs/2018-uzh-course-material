# %% [markdown]
# # Python Project
#
# In this part of the course we will use Python to predict polls as outcomes of the 2016 Prsidential Election. Sound's fun?
#
# Here's what we're going to do:
# 1. use selenium to scrape search volume data from Google Trends
# 3. use pandas to prepare the data
# 2. use data.world to download 538 data from polls in each state
# 4. use scipy to do some data analysis
# 5. use XXX to visualize our results
#
# Let's go!

# %% [markdown]
# ## 1. Web scraping
# Before starting to code your brains out, it's worth taking a look at [Google Trends](https://trends.google.com/trends). Familiarize yourself with the basic functionalities of the website. Search for something and try to get the data in csv form.
#
# Some things to think about:
# - Google Trends normalizes the data so that the peak search interest in the results corresponds to a value of 100. You can't unnormalize the data, but maybe it can actually save you time! Ask: How would I normalize anyways?
# - With this in mind, should you search for both candidates simultaneously or for one at a time?
# - There are different options to search: search terms and concepts. Which should you use?
# - We want to have a time series for each state. There two main ways to accomplish this: export the time series for each state or export the data in the map for each time point. Which should you use?
# - can you use a static method or will you have to used a dynamic webdriver?
#
# For this step-by-step guide we will compare both search terms simultaneously and export the map data for every day in the year leading up to the election. If the volume is very low, Google doesn't report anything. Although there exists a [workaround](https://www.sciencedirect.com/science/article/pii/S0047272714000929) we won't bother with it here.

# %% [markdown]
# As a first step, write write a function `open_driver()` that imports and opens the selenium webdriver. Return the webdriver as an object. I suggest that you also import `By` and `Options`.
#
# You could try changing the download location using Options, but it might not work on your OS. We'll rename the downloads anyways so you can just move them to the correct location at that step. Don't worry, by now that should't be a challenge for you!

# %%
def open_driver():
    """
    Function to open the chrome webdriver.
    """
    # ---
    # add your code here
    
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.chrome.options import Options
    
    chrome_options = Options()
    #chrome_options.add_argument("--headless") # doesn't work yet
    chrome_options.add_argument('--no-sandbox')
    driver = webdriver.Chrome('/usr/local/bin/chromedriver', chrome_options=chrome_options)
    
    # ---
    print('Chrome driver is good to go!')
    return driver

# %% [markdown]
# Make sure to test your function:

# %%
driver = open_driver()

# %% [markdown]
# Next, set up a example search for both candidates on election day (Nov 8, 2016). Take a look at your URL. While the date menue is relatively complicated to navigate, changing the date through the url id straightforward, so that is what we're going to do.
# https://trends.google.com/trends/explore?hl=en&date=[START_DATE]%20[END_DATE]&geo=[REGION]&q=[SEARCH_TERMS]
#
# Note: I added `hl=en` flag to the url, otherwise the labels might not be in English and you'll have trouble matching the data.
#
# Write a function that takes a start date, end date, region, and a list of search terms as inputs and returns the url. For fancy pants: Check if `searchterms` is a list and join it using commas if necessary. Replace spaces in search terms by `%20`.

# %%
def build_url(start, end, region, searchterms):
    """
    Function to construct the URL.
    """
    # ---
    # add your code here
    
    if isinstance(searchterms, list) == True:
        searchterms = ','.join(map(str, searchterms)) # the easier  ",".join(list) might not work with some symbols.
    searchterms = searchterms.replace(' ','%20')
    
    url = 'https://trends.google.com/trends/explore?hl=en&date='+start+'%20'+end+'&geo='+region+'&q='+searchterms
    
    # ---
    return url

# %% [markdown]
# Test the function:

# %%
url = build_url('2016-11-08','2016-11-08','US',['Donald Trump','Hillary Clinton'])
url
# Out:
# 'https://trends.google.com/trends/explore?date=2016-11-08%202016-11-08&geo=US&q=Donald%20Trump,Hillary%20Clinton'

# %% [markdown]
# Now comes the tricky part: Write a function that opens the url in the driver and downloads the csv file for the map. Be careful, as there are multiple download buttons!
#
# Note: Google has a nasty habit of producting an error the first time you access the url. A relatively reliable work around uses the `time.sleep()` function to wait two seconds and try again. A more sophistiated solution would check if the download button is there and reload periodically until it is (although in my experience, either you get the page on the second attempt or you don't get it anytime soon).
#
# Also: All the files will have the same name when downloaded. This can cause some problems, expecially if you start a new download while there's still a previous file in the directory. I suggest that you first remove the old file (if it exists) and that you wait at the end until your download is complete. Both can easily be achieved using an `if os.path.exists("path/to/your/file"):` clause.

# %%
def download_csv(url, driver):
    """
    Function to download the csv file of the map.
    """
    # ---
    # add your code here
    
    import os
    import time
    print('... start download...')
    
    map_dl = '/Users/czuend/Downloads/geoMap.csv'
    if os.path.exists(map_dl):
        os.remove(map_dl)

    export_map = []
    while len(export_map) == 0:
        print('... ... try loading the page...')
        driver.get(url)
        time.sleep(2)
        export_map = driver.find_elements_by_xpath('//*[@class="fe-multi-heat-map-generated fe-atoms-generic-container"]')
    
    export_map[0].find_element_by_xpath('.//*[@title="CSV"]').click()
    
    while not os.path.exists(map_dl):
        time.sleep(1)
        
    del export_map # maybe not needed with the download_csv function. 
    
    print('... download complete.')
    
    # ---
    return

# %% [markdown]
# ... and test it:

# %%
download_csv(url, driver)
# Out:
# ... start download...
# ... ... wait one second and try again...
# ... ... wait one second and try again...
# ... download complete.

# %% [markdown]
# We have to rename (and possibly move) the downloaded csv file. Name the file `"map_[searchterms]_[startdate]_[enddate]_[region].csv"`, to avoid accidentally overwriting existing files if you later explore other search specifications.

# %%
def rename_csv(start, end, region, searchterms):
    """
    Function to rename and move files.
    """
    # ---
    # add your code here
    
    import os
    
    if isinstance(searchterms, list) == True:
        searchterms = ','.join(map(str, searchterms))
    searchterms = searchterms.replace(' ','%20')
    
    dir = 'data'
    if not os.path.exists(dir):
        os.makedirs(dir)

    map_dl = '/Users/czuend/Downloads/geoMap.csv'
    map_name = dir+'/map_'+searchterms+'_'+start+'_'+end+'_'+region+'.csv'

    os.rename(map_dl, map_name)
    
    # ---
    return

# %% [markdown]
# ... and test it:

# %%
rename_csv('2016-11-08','2016-11-08','US',['Donald Trump','Hillary Clinton'])

# %% [markdown]
# Finally, we need a list of dates to loop over. There are many ways to do this. The internet is your friend here!
#
# Note: I suggest you only scrape a month's worth of data and copy the rest from the github repo as webscraping is time consuming and not universally appreciated (e.g. by Google's system admins).

# %%
def get_dates():
    """
    Function to produce a list of dates with YYYY-MM-DD from 2015-11-08 to 2016-11-08.
    """
    # ---
    # add your code here
    
    from datetime import date, timedelta
    d1 = date(2015,7,2)
    d2 = date(2016,11,8)
    dates = [str(d1 + timedelta(days=x)) for x in range((d2-d1).days + 1)]
    
    # ---
    return dates

# %% [markdown]
# One last test:

# %%
get_dates()

# %% [markdown]
# Congratulations, we're ready to put everything together!

# %%
def main():
    driver = open_driver()
    searchterms = ['Donald Trump','Hillary Clinton']
    region = 'US'
    dates = get_dates()
    for date in dates:
        print('Download data for: ', date)
        url = build_url(date, date, region, searchterms)
        download_csv(url, driver)
        rename_csv(date, date, region, searchterms)
    driver.quit()
    print('All data downloaded.')
    
if __name__ == '__main__':
  main()
# Out:
# Chrome driver is good to go!
# Download data for:  2015-11-26
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-11-27
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-11-28
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-11-29
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-11-30
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-01
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-02
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-03
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-04
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-05
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-06
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-07
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-08
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-09
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-10
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-11
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-12
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-13
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-14
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-15
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-16
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-17
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-18
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-19
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-20
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-21
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-22
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-23
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-24
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-25
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-26
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-27
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-28
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-29
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-30
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2015-12-31
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-01
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-02
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-03
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-04
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-05
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-06
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-07
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-08
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-09
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-10
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-11
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-12
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-13
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-14
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-15
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-16
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-17
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-18
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-19
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-20
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-21
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-22
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-23
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-24
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-25
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-26
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-27
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-28
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-29
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-30
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-01-31
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-01
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-02
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-03
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-04
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-05
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-06
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-07
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-08
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-09
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-10
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-11
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-12
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-13
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-14
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-15
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-16
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-17
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-18
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-19
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-20
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-21
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-22
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-23
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-24
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-25
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-26
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-27
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-28
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-02-29
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-01
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-02
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-03
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-04
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-05
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-06
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-07
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-08
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-09
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-10
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-11
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-12
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-13
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-14
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-15
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-16
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-17
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-18
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-19
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-20
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-21
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-22
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-23
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-24
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-25
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-26
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-27
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-28
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-29
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-30
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-03-31
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-01
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-02
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-03
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-04
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-05
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-06
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-07
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-08
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-09
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-10
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-11
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-12
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-13
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-14
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-15
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-16
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-17
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-18
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-19
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-20
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-21
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-22
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-23
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-24
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-25
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-26
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-27
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-28
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-29
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-04-30
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-01
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-02
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-03
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-04
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-05
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-06
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-07
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-08
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-09
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-10
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-11
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-12
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-13
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-14
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-15
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-16
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-17
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-18
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-19
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-20
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-21
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-22
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-23
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-24
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-25
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-26
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-27
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-28
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-29
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-30
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-05-31
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-01
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-02
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-03
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-04
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-05
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-06
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-07
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-08
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-09
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-10
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-11
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-12
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-13
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-14
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-15
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-16
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-17
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-18
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-19
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-20
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-21
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-22
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-23
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-24
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-25
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-26
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-27
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-28
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-29
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-06-30
# ... start download...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-07-01
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... download complete.
# Download data for:  2016-07-02
# ... start download...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ... ... try loading the page...
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-358-6404ec481162> in <module>()
#      13
#      14 if __name__ == '__main__':
# ---> 15   main()
#
# <ipython-input-358-6404ec481162> in main()
#       7         print('Download data for: ', date)
#       8         url = build_url(date, date, region, searchterms)
# ----> 9         download_csv(url, driver)
#      10         rename_csv(date, date, region, searchterms)
#      11     driver.quit()
#
# <ipython-input-292-1b100d301b02> in download_csv(url, driver)
#      19         driver.get(url)
#      20         time.sleep(2)
# ---> 21         export_map = driver.find_elements_by_xpath('//*[@class="fe-multi-heat-map-generated fe-atoms-generic-container"]')
#      22
#      23     export_map[0].find_element_by_xpath('.//*[@title="CSV"]').click()
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_elements_by_xpath(self, xpath)
#     399             elements = driver.find_elements_by_xpath("//div[contains(@class, 'foo')]")
#     400         """
# --> 401         return self.find_elements(by=By.XPATH, value=xpath)
#     402
#     403     def find_element_by_link_text(self, link_text):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_elements(self, by, value)
#     981         return self.execute(Command.FIND_ELEMENTS, {
#     982             'using': by,
# --> 983             'value': value})['value'] or []
#     984
#     985     @property
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.32.498537 (cb2f855cbc7b82e20387eaf9a43f6b99b6105061),platform=Mac OS X 10.13.6 x86_64)

# %%
driver.quit()

# %% [markdown]
# ## 2. Prepare Google Trends data
#
# Now that we have the data from Google, we're going to combine all the csv files in a large pandas dataframe.
#
# - use `os.listdir()` to generate a list of all the files
# - write a loop to append all of them in a large pandas dataframe
# - clean the data to remove missing values and normalize the data

# %% [markdown]
# First, use `os.listdir()` to generate a list `files` of all the files we want to load. If you saved other data in the same directory, you might need to filter the list and keep just the Google Trends data.

# %%
# ---
# add your code here

import os 
files = [f for f in os.listdir('data') if 'map_' in f]

# ---

# %% [markdown]
# If done correctly, you should have 367 files (Nov 8th is included twice and 2016 was a leap year). Let's see how many we got:

# %%
len(files)
# Out:
# 367

# %% [markdown]
# Write a function `load_data()` to load a file from into a pandas dataframe with colums `state`, `trump`, and `clinton`, and generate a column 'date' that contains the date from the file name.

# %%
def load_data(f):
    # ---
    # add your code here
    import re
    
    df = pd.read_csv('data/'+f, header = 1, names = ['state','trump','clinton'])
    date = re.search('\d{4}-\d{2}-\d{2}',f)
    df['date'] = date.group()
    # ---
    return df

# %% [markdown]
# Test the function:

# %%
load_data(files[0])
# Out:
#                    state  trump clinton        date
# 0         South Carolina   94 %    19 %  2016-02-21
# 1          Massachusetts   80 %    32 %  2016-02-21
# 2                Georgia   89 %    23 %  2016-02-21
# 3           Pennsylvania   92 %    21 %  2016-02-21
# 4                 Nevada   70 %    43 %  2016-02-21
# 5             Norddakota   79 %    34 %  2016-02-21
# 6         North Carolina   85 %    28 %  2016-02-21
# 7             New Jersey   86 %    27 %  2016-02-21
# 8            Connecticut   92 %    21 %  2016-02-21
# 9              Tennessee   92 %    21 %  2016-02-21
# 10              New York   79 %    34 %  2016-02-21
# 11               Alabama  100 %    13 %  2016-02-21
# 12         New Hampshire   96 %    17 %  2016-02-21
# 13                  Iowa   81 %    31 %  2016-02-21
# 14               Arizona   87 %    26 %  2016-02-21
# 15               Florida   86 %    27 %  2016-02-21
# 16              Virginia   84 %    29 %  2016-02-21
# 17         West Virginia   88 %    25 %  2016-02-21
# 18              Maryland   84 %    29 %  2016-02-21
# 19              Arkansas   87 %    26 %  2016-02-21
# 20  District of Columbia   76 %    37 %  2016-02-21
# 21               Wyoming   75 %    38 %  2016-02-21
# 22           Mississippi   92 %    21 %  2016-02-21
# 23                  Utah   88 %    25 %  2016-02-21
# 24                  Ohio   92 %    21 %  2016-02-21
# 25                Kansas   92 %    21 %  2016-02-21
# 26              Missouri   93 %    20 %  2016-02-21
# 27              Delaware   88 %    25 %  2016-02-21
# 28              Illinois   80 %    32 %  2016-02-21
# 29                Oregon   85 %    28 %  2016-02-21
# 30           Kalifornien   84 %    29 %  2016-02-21
# 31             Louisiana   92 %    21 %  2016-02-21
# 32              Michigan   84 %    29 %  2016-02-21
# 33              Nebraska   79 %    34 %  2016-02-21
# 34               Indiana   92 %    21 %  2016-02-21
# 35              Kentucky   87 %    26 %  2016-02-21
# 36          Rhode Island   92 %    21 %  2016-02-21
# 37                 Maine   70 %    43 %  2016-02-21
# 38            New Mexico   94 %    19 %  2016-02-21
# 39                 Texas   82 %    30 %  2016-02-21
# 40             Wisconsin   86 %    27 %  2016-02-21
# 41                 Idaho   80 %    32 %  2016-02-21
# 42            Washington   87 %    26 %  2016-02-21
# 43             Minnesota   82 %    30 %  2016-02-21
# 44              Oklahoma   95 %    18 %  2016-02-21
# 45              Colorado   77 %    36 %  2016-02-21
# 46               Vermont   77 %    36 %  2016-02-21
# 47               Montana   92 %    21 %  2016-02-21
# 48                Hawaii   68 %    45 %  2016-02-21
# 49                Alaska   59 %    54 %  2016-02-21
# 50             Süddakota   64 %    48 %  2016-02-21

# %% [markdown]
# Create an empty pandas dataframe `google_raw` and write a loop over `files` that applies `load_data()` on each file and appends it to `google_raw`.

# %%
# ---
# add your code here

import pandas as pd
google_raw = pd.DataFrame()

for f in files:
    df = load_data(f)
    google_raw = google_raw.append(df, ignore_index=True)
    
# ---

# %% [markdown]
# Let's see whether it worked:

# %%
google_raw

# %% [markdown]
# Finally, we'll do some housekeeping:
#
# 1. create a copy of the 'google_raw' dataframe so that we don't have to rerun the loop if we mess up.
# 2. remove missing values
# 3. remove the `%` symbol from the percentages
# 4. normalize the data such that `candidate = candidate / (total searches)`
# 5. use `groupby` to order by `date` and `state`

# %%
# ---
# add your code here

df = google_raw.copy()
df = df.dropna()

df = df.replace(to_replace=r'^Kalifornien$', value='California', regex=True)
df = df.replace(to_replace=r'^Norddakota$', value='North Dakota', regex=True)
df = df.replace(to_replace=r'^Süddakota$', value='South Dakota', regex=True)

df['trump'] = df['trump'].astype(str).str[:-2].astype(np.int64)
df['clinton'] = df['clinton'].astype(str).str[:-2].astype(np.int64)

df['tot'] = df['trump'] + df['clinton']
df['trump'] = df['trump']/df['tot']
df['clinton'] = df['clinton']/df['tot']
del df['tot']

df = df.groupby(["date", "state"]).agg('sum')
# ---

# %% [markdown]
# Checking the result and copying it to `google_data`:

# %%
google_data = df.copy()
google_data
# Out:
#                                     trump   clinton
# date       state
# 2015-11-08 Alabama               0.940000  0.060000
#            Alaska                0.810000  0.190000
#            Arizona               0.920000  0.080000
#            California            0.890000  0.110000
#            Colorado              0.910000  0.090000
#            Connecticut           0.920000  0.080000
#            District of Columbia  0.890000  0.110000
#            Florida               0.900000  0.100000
#            Georgia               0.900000  0.100000
#            Hawaii                0.850000  0.150000
#            Illinois              0.900000  0.100000
#            Indiana               0.870000  0.130000
#            Iowa                  0.860000  0.140000
#            Kansas                0.930000  0.070000
#            Kentucky              0.810000  0.190000
#            Louisiana             0.910000  0.090000
#            Maryland              0.910000  0.090000
#            Massachusetts         0.900000  0.100000
#            Michigan              0.860000  0.140000
#            Minnesota             0.940000  0.060000
#            Mississippi           0.560000  0.440000
#            Missouri              0.800000  0.200000
#            Montana               0.770000  0.230000
#            New Hampshire         0.680000  0.320000
#            New Jersey            0.930000  0.070000
#            New York              0.880000  0.120000
#            North Carolina        0.870000  0.130000
#            Ohio                  0.840000  0.160000
#            Oklahoma              0.880000  0.120000
#            Oregon                0.860000  0.140000
# ...                                   ...       ...
# 2016-11-08 Massachusetts         0.462025  0.537975
#            Michigan              0.531646  0.468354
#            Minnesota             0.518987  0.481013
#            Mississippi           0.490446  0.509554
#            Missouri              0.509554  0.490446
#            Montana               0.449367  0.550633
#            Nebraska              0.462025  0.537975
#            Nevada                0.531646  0.468354
#            New Hampshire         0.490446  0.509554
#            New Jersey            0.500000  0.500000
#            New Mexico            0.500000  0.500000
#            New York              0.462025  0.537975
#            North Carolina        0.518987  0.481013
#            North Dakota          0.518987  0.481013
#            Ohio                  0.500000  0.500000
#            Oklahoma              0.500000  0.500000
#            Oregon                0.481013  0.518987
#            Pennsylvania          0.500000  0.500000
#            Rhode Island          0.632911  0.367089
#            South Carolina        0.509554  0.490446
#            South Dakota          0.550633  0.449367
#            Tennessee             0.518987  0.481013
#            Texas                 0.500000  0.500000
#            Utah                  0.531646  0.468354
#            Vermont               0.388535  0.611465
#            Virginia              0.500000  0.500000
#            Washington            0.500000  0.500000
#            West Virginia         0.500000  0.500000
#            Wisconsin             0.509554  0.490446
#            Wyoming               0.537975  0.462025
#
# [18165 rows x 2 columns]

# %% [markdown]
# ## 3. Prepare polling data
#
# We're going to use polling data compiled by 538. However, instead of scraping that data too, we're going to use a short cut. Interesting data has often been scraped by somebody else before, so you can save a lot of time by googling datasets and checking github and other data repositories!
#
# 1. Go to [data.world](data.world) and registre as a new user (unless you're an old user, duh!). They have some cool data, so it's worth it.
# 2. Download [presidential_polls_2016_fivethirtyeight.csv](https://data.world/databeats/2016-us-presidential-election/workspace/file?filename=presidential_polls_2016_fivethirtyeight.csv) to an appropriate location.
#
# Note: If you feel like showing off, try creating an API key and downloading the data using the python module. [Here's some guidance.](https://data.world/integrations/python)

# %% [markdown]
# Load the poll data into a pandas dataframe called `polls`.

# %%
# ---
# add your code here
import pandas as pd

polls = pd.read_csv('data/presidential_polls_2016_fivethirtyeight.csv')
# ---

# %% [markdown]
# Let's have a look:

# %%
polls
# Out:
#        cycle     branch        type                        matchup  \
# 0       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 5       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 6       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 7       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 8       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 9       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 10      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 11      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 12      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 13      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 14      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 15      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 16      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 17      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 18      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 19      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 20      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 21      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 22      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 23      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 24      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 25      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 26      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 27      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 28      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 29      2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12594   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12595   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12596   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12597   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12598   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12599   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12600   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12601   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12602   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12603   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12604   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12605   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12606   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12607   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12608   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12609   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12610   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12611   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12612   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12613   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12614   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12615   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12616   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12617   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12618   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate           state   startdate     enddate  \
# 0          11/8/16            U.S.   11/3/2016   11/6/2016
# 1          11/8/16            U.S.   11/1/2016   11/7/2016
# 2          11/8/16            U.S.   11/2/2016   11/6/2016
# 3          11/8/16            U.S.   11/4/2016   11/7/2016
# 4          11/8/16            U.S.   11/3/2016   11/6/2016
# 5          11/8/16            U.S.   11/3/2016   11/6/2016
# 6          11/8/16            U.S.   11/2/2016   11/6/2016
# 7          11/8/16            U.S.   11/3/2016   11/5/2016
# 8          11/8/16      New Mexico   11/6/2016   11/6/2016
# 9          11/8/16            U.S.   11/4/2016   11/7/2016
# 10         11/8/16            U.S.   11/4/2016   11/6/2016
# 11         11/8/16            U.S.   11/1/2016   11/4/2016
# 12         11/8/16            U.S.   11/3/2016   11/6/2016
# 13         11/8/16        Virginia   11/3/2016   11/4/2016
# 14         11/8/16            U.S.   11/1/2016   11/3/2016
# 15         11/8/16            Iowa   11/1/2016   11/4/2016
# 16         11/8/16            U.S.   11/5/2016   11/7/2016
# 17         11/8/16       Wisconsin  10/26/2016  10/31/2016
# 18         11/8/16  North Carolina   11/4/2016   11/6/2016
# 19         11/8/16         Georgia   11/6/2016   11/6/2016
# 20         11/8/16         Florida   11/3/2016   11/6/2016
# 21         11/8/16  North Carolina   11/3/2016   11/6/2016
# 22         11/8/16        Virginia  10/27/2016  10/30/2016
# 23         11/8/16            U.S.   11/1/2016   11/7/2016
# 24         11/8/16         Georgia   11/3/2016   11/6/2016
# 25         11/8/16          Oregon   11/3/2016   11/6/2016
# 26         11/8/16            U.S.   11/1/2016   11/5/2016
# 27         11/8/16            Ohio   11/3/2016   11/6/2016
# 28         11/8/16  South Carolina   11/3/2016   11/6/2016
# 29         11/8/16            Ohio   11/2/2016   11/4/2016
# ...            ...             ...         ...         ...
# 12594      11/8/16          Oregon  10/21/2016   11/2/2016
# 12595      11/8/16        Missouri   7/11/2016   7/12/2016
# 12596      11/8/16  North Carolina   2/14/2016   2/16/2016
# 12597      11/8/16         Georgia   9/30/2016   10/6/2016
# 12598      11/8/16        New York   2/28/2016    3/3/2016
# 12599      11/8/16            Iowa    1/2/2016    1/7/2016
# 12600      11/8/16            Utah    3/8/2016   3/15/2016
# 12601      11/8/16       Wisconsin   1/21/2016   1/24/2016
# 12602      11/8/16  North Carolina   3/18/2016   3/20/2016
# 12603      11/8/16       Wisconsin   3/24/2016   3/28/2016
# 12604      11/8/16            Utah   9/14/2016   9/20/2016
# 12605      11/8/16            Utah   3/23/2016    4/5/2016
# 12606      11/8/16   New Hampshire   6/22/2016   6/23/2016
# 12607      11/8/16        Michigan   7/30/2016    8/4/2016
# 12608      11/8/16       Wisconsin    7/7/2016   7/10/2016
# 12609      11/8/16        Michigan   3/19/2016   3/22/2016
# 12610      11/8/16            Utah   8/31/2016    9/6/2016
# 12611      11/8/16            Ohio    3/4/2016   3/10/2016
# 12612      11/8/16    South Dakota  10/28/2016   11/2/2016
# 12613      11/8/16            Utah   12/8/2015  12/14/2015
# 12614      11/8/16            Ohio    3/4/2016    3/6/2016
# 12615      11/8/16  North Carolina   9/27/2016   10/2/2016
# 12616      11/8/16         Florida   7/30/2016    8/7/2016
# 12617      11/8/16            Ohio   6/30/2016   7/11/2016
# 12618      11/8/16      New Jersey   9/30/2016   10/6/2016
# 12619      11/8/16   New Hampshire    7/9/2016   7/18/2016
# 12620      11/8/16       Wisconsin  10/21/2016   11/2/2016
# 12621      11/8/16        New York    8/7/2016   8/10/2016
# 12622      11/8/16        Virginia   9/30/2016   10/6/2016
# 12623      11/8/16       Wisconsin    6/9/2016   6/12/2016
#
#                                                 pollster grade  \
# 0                               ABC News/Washington Post    A+
# 1                                Google Consumer Surveys     B
# 2                                                  Ipsos    A-
# 3                                                 YouGov     B
# 4                                       Gravis Marketing    B-
# 5      Fox News/Anderson Robbins Research/Shaw & Comp...     A
# 6                                CBS News/New York Times    A-
# 7                           NBC News/Wall Street Journal    A-
# 8                                               Zia Poll   NaN
# 9                                               IBD/TIPP    A-
# 10                                      Selzer & Company    A+
# 11                                     Angus Reid Global    A-
# 12                                   Monmouth University    A+
# 13                                 Public Policy Polling    B+
# 14                                        Marist College     A
# 15                                      Selzer & Company    A+
# 16                              The Times-Picayune/Lucid   NaN
# 17                                  Marquette University     A
# 18                                         Siena College     A
# 19                               Landmark Communications     B
# 20                                 Quinnipiac University    A-
# 21                                 Quinnipiac University    A-
# 22                              ABC News/Washington Post    A+
# 23                                 USC Dornsife/LA Times   NaN
# 24                                      Gravis Marketing    B-
# 25                                      Gravis Marketing    B-
# 26                 RKM Research and Communications, Inc.    B+
# 27                                      Gravis Marketing    B-
# 28                                      Gravis Marketing    B-
# 29                                                YouGov     B
# ...                                                  ...   ...
# 12594                                              Ipsos    A-
# 12595                              Public Policy Polling    B+
# 12596                                          SurveyUSA     A
# 12597                                              Ipsos    A-
# 12598                                      Siena College     A
# 12599                                     Marist College     A
# 12600                             Dan Jones & Associates    C+
# 12601                               Marquette University     A
# 12602                              Public Policy Polling    B+
# 12603                               Marquette University     A
# 12604                            Google Consumer Surveys     B
# 12605                             Dan Jones & Associates    C+
# 12606                              Public Policy Polling    B+
# 12607                                           EPIC-MRA    A-
# 12608                               Marquette University     A
# 12609                                           EPIC-MRA    A-
# 12610                            Google Consumer Surveys     B
# 12611                                     Marist College     A
# 12612                                              Ipsos    A-
# 12613                             Dan Jones & Associates    C+
# 12614                              Public Policy Polling    B+
# 12615                              Quinnipiac University    A-
# 12616                              Quinnipiac University    A-
# 12617                              Quinnipiac University    A-
# 12618                                              Ipsos    A-
# 12619                        University of New Hampshire    B+
# 12620                                              Ipsos    A-
# 12621                                      Siena College     A
# 12622                                              Ipsos    A-
# 12623                               Marquette University     A
#
#                ...           adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 0              ...                  45.20163      41.72430         4.626221
# 1              ...                  43.34557      41.21439         5.175792
# 2              ...                  42.02638      38.81620         6.844734
# 3              ...                  45.65676      40.92004         6.069454
# 4              ...                  46.84089      42.33184         3.726098
# 5              ...                  49.02208      43.95631         3.057876
# 6              ...                  45.11649      40.92722         4.341786
# 7              ...                  43.58576      40.77325         5.365788
# 8              ...                  44.82594      41.59978         7.870127
# 9              ...                  42.92745      42.23545         6.316175
# 10             ...                  44.21714      40.57082         4.068708
# 11             ...                  47.57171      43.68125         5.556625
# 12             ...                  48.86765      43.39600         4.838600
# 13             ...                  47.43805      42.32751         2.207659
# 14             ...                  42.83406      43.43819         4.780429
# 15             ...                  39.37561      45.66917         6.062713
# 16             ...                  45.13966      42.26495         3.679914
# 17             ...                  46.10344      40.97982         2.897062
# 18             ...                  44.21875      45.08290         2.335250
# 19             ...                  45.06470      48.80363         3.662548
# 20             ...                  46.44315      43.93999         2.098310
# 21             ...                  47.43742      43.93745         3.098310
# 22             ...                  46.39152      41.58078         6.088089
# 23             ...                  45.32156      43.38579              NaN
# 24             ...                  43.83075      47.32734         3.726098
# 25             ...                  43.84735      39.33472         6.726098
# 26             ...                  47.63973      43.16080         4.761112
# 27             ...                  41.84073      47.33178         4.726098
# 28             ...                  42.83107      47.32748         3.726098
# 29             ...                  44.93624      45.09646              NaN
# ...            ...                       ...           ...              ...
# 12594          ...                  45.11995      37.05362              NaN
# 12595          ...                  39.01575      50.41441         4.301111
# 12596          ...                  40.09037      44.42975              NaN
# 12597          ...                  41.98283      48.59744              NaN
# 12598          ...                  57.06171      38.71300              NaN
# 12599          ...                  46.01621      42.04385              NaN
# 12600          ...                  34.87729      36.76365              NaN
# 12601          ...                  46.65142      40.51451              NaN
# 12602          ...                  42.17860      43.53845              NaN
# 12603          ...                  46.42534      40.70043              NaN
# 12604          ...                  35.62654      32.69339         4.461884
# 12605          ...                  35.92170      40.83069              NaN
# 12606          ...                  43.20015      41.24133              NaN
# 12607          ...                  46.52042      37.57217         3.997598
# 12608          ...                  46.10144      41.52320         3.993682
# 12609          ...                  45.86473      39.25798              NaN
# 12610          ...                  28.21282      37.15491        11.025770
# 12611          ...                  45.64849      45.32819              NaN
# 12612          ...                  26.55907      45.35574              NaN
# 12613          ...                  26.29225      33.43884              NaN
# 12614          ...                  42.87491      41.37695              NaN
# 12615          ...                  47.72989      44.98194         3.904715
# 12616          ...                  45.55449      46.36915         3.338913
# 12617          ...                  40.71486      42.31798         2.796137
# 12618          ...                  48.29913      35.40485              NaN
# 12619          ...                  40.24983      43.04717         6.924110
# 12620          ...                  46.54218      38.96884              NaN
# 12621          ...                  53.83622      32.47939         3.881193
# 12622          ...                  49.57558      39.96954              NaN
# 12623          ...                  46.40999      39.19839              NaN
#
#        adjpoll_mcmullin  multiversions  \
# 0                   NaN            NaN
# 1                   NaN            NaN
# 2                   NaN            NaN
# 3                   NaN            NaN
# 4                   NaN            NaN
# 5                   NaN            NaN
# 6                   NaN            NaN
# 7                   NaN            NaN
# 8                   NaN            NaN
# 9                   NaN            NaN
# 10                  NaN            NaN
# 11                  NaN            NaN
# 12                  NaN            NaN
# 13                  NaN            NaN
# 14                  NaN            NaN
# 15                  NaN            NaN
# 16                  NaN            NaN
# 17                  NaN            NaN
# 18                  NaN            NaN
# 19                  NaN            NaN
# 20                  NaN            NaN
# 21                  NaN            NaN
# 22                  NaN            NaN
# 23                  NaN            NaN
# 24                  NaN            NaN
# 25                  NaN            NaN
# 26                  NaN            NaN
# 27                  NaN            NaN
# 28                  NaN            NaN
# 29                  NaN            NaN
# ...                 ...            ...
# 12594               NaN            NaN
# 12595               NaN            NaN
# 12596               NaN            NaN
# 12597               NaN            NaN
# 12598               NaN            NaN
# 12599               NaN            NaN
# 12600               NaN            NaN
# 12601               NaN            NaN
# 12602               NaN            NaN
# 12603               NaN            NaN
# 12604               NaN            NaN
# 12605               NaN            NaN
# 12606               NaN            NaN
# 12607               NaN            NaN
# 12608               NaN            NaN
# 12609               NaN            NaN
# 12610               NaN            NaN
# 12611               NaN            NaN
# 12612               NaN            NaN
# 12613               NaN            NaN
# 12614               NaN            NaN
# 12615               NaN            NaN
# 12616               NaN            NaN
# 12617               NaN            NaN
# 12618               NaN            NaN
# 12619               NaN            NaN
# 12620               NaN            NaN
# 12621               NaN            NaN
# 12622               NaN            NaN
# 12623               NaN            NaN
#
#                                                      url  poll_id  \
# 0      https://www.washingtonpost.com/news/the-fix/wp...    48630
# 1      https://datastudio.google.com/u/0/#/org//repor...    48847
# 2      http://projects.fivethirtyeight.com/polls/2016...    48922
# 3      https://d25d2506sfb94s.cloudfront.net/cumulus_...    48687
# 4      http://www.gravispolls.com/2016/11/final-natio...    48848
# 5      http://www.foxnews.com/politics/2016/11/07/fox...    48619
# 6      http://www.cbsnews.com/news/cbs-news-poll-stat...    48521
# 7      http://www.nbcnews.com/storyline/2016-election...    48480
# 8      http://projects.fivethirtyeight.com.s3.amazona...    48614
# 9      http://www.investors.com/politics/ibd-tipp-pre...    48916
# 10     http://www.bloomberg.com/politics/articles/201...    48513
# 11     http://angusreid.org/wp-content/uploads/2016/1...    48626
# 12     https://www.monmouth.edu/polling-institute/rep...    48623
# 13     http://www.publicpolicypolling.com/pdf/2015/PP...    48349
# 14     http://www.mcclatchydc.com/news/politics-gover...    48362
# 15     http://www.desmoinesregister.com/story/news/po...    48470
# 16             https://luc.id/2016-presidential-tracker/    48771
# 17                         https://twitter.com/MULawPoll    48095
# 18     http://www.nytimes.com/2016/11/08/upshot/trump...    48524
# 19     http://landmarkcommunications.net/landmarkrose...    48525
# 20     https://poll.qu.edu/2016-presidential-swing-st...    48522
# 21     https://poll.qu.edu/2016-presidential-swing-st...    48523
# 22     https://www.washingtonpost.com/local/virginia-...    47880
# 23                          http://latimes.com/politics/    48917
# 24     http://www.gravispolls.com/2016/11/multi-state...    48852
# 25     http://www.gravispolls.com/2016/11/multi-state...    48855
# 26     http://www.bostonherald.com/news/local_coverag...    48509
# 27     http://www.gravispolls.com/2016/11/multi-state...    48854
# 28     http://www.gravispolls.com/2016/11/multi-state...    48857
# 29     https://d25d2506sfb94s.cloudfront.net/cumulus_...    48481
# ...                                                  ...      ...
# 12594          http://www.reuters.com/statesofthenation/    48248
# 12595  http://www.publicpolicypolling.com/pdf/2015/PP...    44598
# 12596  http://www.surveyusa.com/client/PollReport.asp...    36380
# 12597          http://www.reuters.com/statesofthenation/    46641
# 12598  http://big.assets.huffingtonpost.com/SienaPoll...    36549
# 12599  http://msnbcmedia.msn.com/i/MSNBC/Sections/A_P...    35805
# 12600           http://www.ksl.com/?sid=38970451&nid=960    36635
# 12601  https://law.marquette.edu/poll/2016/01/28/new-...    35995
# 12602  http://www.publicpolicypolling.com/pdf/2015/PP...    36645
# 12603  https://law.marquette.edu/poll/2016/03/30/new-...    36667
# 12604  https://datastudio.google.com/u/0/#/org//repor...    45992
# 12605  http://utahpolicy.com/index.php/features/today...    42187
# 12606  http://www.americansunitedforchange.org/page/-...    44434
# 12607  http://www.freep.com/story/news/politics/2016/...    44775
# 12608  https://law.marquette.edu/poll/2016/07/13/new-...    44576
# 12609  http://www.epicmra.com/press/Stwd_Survey_Mar20...    36710
# 12610  https://drive.google.com/drive/u/0/folders/0B2...    45483
# 12611  http://maristpoll.marist.edu/313-trump-ahead-i...    36598
# 12612          http://www.reuters.com/statesofthenation/    48251
# 12613  http://utahpolicy.com/index.php/features/today...    35846
# 12614  http://www.publicpolicypolling.com/pdf/2015/PP...    36554
# 12615  https://www.qu.edu/news-and-events/quinnipiac-...    46382
# 12616  https://drive.google.com/file/d/0B1XFXSmJVNknN...    44806
# 12617  http://www.qu.edu/news-and-events/quinnipiac-u...    44566
# 12618          http://www.reuters.com/statesofthenation/    46660
# 12619  https://cola.unh.edu/sites/cola.unh.edu/files/...    44650
# 12620          http://www.reuters.com/statesofthenation/    48259
# 12621  https://www.siena.edu/assets/files/news/SNY081...    44852
# 12622          http://www.reuters.com/statesofthenation/    46675
# 12623  https://law.marquette.edu/poll/2016/06/15/new-...    44341
#
#        question_id  createddate             timestamp
# 0            76192      11/7/16  09:35:33  8 Nov 2016
# 1            76443      11/7/16  09:35:33  8 Nov 2016
# 2            76636      11/8/16  09:35:33  8 Nov 2016
# 3            76262      11/7/16  09:35:33  8 Nov 2016
# 4            76444      11/7/16  09:35:33  8 Nov 2016
# 5            76163      11/7/16  09:35:33  8 Nov 2016
# 6            76058      11/7/16  09:35:33  8 Nov 2016
# 7            75974      11/6/16  09:35:33  8 Nov 2016
# 8            76158      11/7/16  09:35:33  8 Nov 2016
# 9            76611      11/8/16  09:35:33  8 Nov 2016
# 10           76036      11/7/16  09:35:33  8 Nov 2016
# 11           76181      11/7/16  09:35:33  8 Nov 2016
# 12           76176      11/7/16  09:35:33  8 Nov 2016
# 13           75743      11/4/16  09:35:33  8 Nov 2016
# 14           75818      11/4/16  09:35:33  8 Nov 2016
# 15           75957      11/5/16  09:35:33  8 Nov 2016
# 16           76354      11/7/16  09:35:33  8 Nov 2016
# 17           75264      11/2/16  09:35:33  8 Nov 2016
# 18           76066      11/7/16  09:35:33  8 Nov 2016
# 19           76068      11/7/16  09:35:33  8 Nov 2016
# 20           76060      11/7/16  09:35:33  8 Nov 2016
# 21           76062      11/7/16  09:35:33  8 Nov 2016
# 22           74934      11/1/16  09:35:33  8 Nov 2016
# 23           76612      11/8/16  09:35:33  8 Nov 2016
# 24           76448      11/7/16  09:35:33  8 Nov 2016
# 25           76451      11/7/16  09:35:33  8 Nov 2016
# 26           76029      11/7/16  09:35:33  8 Nov 2016
# 27           76450      11/7/16  09:35:33  8 Nov 2016
# 28           76453      11/7/16  09:35:33  8 Nov 2016
# 29           75977      11/6/16  09:35:33  8 Nov 2016
# ...            ...          ...                   ...
# 12594        75549      11/3/16  09:14:14  8 Nov 2016
# 12595        67974      7/15/16  09:14:14  8 Nov 2016
# 12596        65582       5/5/16  09:14:14  8 Nov 2016
# 12597        72935     10/10/16  09:14:14  8 Nov 2016
# 12598        65553       5/5/16  09:14:14  8 Nov 2016
# 12599        48036      1/10/16  09:14:14  8 Nov 2016
# 12600        66119       6/2/16  09:14:14  8 Nov 2016
# 12601        48825      1/28/16  09:14:14  8 Nov 2016
# 12602        50328      3/23/16  09:14:14  8 Nov 2016
# 12603        50543       4/8/16  09:14:14  8 Nov 2016
# 12604        71879      9/22/16  09:14:14  8 Nov 2016
# 12605        65686       5/5/16  09:14:14  8 Nov 2016
# 12606        67455      6/27/16  09:14:14  8 Nov 2016
# 12607        68543       8/5/16  09:14:14  8 Nov 2016
# 12608        67930      7/13/16  09:14:14  8 Nov 2016
# 12609        50556       4/8/16  09:14:14  8 Nov 2016
# 12610        70801       9/9/16  09:14:14  8 Nov 2016
# 12611        65505       5/5/16  09:14:14  8 Nov 2016
# 12612        75552      11/3/16  09:14:14  8 Nov 2016
# 12613        48191      1/14/16  09:14:14  8 Nov 2016
# 12614        50193      3/11/16  09:14:14  8 Nov 2016
# 12615        72511      10/3/16  09:14:14  8 Nov 2016
# 12616        68629       8/9/16  09:14:14  8 Nov 2016
# 12617        67906      7/13/16  09:14:14  8 Nov 2016
# 12618        72954     10/10/16  09:14:14  8 Nov 2016
# 12619        68189      7/21/16  09:14:14  8 Nov 2016
# 12620        75560      11/3/16  09:14:14  8 Nov 2016
# 12621        68743      8/15/16  09:14:14  8 Nov 2016
# 12622        72969     10/10/16  09:14:14  8 Nov 2016
# 12623        66966      6/15/16  09:14:14  8 Nov 2016
#
# [12624 rows x 27 columns]

# %% [markdown]
# To ensure that the data are comparable, check whether all the results are for the same election cycle, branch of government, type, forecastdate, and most importantly, the same matchup of candidates! Table the data to make sure that this is indead the case.

# %%
# ---
# add your code here

print(polls.groupby('cycle')['cycle'].count(),'\n')
print(polls.groupby('branch')['cycle'].count(),'\n')
print(polls.groupby('type')['cycle'].count(),'\n')
print(polls.groupby('matchup')['cycle'].count(),'\n')
print(polls.groupby('forecastdate')['cycle'].count(),'\n')
print(polls.groupby('cycle')['cycle'].count(),'\n')

# ---
# Out:
# cycle
# 2016    12624
# Name: cycle, dtype: int64
#
# branch
# President    12624
# Name: cycle, dtype: int64
#
# type
# now-cast      4208
# polls-only    4208
# polls-plus    4208
# Name: cycle, dtype: int64
#
# matchup
# Clinton vs. Trump vs. Johnson    12624
# Name: cycle, dtype: int64
#
# forecastdate
# 11/8/16    12624
# Name: cycle, dtype: int64
#
# cycle
# 2016    12624
# Name: cycle, dtype: int64

# %% [markdown]
# This seems mostly ok. But what's up with type? Turns out that each poll is included three times:

# %%
polls.groupby('poll_id')['cycle'].count()

# %% [markdown]
# We'll have to change that. The next step is filtering the data!
#
# Use pandas amazing data-slizing ability to generate `polls_filtered` such that:
# - only `polls-only` are included
# - only polls with information on sample size are included
# - national polls (`state` = 'U.S.') are excluded
# - Main and Nebraska have split electoral votes. Make sure to include only polls for the entire state.

# %%
# ---
# add your code here

polls_filtered = polls[(polls.type == 'polls-only') & (-polls.samplesize.isnull()) & (polls.state != 'U.S.') & (-polls.state.str.contains('CD-'))]

# ---

# %% [markdown]
# Let's see:

# %%
polls_filtered
# Out:
#        cycle     branch        type                        matchup  \
# 8424    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8429    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8431    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8433    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8434    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8435    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8436    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8437    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8438    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8440    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8441    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8443    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8444    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8445    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8446    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8447    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8448    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8449    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8450    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8451    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8452    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8453    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8454    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8455    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8456    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8457    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8458    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8460    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8461    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8463    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12594   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12595   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12596   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12597   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12598   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12599   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12600   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12601   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12602   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12603   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12604   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12605   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12606   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12607   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12608   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12609   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12610   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12611   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12612   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12613   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12614   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12615   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12616   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12617   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12618   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate           state   startdate     enddate  \
# 8424       11/8/16      New Mexico   11/6/2016   11/6/2016
# 8429       11/8/16        Virginia   11/3/2016   11/4/2016
# 8431       11/8/16            Iowa   11/1/2016   11/4/2016
# 8433       11/8/16       Wisconsin  10/26/2016  10/31/2016
# 8434       11/8/16  North Carolina   11/4/2016   11/6/2016
# 8435       11/8/16         Georgia   11/6/2016   11/6/2016
# 8436       11/8/16         Florida   11/3/2016   11/6/2016
# 8437       11/8/16  North Carolina   11/3/2016   11/6/2016
# 8438       11/8/16        Virginia  10/27/2016  10/30/2016
# 8440       11/8/16         Georgia   11/3/2016   11/6/2016
# 8441       11/8/16          Oregon   11/3/2016   11/6/2016
# 8443       11/8/16            Ohio   11/3/2016   11/6/2016
# 8444       11/8/16  South Carolina   11/3/2016   11/6/2016
# 8445       11/8/16            Ohio   11/2/2016   11/4/2016
# 8446       11/8/16        Virginia   11/1/2016   11/2/2016
# 8447       11/8/16        New York   11/3/2016   11/6/2016
# 8448       11/8/16        Michigan   11/3/2016   11/4/2016
# 8449       11/8/16  North Carolina  10/31/2016   11/1/2016
# 8450       11/8/16       Wisconsin   11/1/2016   11/2/2016
# 8451       11/8/16    Pennsylvania   11/1/2016   11/2/2016
# 8452       11/8/16        Virginia   11/1/2016   11/6/2016
# 8453       11/8/16  North Carolina   11/1/2016   11/2/2016
# 8454       11/8/16            Ohio   11/1/2016   11/2/2016
# 8455       11/8/16         Georgia   11/3/2016   11/5/2016
# 8456       11/8/16        Missouri  10/31/2016   11/1/2016
# 8457       11/8/16   New Hampshire   11/4/2016   11/5/2016
# 8458       11/8/16         Arizona   11/3/2016   11/6/2016
# 8460       11/8/16         Florida   11/1/2016   11/2/2016
# 8461       11/8/16    Pennsylvania  10/31/2016   11/1/2016
# 8463       11/8/16    Pennsylvania   11/3/2016   11/5/2016
# ...            ...             ...         ...         ...
# 12594      11/8/16          Oregon  10/21/2016   11/2/2016
# 12595      11/8/16        Missouri   7/11/2016   7/12/2016
# 12596      11/8/16  North Carolina   2/14/2016   2/16/2016
# 12597      11/8/16         Georgia   9/30/2016   10/6/2016
# 12598      11/8/16        New York   2/28/2016    3/3/2016
# 12599      11/8/16            Iowa    1/2/2016    1/7/2016
# 12600      11/8/16            Utah    3/8/2016   3/15/2016
# 12601      11/8/16       Wisconsin   1/21/2016   1/24/2016
# 12602      11/8/16  North Carolina   3/18/2016   3/20/2016
# 12603      11/8/16       Wisconsin   3/24/2016   3/28/2016
# 12604      11/8/16            Utah   9/14/2016   9/20/2016
# 12605      11/8/16            Utah   3/23/2016    4/5/2016
# 12606      11/8/16   New Hampshire   6/22/2016   6/23/2016
# 12607      11/8/16        Michigan   7/30/2016    8/4/2016
# 12608      11/8/16       Wisconsin    7/7/2016   7/10/2016
# 12609      11/8/16        Michigan   3/19/2016   3/22/2016
# 12610      11/8/16            Utah   8/31/2016    9/6/2016
# 12611      11/8/16            Ohio    3/4/2016   3/10/2016
# 12612      11/8/16    South Dakota  10/28/2016   11/2/2016
# 12613      11/8/16            Utah   12/8/2015  12/14/2015
# 12614      11/8/16            Ohio    3/4/2016    3/6/2016
# 12615      11/8/16  North Carolina   9/27/2016   10/2/2016
# 12616      11/8/16         Florida   7/30/2016    8/7/2016
# 12617      11/8/16            Ohio   6/30/2016   7/11/2016
# 12618      11/8/16      New Jersey   9/30/2016   10/6/2016
# 12619      11/8/16   New Hampshire    7/9/2016   7/18/2016
# 12620      11/8/16       Wisconsin  10/21/2016   11/2/2016
# 12621      11/8/16        New York    8/7/2016   8/10/2016
# 12622      11/8/16        Virginia   9/30/2016   10/6/2016
# 12623      11/8/16       Wisconsin    6/9/2016   6/12/2016
#
#                              pollster grade          ...           \
# 8424                         Zia Poll   NaN          ...
# 8429            Public Policy Polling    B+          ...
# 8431                 Selzer & Company    A+          ...
# 8433             Marquette University     A          ...
# 8434                    Siena College     A          ...
# 8435          Landmark Communications     B          ...
# 8436            Quinnipiac University    A-          ...
# 8437            Quinnipiac University    A-          ...
# 8438         ABC News/Washington Post    A+          ...
# 8440                 Gravis Marketing    B-          ...
# 8441                 Gravis Marketing    B-          ...
# 8443                 Gravis Marketing    B-          ...
# 8444                 Gravis Marketing    B-          ...
# 8445                           YouGov     B          ...
# 8446                        Remington   NaN          ...
# 8447                 Gravis Marketing    B-          ...
# 8448            Public Policy Polling    B+          ...
# 8449            Public Policy Polling    B+          ...
# 8450                        Remington   NaN          ...
# 8451                        Remington   NaN          ...
# 8452   Christopher Newport University    B-          ...
# 8453                        Remington   NaN          ...
# 8454                        Remington   NaN          ...
# 8455                           YouGov     B          ...
# 8456            Public Policy Polling    B+          ...
# 8457                  Emerson College     B          ...
# 8458                 Gravis Marketing    B-          ...
# 8460                        Remington   NaN          ...
# 8461            Public Policy Polling    B+          ...
# 8463                           YouGov     B          ...
# ...                               ...   ...          ...
# 12594                           Ipsos    A-          ...
# 12595           Public Policy Polling    B+          ...
# 12596                       SurveyUSA     A          ...
# 12597                           Ipsos    A-          ...
# 12598                   Siena College     A          ...
# 12599                  Marist College     A          ...
# 12600          Dan Jones & Associates    C+          ...
# 12601            Marquette University     A          ...
# 12602           Public Policy Polling    B+          ...
# 12603            Marquette University     A          ...
# 12604         Google Consumer Surveys     B          ...
# 12605          Dan Jones & Associates    C+          ...
# 12606           Public Policy Polling    B+          ...
# 12607                        EPIC-MRA    A-          ...
# 12608            Marquette University     A          ...
# 12609                        EPIC-MRA    A-          ...
# 12610         Google Consumer Surveys     B          ...
# 12611                  Marist College     A          ...
# 12612                           Ipsos    A-          ...
# 12613          Dan Jones & Associates    C+          ...
# 12614           Public Policy Polling    B+          ...
# 12615           Quinnipiac University    A-          ...
# 12616           Quinnipiac University    A-          ...
# 12617           Quinnipiac University    A-          ...
# 12618                           Ipsos    A-          ...
# 12619     University of New Hampshire    B+          ...
# 12620                           Ipsos    A-          ...
# 12621                   Siena College     A          ...
# 12622                           Ipsos    A-          ...
# 12623            Marquette University     A          ...
#
#        adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 8424          45.03026      41.83415         8.034579               NaN
# 8429          47.45132      42.32406         2.164561               NaN
# 8431          39.49021      45.61412         6.009565               NaN
# 8433          46.12806      40.94420         2.939782               NaN
# 8434          44.26774      45.04665         2.408998               NaN
# 8435          45.23540      48.68394         3.665207               NaN
# 8436          46.39114      44.03355         1.978985               NaN
# 8437          47.38561      44.03075         2.978985               NaN
# 8438          46.40351      41.57526         6.069753               NaN
# 8440          43.82129      47.27258         3.749071               NaN
# 8441          43.83731      39.28070         6.749071               NaN
# 8443          41.83092      47.27746         4.749071               NaN
# 8444          42.82159      47.27274         3.749071               NaN
# 8445          44.95264      45.07981              NaN               NaN
# 8446          45.23189      41.89108              NaN               NaN
# 8447          54.83209      35.27805         2.749071               NaN
# 8448          45.45853      40.32777         7.164561               NaN
# 8449          47.92299      45.95507              NaN               NaN
# 8450          48.18295      38.84011              NaN               NaN
# 8451          45.25945      42.91885              NaN               NaN
# 8452          48.89921      43.55269         2.077036               NaN
# 8453          44.36333      46.02362              NaN               NaN
# 8454          42.98589      42.64419              NaN               NaN
# 8455          43.82939      48.97638         5.218912               NaN
# 8456          36.56333      49.59931         4.986115               NaN
# 8457          45.29993      41.82134         4.713688               NaN
# 8458          42.83298      44.27851         3.749071               NaN
# 8460          44.81810      46.47661              NaN               NaN
# 8461          46.81950      42.85442              NaN               NaN
# 8463          45.84151      42.98263         5.218912               NaN
# ...                ...           ...              ...               ...
# 12594         45.11995      37.05362              NaN               NaN
# 12595         39.01575      50.41441         4.301111               NaN
# 12596         40.09037      44.42975              NaN               NaN
# 12597         41.98283      48.59744              NaN               NaN
# 12598         57.06171      38.71300              NaN               NaN
# 12599         46.01621      42.04385              NaN               NaN
# 12600         34.87729      36.76365              NaN               NaN
# 12601         46.65142      40.51451              NaN               NaN
# 12602         42.17860      43.53845              NaN               NaN
# 12603         46.42534      40.70043              NaN               NaN
# 12604         35.62654      32.69339         4.461884               NaN
# 12605         35.92170      40.83069              NaN               NaN
# 12606         43.20015      41.24133              NaN               NaN
# 12607         46.52042      37.57217         3.997598               NaN
# 12608         46.10144      41.52320         3.993682               NaN
# 12609         45.86473      39.25798              NaN               NaN
# 12610         28.21282      37.15491        11.025770               NaN
# 12611         45.64849      45.32819              NaN               NaN
# 12612         26.55907      45.35574              NaN               NaN
# 12613         26.29225      33.43884              NaN               NaN
# 12614         42.87491      41.37695              NaN               NaN
# 12615         47.72989      44.98194         3.904715               NaN
# 12616         45.55449      46.36915         3.338913               NaN
# 12617         40.71486      42.31798         2.796137               NaN
# 12618         48.29913      35.40485              NaN               NaN
# 12619         40.24983      43.04717         6.924110               NaN
# 12620         46.54218      38.96884              NaN               NaN
# 12621         53.83622      32.47939         3.881193               NaN
# 12622         49.57558      39.96954              NaN               NaN
# 12623         46.40999      39.19839              NaN               NaN
#
#        multiversions                                                url  \
# 8424             NaN  http://projects.fivethirtyeight.com.s3.amazona...
# 8429             NaN  http://www.publicpolicypolling.com/pdf/2015/PP...
# 8431             NaN  http://www.desmoinesregister.com/story/news/po...
# 8433             NaN                      https://twitter.com/MULawPoll
# 8434             NaN  http://www.nytimes.com/2016/11/08/upshot/trump...
# 8435             NaN  http://landmarkcommunications.net/landmarkrose...
# 8436             NaN  https://poll.qu.edu/2016-presidential-swing-st...
# 8437             NaN  https://poll.qu.edu/2016-presidential-swing-st...
# 8438             NaN  https://www.washingtonpost.com/local/virginia-...
# 8440             NaN  http://www.gravispolls.com/2016/11/multi-state...
# 8441             NaN  http://www.gravispolls.com/2016/11/multi-state...
# 8443             NaN  http://www.gravispolls.com/2016/11/multi-state...
# 8444             NaN  http://www.gravispolls.com/2016/11/multi-state...
# 8445             NaN  https://d25d2506sfb94s.cloudfront.net/cumulus_...
# 8446             NaN  http://docs.axiomstrategies.com/wp-content/upl...
# 8447             NaN  http://www.gravispolls.com/2016/11/multi-state...
# 8448             NaN  http://www.publicpolicypolling.com/pdf/2015/PP...
# 8449             NaN  https://cdn.americanprogress.org/content/uploa...
# 8450             NaN  http://docs.axiomstrategies.com/wp-content/upl...
# 8451             NaN  http://docs.axiomstrategies.com/wp-content/upl...
# 8452             NaN  http://www.nbc12.com/story/33645067/poll-clint...
# 8453             NaN  http://docs.axiomstrategies.com/wp-content/upl...
# 8454             NaN  http://docs.axiomstrategies.com/wp-content/upl...
# 8455             NaN  https://today.yougov.com/news/2016/11/07/yougo...
# 8456             NaN  http://images.campaignpartner.net/images/15290...
# 8457             NaN  projects.fivethirtyeight.com/polls/20161107_Sw...
# 8458             NaN  http://www.gravispolls.com/2016/11/multi-state...
# 8460             NaN  http://docs.axiomstrategies.com/wp-content/upl...
# 8461             NaN  https://cdn.americanprogress.org/content/uploa...
# 8463             NaN  https://today.yougov.com/news/2016/11/07/yougo...
# ...              ...                                                ...
# 12594            NaN          http://www.reuters.com/statesofthenation/
# 12595            NaN  http://www.publicpolicypolling.com/pdf/2015/PP...
# 12596            NaN  http://www.surveyusa.com/client/PollReport.asp...
# 12597            NaN          http://www.reuters.com/statesofthenation/
# 12598            NaN  http://big.assets.huffingtonpost.com/SienaPoll...
# 12599            NaN  http://msnbcmedia.msn.com/i/MSNBC/Sections/A_P...
# 12600            NaN           http://www.ksl.com/?sid=38970451&nid=960
# 12601            NaN  https://law.marquette.edu/poll/2016/01/28/new-...
# 12602            NaN  http://www.publicpolicypolling.com/pdf/2015/PP...
# 12603            NaN  https://law.marquette.edu/poll/2016/03/30/new-...
# 12604            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 12605            NaN  http://utahpolicy.com/index.php/features/today...
# 12606            NaN  http://www.americansunitedforchange.org/page/-...
# 12607            NaN  http://www.freep.com/story/news/politics/2016/...
# 12608            NaN  https://law.marquette.edu/poll/2016/07/13/new-...
# 12609            NaN  http://www.epicmra.com/press/Stwd_Survey_Mar20...
# 12610            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 12611            NaN  http://maristpoll.marist.edu/313-trump-ahead-i...
# 12612            NaN          http://www.reuters.com/statesofthenation/
# 12613            NaN  http://utahpolicy.com/index.php/features/today...
# 12614            NaN  http://www.publicpolicypolling.com/pdf/2015/PP...
# 12615            NaN  https://www.qu.edu/news-and-events/quinnipiac-...
# 12616            NaN  https://drive.google.com/file/d/0B1XFXSmJVNknN...
# 12617            NaN  http://www.qu.edu/news-and-events/quinnipiac-u...
# 12618            NaN          http://www.reuters.com/statesofthenation/
# 12619            NaN  https://cola.unh.edu/sites/cola.unh.edu/files/...
# 12620            NaN          http://www.reuters.com/statesofthenation/
# 12621            NaN  https://www.siena.edu/assets/files/news/SNY081...
# 12622            NaN          http://www.reuters.com/statesofthenation/
# 12623            NaN  https://law.marquette.edu/poll/2016/06/15/new-...
#
#        poll_id  question_id  createddate             timestamp
# 8424     48614        76158      11/7/16  09:14:14  8 Nov 2016
# 8429     48349        75743      11/4/16  09:14:14  8 Nov 2016
# 8431     48470        75957      11/5/16  09:14:14  8 Nov 2016
# 8433     48095        75264      11/2/16  09:14:14  8 Nov 2016
# 8434     48524        76066      11/7/16  09:14:14  8 Nov 2016
# 8435     48525        76068      11/7/16  09:14:14  8 Nov 2016
# 8436     48522        76060      11/7/16  09:14:14  8 Nov 2016
# 8437     48523        76062      11/7/16  09:14:14  8 Nov 2016
# 8438     47880        74934      11/1/16  09:14:14  8 Nov 2016
# 8440     48852        76448      11/7/16  09:14:14  8 Nov 2016
# 8441     48855        76451      11/7/16  09:14:14  8 Nov 2016
# 8443     48854        76450      11/7/16  09:14:14  8 Nov 2016
# 8444     48857        76453      11/7/16  09:14:14  8 Nov 2016
# 8445     48481        75977      11/6/16  09:14:14  8 Nov 2016
# 8446     48494        76000      11/6/16  09:14:14  8 Nov 2016
# 8447     48853        76449      11/7/16  09:14:14  8 Nov 2016
# 8448     48348        75741      11/4/16  09:14:14  8 Nov 2016
# 8449     48326        75699      11/4/16  09:14:14  8 Nov 2016
# 8450     48495        76001      11/6/16  09:14:14  8 Nov 2016
# 8451     48493        75999      11/6/16  09:14:14  8 Nov 2016
# 8452     48512        76034      11/7/16  09:14:14  8 Nov 2016
# 8453     48491        75997      11/6/16  09:14:14  8 Nov 2016
# 8454     48492        75998      11/6/16  09:14:14  8 Nov 2016
# 8455     48682        76245      11/7/16  09:14:14  8 Nov 2016
# 8456     48119        75343      11/2/16  09:14:14  8 Nov 2016
# 8457     48519        76055      11/7/16  09:14:14  8 Nov 2016
# 8458     48851        76447      11/7/16  09:14:14  8 Nov 2016
# 8460     48489        75995      11/6/16  09:14:14  8 Nov 2016
# 8461     48329        75702      11/4/16  09:14:14  8 Nov 2016
# 8463     48683        76246      11/7/16  09:14:14  8 Nov 2016
# ...        ...          ...          ...                   ...
# 12594    48248        75549      11/3/16  09:14:14  8 Nov 2016
# 12595    44598        67974      7/15/16  09:14:14  8 Nov 2016
# 12596    36380        65582       5/5/16  09:14:14  8 Nov 2016
# 12597    46641        72935     10/10/16  09:14:14  8 Nov 2016
# 12598    36549        65553       5/5/16  09:14:14  8 Nov 2016
# 12599    35805        48036      1/10/16  09:14:14  8 Nov 2016
# 12600    36635        66119       6/2/16  09:14:14  8 Nov 2016
# 12601    35995        48825      1/28/16  09:14:14  8 Nov 2016
# 12602    36645        50328      3/23/16  09:14:14  8 Nov 2016
# 12603    36667        50543       4/8/16  09:14:14  8 Nov 2016
# 12604    45992        71879      9/22/16  09:14:14  8 Nov 2016
# 12605    42187        65686       5/5/16  09:14:14  8 Nov 2016
# 12606    44434        67455      6/27/16  09:14:14  8 Nov 2016
# 12607    44775        68543       8/5/16  09:14:14  8 Nov 2016
# 12608    44576        67930      7/13/16  09:14:14  8 Nov 2016
# 12609    36710        50556       4/8/16  09:14:14  8 Nov 2016
# 12610    45483        70801       9/9/16  09:14:14  8 Nov 2016
# 12611    36598        65505       5/5/16  09:14:14  8 Nov 2016
# 12612    48251        75552      11/3/16  09:14:14  8 Nov 2016
# 12613    35846        48191      1/14/16  09:14:14  8 Nov 2016
# 12614    36554        50193      3/11/16  09:14:14  8 Nov 2016
# 12615    46382        72511      10/3/16  09:14:14  8 Nov 2016
# 12616    44806        68629       8/9/16  09:14:14  8 Nov 2016
# 12617    44566        67906      7/13/16  09:14:14  8 Nov 2016
# 12618    46660        72954     10/10/16  09:14:14  8 Nov 2016
# 12619    44650        68189      7/21/16  09:14:14  8 Nov 2016
# 12620    48259        75560      11/3/16  09:14:14  8 Nov 2016
# 12621    44852        68743      8/15/16  09:14:14  8 Nov 2016
# 12622    46675        72969     10/10/16  09:14:14  8 Nov 2016
# 12623    44341        66966      6/15/16  09:14:14  8 Nov 2016
#
# [3072 rows x 27 columns]

# %% [markdown]
# Finally we have to aggregate the data so that we can merge it on the day and state. There are many possibilities and there's going to be an element of subjective judgement. Here's one way:
#
# - `date`: There's a start date and an end date. We deal with this by calculating the number of days that the poll run for and assuming that the same number of repondents participated on each day.
# - `state`: There can be multiple polls in the same state and on the same day. We deal with this by calculating a weighted average based on the (estimated) sample size of each poll on that date.
#
# Step by step:
# 1. copy the `polls_filtere` to a new dataframe `df`. We don't want to make a mess!
# 2. calculate the number of days that the poll ran for from `startdate` and `enddate`.
# 3. calculate `samplesize_day` by dividing `samplesize` by the number of days.
# 4. expand the dataframe such that each observation is included `days` time.
# 5. generate a variable `date` with the ficticious polling date.
# 6. aggregate the data by date and state such that `rawpoll_clinton`, `rawpoll_trump`, `adjpoll_clinton` and `adjpoll_trump` are averages weighted by the sample size, and `samplesize` is the sum of the daily sample sizes.

# %%
# ---
# add your code here

df = polls_filtered.copy()

df['days'] = pd.to_datetime(df['enddate']) - pd.to_datetime(df['startdate']) + pd.offsets.Day(1)
df['days'] = df['days'].dt.days

df['samplesize_day'] = df['samplesize'] / df['days']

import numpy as np
df = df.reindex(np.repeat(df.index, df['days'])).reset_index(drop=True)

df['n'] = df.groupby('poll_id').cumcount() + 1
df['date'] = pd.to_datetime(df['startdate']) + pd.to_timedelta(df['n'], unit='D')
df['date'] = df['date'].astype(str)

wm = lambda x: np.average(x, weights=df.loc[x.index, "samplesize_day"])
f = {'samplesize_day': ['sum'], 
     'rawpoll_clinton': {'weighted_mean' : wm}, 
     'rawpoll_trump': {'weighted_mean' : wm}, 
     'adjpoll_clinton': {'weighted_mean' : wm}, 
     'adjpoll_trump': {'weighted_mean' : wm}
    }

df = df.groupby(["date", "state"]).agg(f)
df.columns = ['samplesize', 'rawpoll_clinton', 'rawpoll_trump', 'adjpoll_clinton', 'adjpoll_trump']
# ---
# Out:
# /Users/czuend/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %% [markdown]
# Let's check the results:

# %%
poll_data = df.copy()
poll_data
# Out:
#                            samplesize_day  rawpoll_clinton  rawpoll_trump  \
# date       state
# 2015-11-07 New Hampshire        48.181818        45.000000      38.000000
# 2015-11-08 New Hampshire        48.181818        45.000000      38.000000
#            South Carolina      645.000000        42.000000      47.000000
# 2015-11-09 New Hampshire        48.181818        45.000000      38.000000
#            South Carolina      645.000000        42.000000      47.000000
# 2015-11-10 New Hampshire        48.181818        45.000000      38.000000
#            Virginia            111.000000        50.000000      36.000000
# 2015-11-11 Iowa                 91.571429        41.000000      40.000000
#            Nevada               89.714286        41.000000      44.000000
#            New Hampshire        48.181818        45.000000      38.000000
#            South Carolina       89.571429        41.000000      44.000000
#            Virginia            111.000000        50.000000      36.000000
# 2015-11-12 Colorado            252.400000        37.000000      48.000000
#            Iowa                 91.571429        41.000000      40.000000
#            Nevada               89.714286        41.000000      44.000000
#            New Hampshire        48.181818        45.000000      38.000000
#            South Carolina       89.571429        41.000000      44.000000
#            Virginia            111.000000        50.000000      36.000000
# 2015-11-13 Colorado            252.400000        37.000000      48.000000
#            Iowa                 91.571429        41.000000      40.000000
#            Nevada               89.714286        41.000000      44.000000
#            New Hampshire        48.181818        45.000000      38.000000
#            South Carolina       89.571429        41.000000      44.000000
#            Virginia            111.000000        50.000000      36.000000
#            Wisconsin           200.750000        48.000000      38.000000
# 2015-11-14 Colorado            252.400000        37.000000      48.000000
#            Iowa                 91.571429        41.000000      40.000000
#            Nevada               89.714286        41.000000      44.000000
#            New Hampshire        48.181818        45.000000      38.000000
#            South Carolina       89.571429        41.000000      44.000000
# ...                                   ...              ...            ...
# 2016-11-08 Massachusetts       277.142857        53.636124      28.809371
#            Michigan            566.571429        42.174175      40.354274
#            Minnesota           283.857143        42.274912      36.334726
#            Mississippi         144.285714        37.107743      50.662673
#            Missouri            297.857143        39.071511      43.680806
#            Montana              91.714286        31.388879      46.877383
#            Nebraska            179.142857        34.009394      49.740909
#            Nevada              209.428571        43.413492      42.114877
#            New Hampshire       115.000000        46.861888      37.081963
#            New Jersey          341.285714        46.649828      35.123416
#            New Mexico          144.285714        40.651208      35.914584
#            New York            502.285714        50.612526      32.479898
#            North Carolina      560.000000        45.372913      40.929107
#            North Dakota         62.142857        27.137747      54.268322
#            Ohio                561.428571        40.102316      43.143155
#            Oklahoma            217.000000        31.141224      54.769796
#            Oregon              299.571429        48.791082      32.931674
#            Pennsylvania        574.571429        43.568158      41.329023
#            Rhode Island         70.857143        46.806230      33.893347
#            South Carolina      305.428571        40.717680      46.695416
#            South Dakota         84.000000        32.763469      49.345000
#            Tennessee           275.285714        39.259336      47.802813
#            Texas               594.857143        40.029287      45.023631
#            Utah                252.142857        29.433076      34.170142
#            Vermont              78.428571        59.463388      23.937523
#            Virginia            421.142857        46.488060      38.589264
#            Washington          304.714286        48.336587      32.178275
#            West Virginia        87.000000        28.165402      54.998933
#            Wisconsin           451.428571        43.759930      38.832816
#            Wyoming              46.571429        22.400368      55.525061
#
#                            adjpoll_clinton  adjpoll_trump
# date       state
# 2015-11-07 New Hampshire         45.641840      39.072340
# 2015-11-08 New Hampshire         45.641840      39.072340
#            South Carolina        40.866410      45.800820
# 2015-11-09 New Hampshire         45.641840      39.072340
#            South Carolina        40.866410      45.800820
# 2015-11-10 New Hampshire         45.641840      39.072340
#            Virginia              49.381830      38.098560
# 2015-11-11 Iowa                  42.006200      41.554670
#            Nevada                41.870070      45.427960
#            New Hampshire         45.641840      39.072340
#            South Carolina        42.378460      45.954830
#            Virginia              49.381830      38.098560
# 2015-11-12 Colorado              36.477440      46.593300
#            Iowa                  42.006200      41.554670
#            Nevada                41.870070      45.427960
#            New Hampshire         45.641840      39.072340
#            South Carolina        42.378460      45.954830
#            Virginia              49.381830      38.098560
# 2015-11-13 Colorado              36.477440      46.593300
#            Iowa                  42.006200      41.554670
#            Nevada                41.870070      45.427960
#            New Hampshire         45.641840      39.072340
#            South Carolina        42.378460      45.954830
#            Virginia              49.381830      38.098560
#            Wisconsin             47.966370      38.570480
# 2015-11-14 Colorado              36.477440      46.593300
#            Iowa                  42.006200      41.554670
#            Nevada                41.870070      45.427960
#            New Hampshire         45.641840      39.072340
#            South Carolina        42.378460      45.954830
# ...                                    ...            ...
# 2016-11-08 Massachusetts         54.189624      30.003283
#            Michigan              42.130776      41.033364
#            Minnesota             43.212616      37.877200
#            Mississippi           37.590540      51.816194
#            Missouri              39.956431      45.181316
#            Montana               31.994783      48.125691
#            Nebraska              34.003305      50.452038
#            Nevada                43.161633      42.610507
#            New Hampshire         46.358836      37.344726
#            New Jersey            48.088936      37.109316
#            New Mexico            40.963553      36.905833
#            New York              51.696415      34.153444
#            North Carolina        45.285212      41.574191
#            North Dakota          27.612346      55.398431
#            Ohio                  40.502692      44.214473
#            Oklahoma              30.790226      55.180734
#            Oregon                48.979347      33.811296
#            Pennsylvania          44.101094      42.519717
#            Rhode Island          46.497914      34.326394
#            South Carolina        40.645997      47.356894
#            South Dakota          32.811297      50.102117
#            Tennessee             39.546639      48.775996
#            Texas                 40.459925      46.123358
#            Utah                  29.087217      34.580664
#            Vermont               59.211470      24.424033
#            Virginia              46.795925      39.580913
#            Washington            49.075756      33.543160
#            West Virginia         28.247749      55.787800
#            Wisconsin             44.283059      40.009943
#            Wyoming               23.316757      57.048664
#
# [6296 rows x 5 columns]

# %% [markdown]
# ## 4. Analyze data
# With our data at hand, we can finally test what google searches reveal about political opinion. We combine the data (easy!) and use the scipy module to test some ideas. After that you're free to explore!

# %% [markdown]
# Combine Google and 538 data using `pd.concat()`.

# %%
# ---
# add your code here

data = pd.concat([google_data, poll_data], axis=1)

# ---

# %% [markdown]
# As always, check the result! (If you have no complete observations, something went wrong with the matching. Most likely the date wasn't the same format.)

# %%
data.dropna()
# Out:
#                               trump   clinton  samplesize_day  \
# date       state
# 2015-11-08 New Hampshire   0.680000  0.320000       48.181818
#            South Carolina  0.820000  0.180000      645.000000
# 2015-11-09 New Hampshire   0.630000  0.370000       48.181818
#            South Carolina  0.880000  0.120000      645.000000
# 2015-11-10 New Hampshire   0.570000  0.430000       48.181818
#            Virginia        0.750000  0.250000      111.000000
# 2015-11-11 Iowa            0.750000  0.250000       91.571429
#            Nevada          0.680000  0.320000       89.714286
#            New Hampshire   0.620000  0.380000       48.181818
#            South Carolina  0.840000  0.160000       89.571429
#            Virginia        0.720000  0.280000      111.000000
# 2015-11-12 Colorado        0.660000  0.340000      252.400000
#            Iowa            0.640000  0.360000       91.571429
#            Nevada          0.650000  0.350000       89.714286
#            New Hampshire   0.440000  0.560000       48.181818
#            South Carolina  0.630000  0.370000       89.571429
#            Virginia        0.730000  0.270000      111.000000
# 2015-11-13 Colorado        0.840000  0.160000      252.400000
#            Iowa            0.900000  0.100000       91.571429
#            Nevada          0.710000  0.290000       89.714286
#            New Hampshire   0.470000  0.530000       48.181818
#            South Carolina  0.850000  0.150000       89.571429
#            Virginia        0.730000  0.270000      111.000000
#            Wisconsin       0.770000  0.230000      200.750000
# 2015-11-14 Colorado        0.870000  0.130000      252.400000
#            Iowa            0.810000  0.190000       91.571429
#            Nevada          0.830000  0.170000       89.714286
#            New Hampshire   0.510000  0.490000       48.181818
#            South Carolina  0.900000  0.100000       89.571429
#            Virginia        0.770000  0.230000      111.000000
# ...                             ...       ...             ...
# 2016-11-08 Massachusetts   0.462025  0.537975      277.142857
#            Michigan        0.531646  0.468354      566.571429
#            Minnesota       0.518987  0.481013      283.857143
#            Mississippi     0.490446  0.509554      144.285714
#            Missouri        0.509554  0.490446      297.857143
#            Montana         0.449367  0.550633       91.714286
#            Nebraska        0.462025  0.537975      179.142857
#            Nevada          0.531646  0.468354      209.428571
#            New Hampshire   0.490446  0.509554      115.000000
#            New Jersey      0.500000  0.500000      341.285714
#            New Mexico      0.500000  0.500000      144.285714
#            New York        0.462025  0.537975      502.285714
#            North Carolina  0.518987  0.481013      560.000000
#            North Dakota    0.518987  0.481013       62.142857
#            Ohio            0.500000  0.500000      561.428571
#            Oklahoma        0.500000  0.500000      217.000000
#            Oregon          0.481013  0.518987      299.571429
#            Pennsylvania    0.500000  0.500000      574.571429
#            Rhode Island    0.632911  0.367089       70.857143
#            South Carolina  0.509554  0.490446      305.428571
#            South Dakota    0.550633  0.449367       84.000000
#            Tennessee       0.518987  0.481013      275.285714
#            Texas           0.500000  0.500000      594.857143
#            Utah            0.531646  0.468354      252.142857
#            Vermont         0.388535  0.611465       78.428571
#            Virginia        0.500000  0.500000      421.142857
#            Washington      0.500000  0.500000      304.714286
#            West Virginia   0.500000  0.500000       87.000000
#            Wisconsin       0.509554  0.490446      451.428571
#            Wyoming         0.537975  0.462025       46.571429
#
#                            rawpoll_clinton  rawpoll_trump  adjpoll_clinton  \
# date       state
# 2015-11-08 New Hampshire         45.000000      38.000000        45.641840
#            South Carolina        42.000000      47.000000        40.866410
# 2015-11-09 New Hampshire         45.000000      38.000000        45.641840
#            South Carolina        42.000000      47.000000        40.866410
# 2015-11-10 New Hampshire         45.000000      38.000000        45.641840
#            Virginia              50.000000      36.000000        49.381830
# 2015-11-11 Iowa                  41.000000      40.000000        42.006200
#            Nevada                41.000000      44.000000        41.870070
#            New Hampshire         45.000000      38.000000        45.641840
#            South Carolina        41.000000      44.000000        42.378460
#            Virginia              50.000000      36.000000        49.381830
# 2015-11-12 Colorado              37.000000      48.000000        36.477440
#            Iowa                  41.000000      40.000000        42.006200
#            Nevada                41.000000      44.000000        41.870070
#            New Hampshire         45.000000      38.000000        45.641840
#            South Carolina        41.000000      44.000000        42.378460
#            Virginia              50.000000      36.000000        49.381830
# 2015-11-13 Colorado              37.000000      48.000000        36.477440
#            Iowa                  41.000000      40.000000        42.006200
#            Nevada                41.000000      44.000000        41.870070
#            New Hampshire         45.000000      38.000000        45.641840
#            South Carolina        41.000000      44.000000        42.378460
#            Virginia              50.000000      36.000000        49.381830
#            Wisconsin             48.000000      38.000000        47.966370
# 2015-11-14 Colorado              37.000000      48.000000        36.477440
#            Iowa                  41.000000      40.000000        42.006200
#            Nevada                41.000000      44.000000        41.870070
#            New Hampshire         45.000000      38.000000        45.641840
#            South Carolina        41.000000      44.000000        42.378460
#            Virginia              50.000000      36.000000        49.381830
# ...                                    ...            ...              ...
# 2016-11-08 Massachusetts         53.636124      28.809371        54.189624
#            Michigan              42.174175      40.354274        42.130776
#            Minnesota             42.274912      36.334726        43.212616
#            Mississippi           37.107743      50.662673        37.590540
#            Missouri              39.071511      43.680806        39.956431
#            Montana               31.388879      46.877383        31.994783
#            Nebraska              34.009394      49.740909        34.003305
#            Nevada                43.413492      42.114877        43.161633
#            New Hampshire         46.861888      37.081963        46.358836
#            New Jersey            46.649828      35.123416        48.088936
#            New Mexico            40.651208      35.914584        40.963553
#            New York              50.612526      32.479898        51.696415
#            North Carolina        45.372913      40.929107        45.285212
#            North Dakota          27.137747      54.268322        27.612346
#            Ohio                  40.102316      43.143155        40.502692
#            Oklahoma              31.141224      54.769796        30.790226
#            Oregon                48.791082      32.931674        48.979347
#            Pennsylvania          43.568158      41.329023        44.101094
#            Rhode Island          46.806230      33.893347        46.497914
#            South Carolina        40.717680      46.695416        40.645997
#            South Dakota          32.763469      49.345000        32.811297
#            Tennessee             39.259336      47.802813        39.546639
#            Texas                 40.029287      45.023631        40.459925
#            Utah                  29.433076      34.170142        29.087217
#            Vermont               59.463388      23.937523        59.211470
#            Virginia              46.488060      38.589264        46.795925
#            Washington            48.336587      32.178275        49.075756
#            West Virginia         28.165402      54.998933        28.247749
#            Wisconsin             43.759930      38.832816        44.283059
#            Wyoming               22.400368      55.525061        23.316757
#
#                            adjpoll_trump
# date       state
# 2015-11-08 New Hampshire       39.072340
#            South Carolina      45.800820
# 2015-11-09 New Hampshire       39.072340
#            South Carolina      45.800820
# 2015-11-10 New Hampshire       39.072340
#            Virginia            38.098560
# 2015-11-11 Iowa                41.554670
#            Nevada              45.427960
#            New Hampshire       39.072340
#            South Carolina      45.954830
#            Virginia            38.098560
# 2015-11-12 Colorado            46.593300
#            Iowa                41.554670
#            Nevada              45.427960
#            New Hampshire       39.072340
#            South Carolina      45.954830
#            Virginia            38.098560
# 2015-11-13 Colorado            46.593300
#            Iowa                41.554670
#            Nevada              45.427960
#            New Hampshire       39.072340
#            South Carolina      45.954830
#            Virginia            38.098560
#            Wisconsin           38.570480
# 2015-11-14 Colorado            46.593300
#            Iowa                41.554670
#            Nevada              45.427960
#            New Hampshire       39.072340
#            South Carolina      45.954830
#            Virginia            38.098560
# ...                                  ...
# 2016-11-08 Massachusetts       30.003283
#            Michigan            41.033364
#            Minnesota           37.877200
#            Mississippi         51.816194
#            Missouri            45.181316
#            Montana             48.125691
#            Nebraska            50.452038
#            Nevada              42.610507
#            New Hampshire       37.344726
#            New Jersey          37.109316
#            New Mexico          36.905833
#            New York            34.153444
#            North Carolina      41.574191
#            North Dakota        55.398431
#            Ohio                44.214473
#            Oklahoma            55.180734
#            Oregon              33.811296
#            Pennsylvania        42.519717
#            Rhode Island        34.326394
#            South Carolina      47.356894
#            South Dakota        50.102117
#            Tennessee           48.775996
#            Texas               46.123358
#            Utah                34.580664
#            Vermont             24.424033
#            Virginia            39.580913
#            Washington          33.543160
#            West Virginia       55.787800
#            Wisconsin           40.009943
#            Wyoming             57.048664
#
# [6259 rows x 7 columns]

# %% [markdown]
# Before we use scipy, it's worth keeping in mind that pandas has a lot of data science capability built in! Try to estimate the correlation between the relative search volume for Trump and his performance in the polls using `.corr()`:

# %%
# ---
# add your code here
print(data['rawpoll_trump'].corr(data['trump']))
print(data['rawpoll_clinton'].corr(data['clinton']))

# ---
# Out:
# -0.06811603007332102
# -0.13837400708040404

# %% [markdown]
# Seems like people didn't particularily like the candidates they googled...

# %%
states = data.index.get_level_values(1).unique()

df = data.copy()
df = df.reset_index(level=['state', 'date'])

for state in states:
    print(state,':')
    df1 = df[df['state'] == state]
    print(df1['rawpoll_trump'].corr(df1['trump']))
    print(df1['rawpoll_clinton'].corr(df1['clinton']))
    print('')
# Out:
# New Hampshire :
# 0.08492454422868134
# -0.05581006335463174
#
# Alabama :
# 0.029880230372623186
# -0.14439223672618134
#
# Alaska :
# -0.2014053238558636
# 0.012037607836193771
#
# Arizona :
# 0.0344630781623133
# -0.14547733649553238
#
# California :
# 0.13005408100779295
# -0.14069124636707947
#
# Colorado :
# -0.03901347523098426
# -0.1789499750511866
#
# Connecticut :
# -0.12272704155784375
# 0.03090220191402395
#
# District of Columbia :
# -0.04074292334544256
# 0.06456152186700687
#
# Florida :
# -0.21371622697317946
# -0.42036865055851036
#
# Georgia :
# -0.14944956122165087
# -0.02927963316852944
#
# Hawaii :
# 0.009737456185285322
# -0.3338100210587378
#
# Illinois :
# -0.27801930012176007
# -0.1491028249263646
#
# Indiana :
# 0.10350899684120925
# -0.2720359329020461
#
# Iowa :
# -0.11209945728693901
# -0.3717510757757521
#
# Kansas :
# -0.09686310532076879
# 0.2428560542712669
#
# Kentucky :
# -0.09152823804312159
# -0.16655976382103038
#
# Louisiana :
# -0.12140367050653773
# -0.004350064553488925
#
# Maryland :
# -0.14213725665604207
# -0.17145988101527238
#
# Massachusetts :
# -0.3461321241089863
# -0.24099672786314005
#
# Michigan :
# -0.06896908404748471
# -0.39110129247396713
#
# Minnesota :
# -0.11629037555989058
# 0.027543564327058786
#
# Mississippi :
# -0.2080184972737002
# -0.123226327513928
#
# Missouri :
# -0.27118931301107624
# -0.35693616363239333
#
# Montana :
# 0.05036891384092018
# 0.16259033266962505
#
# New Jersey :
# 0.0533702398170863
# -0.10233015206927011
#
# New York :
# 0.1635345415902747
# -0.22558236101251417
#
# North Carolina :
# 0.08690291834768303
# -0.1878188974053556
#
# Ohio :
# 0.027956939610351443
# -0.3378471673383266
#
# Oklahoma :
# -0.11762495176072504
# -0.14316388620487644
#
# Oregon :
# -0.08191095024824452
# 0.07772025312272807
#
# Pennsylvania :
# -0.18552318949509256
# -0.2503622248547946
#
# South Carolina :
# -0.0818355597770097
# -0.0986554157327126
#
# Tennessee :
# -0.5530090589557901
# -0.13663254821399395
#
# Texas :
# -0.30778280593818735
# -0.11802217735728143
#
# Utah :
# 0.04439020843392774
# -0.35230851609086
#
# Vermont :
# -0.024063109381828054
# 0.08174910622481063
#
# Virginia :
# -0.23418996636017334
# -0.1844413541635766
#
# Washington :
# 0.12123618139997741
# -0.0317446814618461
#
# West Virginia :
# 0.031364918715887924
# -0.06807550014526616
#
# Wisconsin :
# 0.03791699046495691
# -0.4365743448508763
#
# Wyoming :
# 0.07136283542018008
# 0.0013857206835714798
#
# Arkansas :
# -0.3720785921876179
# -0.2386779687416287
#
# Idaho :
# -0.16770435780816134
# -0.34569438215742604
#
# Nebraska :
# -0.30927817977687827
# -0.21396449037589604
#
# Nevada :
# -0.07927101762784877
# -0.14264274361353374
#
# Rhode Island :
# -0.10739662776307364
# -0.15917560115064047
#
# South Dakota :
# -0.06479267475159074
# -0.2384497102836492
#
# New Mexico :
# -0.0706588139535627
# 0.07574518030182917
#
# North Dakota :
# 0.021410145841233987
# 0.20324216714726873
#
# Delaware :
# -0.08153079176843847
# 0.02540447734574195
#
# Maine :
# -0.11912133999663362
# -0.015433311139748732

# %% [markdown]
# Some additional ideas to test if you have enough time:
# - Search data around the primaries might be missleading. Does the fit improve if we only look after the national conventions?
